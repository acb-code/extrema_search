# %%
# notebook for first canonical problem for multimodal optimization looking for localized extreme
# events with agent-based military simulation
# Experiment 2.1 - Deterministic multimodal localized extrema test problem
# Part 2 - Balanced strategy approach (PIONEER)
# PIONEER - Partitioned bayesIan OptimizatioN for multi-Extrema Emergent behavioR
#
# Author: Alex Braafladt
# Initial creation: 3/10/23
#
# Goal: Benchmark new algorithm for balancing global and local search on a multimodal
#       optimization test function focused on localized extrema
#
# Notes:
# -Using the BoTorch framework [1] and NEI from [4]
# -TEAD technique from [2]
# -TuRBO technique from [3]
# -Balanced strategy definition from [5]
#
# References:
# [1] M. Balandat et al., “BOTORCH: A framework for efficient Monte-Carlo Bayesian optimization,”
#     Adv. Neural Inf. Process. Syst., vol. 2020-Decem, no. MC, 2020.
# [2] S. Mo et al., “A Taylor Expansion-Based Adaptive Design Strategy for Global Surrogate
#     Modeling With Applications in Groundwater Modeling,” Water Resour. Res., vol. 53, no.
#     12, pp. 10802–10823, 2017, doi: 10.1002/2017WR021622.
# [3] D. Eriksson, M. Pearce, J. R. Gardner, R. Turner, and M. Poloczek, “Scalable global
#     optimization via local Bayesian optimization,” Adv. Neural Inf. Process. Syst., vol.
#     32, no. NeurIPS, 2019.
# [4] B. Letham, B. Karrer, G. Ottoni, and E. Bakshy, “Constrained Bayesian optimization with noisy
#     experiments,” Bayesian Anal., vol. 14, no. 2, pp. 495–519, 2019, doi: 10.1214/18-BA1110.
# [5] J. N. Fuhg, A. Fau, and U. Nackenhorst, State-of-the-Art and Comparative Review of
#     Adaptive Sampling Methods for Kriging, vol. 28, no. 4. Springer Netherlands, 2021.

# %%
# imports
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from extremasearch.globalmm.globalsearch import MultimodalExtremaSearch
from botorch import fit_gpytorch_mll
from botorch.models.gp_regression import SingleTaskGP
from gpytorch.mlls import ExactMarginalLogLikelihood
import numpy as np
import networkx as nx
from botorch.models.transforms import Normalize, Standardize
import time


# setup
dtype = torch.double
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import warnings
from botorch.exceptions import BadInitialCandidatesWarning
warnings.filterwarnings('ignore', category=BadInitialCandidatesWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# %%
# setup file i/o
import os as os
import datetime as dt
# get current working directory
wrkdir = os.getcwd()
print('Current working directory: '+wrkdir)
# set up a data save directory for all future runs
newoutputdir = wrkdir+'\output'
if not os.path.exists(newoutputdir):
    os.makedirs(newoutputdir)
# set up a new directory to store files for the current run - updates at each new full run of notebook
curDatetime = dt.datetime.now()
datasavedir = newoutputdir + r'\\' + 'exp2.1_balanced_mme_deterministic' + str(curDatetime.strftime('%Y%m%d%H%M%S'))
if not os.path.exists(datasavedir):
    os.makedirs(datasavedir)
print('Data save directory: '+datasavedir)
# Out:
# Current working directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks\iter4_exp2
# Data save directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks\iter4_exp2\output\\exp2.1_balanced_mme_deterministic20230310131211

# %%
# test function
def mme_torch(x):
    x = x
    y = torch.zeros(x.shape)
    y += 0.66*(-1.*x + 0.1*torch.sin(30.*x) + torch.exp(-(100.*(x-0.65))**2.))
    y += 0.5 * ( torch.exp(-(100.*(x-0.35))**2.) )
    y += 0.4 * ( torch.exp(-(100.*(x-0.92))**2.) )
    y += 0.73
    return y

# %%
# plot the test function
x1 = torch.linspace(0,1.0,200)
y1 = mme_torch(x1)
fig, ax = plt.subplots(1, 1, figsize=(8,6))
sns.lineplot(x=x1, y=y1, ax=ax, color='r')
# ax.set_xlim([0.915, 0.925])
# ax.set_ylim([0.4, 0.6])
plt.savefig(datasavedir + '/'+'deterministic_test_problem'+'.png')

# %%
# wrapper for use in optimization loop
def outcome_objective(x):
    """wrapper for the outcome objective function"""
    # return mme_torch(X).type_as(X)
    return mme_torch(x).type_as(x)

# %%
# functions for getting and working with data from searches
def get_bounds(graph):
    """Get the bounds for each node in a graph to be able to plot them"""
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    bound_list = []
    node_list = []
    for n in graph_leaves:
        # get current leaf node
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_bounds = current_state.local_bounds
        node_list.append(n)
        bound_list.append(current_bounds)
    return node_list, bound_list


def get_bounds_all(graph):
    """Get the bounds for each node in a graph to be able to plot them"""
    graph_nodes = [n for n in graph]
    bound_list = []
    node_list = []
    for n in graph_nodes:
        # get current node
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_bounds = current_state.local_bounds
        node_list.append(n)
        bound_list.append(current_bounds)
    return node_list, bound_list


def fit_local_models(graph):
    """Go through leaf nodes and update LocalSearchState to have local {x, y}
    based on global {x, y} that are within bounds"""
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    for n in graph_leaves:
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_state.local_model = SingleTaskGP(current_state.x_local, current_state.y_local,
                                                 input_transform=Normalize(d=current_state.x_local.shape[-1]),
                                                 outcome_transform=Standardize(m=current_state.y_local.shape[-1]))
        current_state.local_mll = ExactMarginalLogLikelihood(current_state.local_model.likelihood,
                                                             current_state.local_model)
        fit_gpytorch_mll(current_state.local_mll)


def plot_local_models_1d(graph, x_search, y_search, rep):
    """Go through leaf nodes and plot the local models only within the bounds of the node"""
    fit_local_models(graph)
    nodes, bnds = get_bounds(graph)
    x_test = torch.linspace(0, 1, 400)
    f, ax = plt.subplots(1, 1, figsize=(8, 6))
    # true objective
    ax.plot(x_test.numpy(), outcome_objective(x_test).numpy(), 'r-', alpha=0.9, label='true objective')
    # local models
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    for n in graph_leaves:
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_model = current_state.local_model
        current_bounds = current_state.local_bounds
        current_x_test_mask = torch.ge(x_test, current_bounds[0]) & torch.lt(x_test, current_bounds[1])
        current_x_test = x_test[current_x_test_mask]
        mean_test = current_model.posterior(current_x_test.unsqueeze(-1)).mean.detach().numpy()
        ax.plot(current_x_test.numpy(), mean_test, 'b-', alpha=0.9, label='surrogate mean')
        var_test = current_model.posterior(current_x_test.unsqueeze(-1)).variance.detach().numpy()
        sd_test = np.sqrt(var_test)
        upper_test = mean_test + 2.0 * sd_test
        lower_test = mean_test - 2.0 * sd_test
        ax.fill_between(current_x_test.numpy(), lower_test.squeeze(), upper_test.squeeze(), color='b', alpha=0.3,
                        label=r'surrogate 2$\sigma$')
    # training points
    ax.plot(x_search.numpy()[0:10], y_search[0:10].numpy(), '.', color='tab:orange', label='initial data')
    ax.plot(x_search.numpy()[10:], y_search[10:].numpy(), '.', color='g', label='bo data')
    # partitions
    for n, b in zip(nodes, bnds):
        ax.plot([b[0].numpy(), b[0].numpy()], [-0.05, 1.45], 'k-')
    # ax.legend()
    ax.set_ylim([-0.02, 1.02])
    ax.set_title('PIONEER_rep{}'.format(rep))
    # ax.set_xlim([0.915, 0.925])
    plt.savefig(datasavedir + '/'+'1d_results_local_models_rep{}'.format(rep)+'.png')


def plot_current_tree(global_search: MultimodalExtremaSearch, rep):
    """Save a plot of the tree structure after the search"""
    # tree figure
    T = global_search.global_state.partition_graph
    pos = nx.nx_agraph.graphviz_layout(T, prog="dot")
    # bounds to put on nodes on plot
    all_nodes, all_bounds = get_bounds_all(global_search.global_state.partition_graph)
    # positioning of bound text
    pos_attrs = {}
    for node, coords in pos.items():
        pos_attrs[node] = (coords[0]-15, coords[1])
    custom_node_attrs = {}
    for node, attrs in zip(all_nodes, all_bounds):
        custom_node_attrs[node] = str(attrs.numpy().round(decimals=3))
    # plot commands
    f, ax = plt.subplots(1, 1, figsize=(12, 8), constrained_layout=True)
    nx.draw(T, pos, with_labels=True, font_weight='bold', ax=ax)
    nx.draw_networkx_labels(T, pos_attrs, labels=custom_node_attrs, ax=ax)
    ax.set_title('PIONEER Partition Tree')
    plt.savefig(datasavedir + '/'+'partition_tree_rep{}'.format(rep)+'.png')

# %%
# experiment functions to calculate metrics
# metrics functions
def count_number_peaks_observed(x_obs, y_obs, num_known_peaks=4):
    """Function to count the number of peaks observed for the mme_noise_jump_1d function"""
    peak1, peak2, peak3, peak4 = False, False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.03 <= x <= 0.07:
            if y >= 0.74:
                peak1 = True
        elif 0.345 <= x <= 0.355:
            if y >= 0.81:
                peak2 = True
        elif 0.645 <= x <= 0.655:
            if y >= 0.84:
                peak3 = True
        elif 0.915 <= x <= 0.925:
            if y >= 0.45:
                peak4 = True
    num_peaks_observed = peak1 + peak2 + peak3 + peak4
    return num_peaks_observed


def count_evaluations_for_all_peaks(x_obs, y_obs):
    """Count the number of function evaluations before finding all peaks"""
    i = 0
    num_evals_for_all_peaks = x_obs.shape[0]
    peak1, peak2, peak3, peak4 = False, False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.03 <= x <= 0.07:
            if y >= 0.74:
                peak1 = True
        elif 0.345 <= x <= 0.355:
            if y >= 0.81:
                peak2 = True
        elif 0.645 <= x <= 0.655:
            if y >= 0.84:
                peak3 = True
        elif 0.915 <= x <= 0.925:
            if y >= 0.45:
                peak4 = True
        i += 1
        if peak1 and peak2 and peak3 and peak4:
            num_evals_for_all_peaks = i
            break
    return num_evals_for_all_peaks

# %%
# replicated searches

# search and experiment settings
n_replications = 15
global_bounds = torch.tensor([0.0, 1.0], dtype=dtype)
n_evals = 130

# data holders
x_observed_all = []
y_observed_all = []
distinct_peaks = []
function_evaluations = []

# experiment loop
for rep in range(1, n_replications + 1):
    print(f"\nTrial {rep:>2} of {n_replications} ", end="")
    t0 = time.monotonic()
    # initialize search
    current_global_search = MultimodalExtremaSearch(60,global_bounds,outcome_objective,total_iteration_limit=n_evals)
    # run search
    current_global_search.run_global_search()

    # collect data
    x_observed_all.append(current_global_search.global_state.x_global)
    y_observed_all.append(current_global_search.global_state.y_global)

    # run and save plots
    # results with local model
    plot_local_models_1d(current_global_search.global_state.partition_graph,
                         current_global_search.global_state.x_global,
                         current_global_search.global_state.y_global,
                         rep)
    # partitioning results tree
    plot_current_tree(current_global_search, rep)

    # calculate metrics
    num_peaks_observed = count_number_peaks_observed(current_global_search.global_state.x_global,
                                                     current_global_search.global_state.y_global)
    print("Observed {num:} peaks".format(num=num_peaks_observed),)
    distinct_peaks.append(num_peaks_observed)
    fe = count_evaluations_for_all_peaks(current_global_search.global_state.x_global,
                                         current_global_search.global_state.y_global)
    print("Function evaluations to find all peaks: {}".format(fe))
    function_evaluations.append(fe)
    # time for search
    t1 = time.monotonic()
    print("Time to complete search: {}".format(t1-t0))
# Out:
# Trial  1 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.2095, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.2095001384500033
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.032588536875491354  best tead:  0.7000839930451128
# SELECT: For node  2  best x:  0.9465422678001183  best tead:  1.218759104307279
# SELECT: Found  2  as best with score  1.218759104307279
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.10257675587891862  and  0.2377363116959516
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.03487473486709461  and  0.06224635250067501
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.4734, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(0.8493, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.4733533474242173
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  3  new edge from  1  to  3
# PARTITION: New node  4  new edge from  1  to  4
# Running subdomain selection
# SELECT: For node  2  best x:  0.5067891807932028  best tead:  1.2288302405806935
# SELECT: For node  3  best x:  0.17922629105160756  best tead:  0.6725257401376971
# SELECT: For node  4  best x:  0.49344864138086425  best tead:  1.0929434147230213
# SELECT: Found  2  as best with score  1.2288302405806935
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.10345011934948906  and  0.23757639502016012
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.022387780567031963  and  0.14628764972401603
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  2  tead score:  tensor(1.1816, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.7124, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.9834, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.1816085888536487
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  5  new edge from  2  to  5
# PARTITION: New node  6  new edge from  2  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.179635825623375  best tead:  0.6769325557446925
# SELECT: For node  4  best x:  0.49852173748985396  best tead:  0.8825301078999015
# SELECT: For node  5  best x:  0.5014866364971693  best tead:  1.0502132591958189
# SELECT: For node  6  best x:  0.7792045206312289  best tead:  0.8556425379681086
# SELECT: Found  5  as best with score  1.0502132591958189
# Running local search
# LOCALSEARCH: Running search in node  5
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.47472747617850575  and  0.5389451048049555
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.4434851608121072  and  0.47744139858970913
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.3439, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.5238, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.5096, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.6078, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  0.6077925430688603
# Running partition
# PARTITION: Splitting node  6  from  0.75  to  0.875  to  1.0
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.17012195653212203  best tead:  0.35056512995890593
# SELECT: For node  4  best x:  0.49858382288793673  best tead:  0.5239501220281725
# SELECT: For node  5  best x:  0.5654209253681247  best tead:  0.5119368183680982
# SELECT: For node  7  best x:  0.8452459110699164  best tead:  0.47405839478139056
# SELECT: For node  8  best x:  0.8943037529436465  best tead:  0.5277715210337209
# SELECT: Found  8  as best with score  0.5277715210337209
# Running local search
# LOCALSEARCH: Running search in node  8
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.3216024563631536  and  0.41382814800320533
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.24204072551639094  and  0.31103710120497546
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.3880, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.5768, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.9918, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.9215, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.8607, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  5  for split with score  0.9917546181278046
# Running partition
# PARTITION: Splitting node  5  from  0.5  to  0.625  to  0.75
# PARTITION: New node  9  new edge from  5  to  9
# PARTITION: New node  10  new edge from  5  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.17005977719493745  best tead:  0.3917642602059243
# SELECT: For node  4  best x:  0.376724363053887  best tead:  0.615156497967299
# SELECT: For node  7  best x:  0.7912346696914159  best tead:  0.9453113250565949
# SELECT: For node  8  best x:  0.9891994992497881  best tead:  0.8720545702550369
# SELECT: For node  9  best x:  0.5652374129803986  best tead:  1.0289700534683661
# SELECT: For node  10  best x:  0.7450542927615448  best tead:  0.9303904496245083
# SELECT: Found  9  as best with score  1.0289700534683661
# Running local search
# LOCALSEARCH: Running search in node  9
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.167533632602768  and  0.5602233137129862
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.16363954241596346  and  0.23511542589612489
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.4947, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.7100, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.5498, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.8892, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.7808, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.8924, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  10  for split with score  0.8924315697939829
# Running partition
# PARTITION: Splitting node  10  from  0.625  to  0.6875  to  0.75
# PARTITION: New node  11  new edge from  10  to  11
# PARTITION: New node  12  new edge from  10  to  12
# Running subdomain selection
# SELECT: For node  3  best x:  0.1157372486149085  best tead:  0.49711763606469694
# SELECT: For node  4  best x:  0.37640295651126815  best tead:  0.7050221024735648
# SELECT: For node  7  best x:  0.8391793369640452  best tead:  0.5436182702440048
# SELECT: For node  8  best x:  0.9890312151364063  best tead:  0.9083570285234046
# SELECT: For node  9  best x:  0.5688159273712882  best tead:  0.780517275792713
# SELECT: For node  11  best x:  0.6732152283640526  best tead:  0.4874713660279885
# SELECT: For node  12  best x:  0.7162085481235507  best tead:  0.5206989012376196
# SELECT: Found  8  as best with score  0.9083570285234046
# Running local search
# LOCALSEARCH: Running search in node  8
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.37705710661498787  and  0.40571337343459907
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.9040762611369318  and  0.9229797441624287
# Observed 4 peaks
# Function evaluations to find all peaks: 88
# Time to complete search: 646.2350000000006
#
# Trial  2 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.2902, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.2902362194439136
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.202294469571704  best tead:  0.5334410935014852
# SELECT: For node  2  best x:  0.9650300022050688  best tead:  1.4641418247559943
# SELECT: Found  2  as best with score  1.4641418247559943
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.9249140613258158  and  0.9254208994152344
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.8592693652906581  and  0.9585953335925131
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.0789, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.2037, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.2037067108901123
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.16786150196810012  best tead:  1.0866724339975027
# SELECT: For node  3  best x:  0.7309776133967478  best tead:  0.5377436652769314
# SELECT: For node  4  best x:  0.7560444048466265  best tead:  1.0863002558398103
# SELECT: Found  1  as best with score  1.0866724339975027
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.7535524124576161  and  0.8025058701761292
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.2886155626127111  and  0.35097340576775243
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.9791, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.5828, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.9806, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  0.9806321584390701
# Running partition
# PARTITION: Splitting node  4  from  0.75  to  0.875  to  1.0
# PARTITION: New node  5  new edge from  4  to  5
# PARTITION: New node  6  new edge from  4  to  6
# Running subdomain selection
# SELECT: For node  1  best x:  0.00012838515076955438  best tead:  0.9207614973854549
# SELECT: For node  3  best x:  0.7308426603224562  best tead:  0.5510051951733069
# SELECT: For node  5  best x:  0.8325685912654407  best tead:  0.32465105956325524
# SELECT: For node  6  best x:  0.9441354887275453  best tead:  0.6447396321117489
# SELECT: Found  1  as best with score  0.9207614973854549
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.7537313515119557  and  0.8025505936466238
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.34972936369903257  and  0.3652947832686441
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.7014, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.5590, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.3331, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.6371, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  0.7013607808691706
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  7  new edge from  1  to  7
# PARTITION: New node  8  new edge from  1  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.7307194399298604  best tead:  0.5518908677268474
# SELECT: For node  5  best x:  0.8327700409978911  best tead:  0.3293321133304
# SELECT: For node  6  best x:  0.9440992593605617  best tead:  0.62849237204687
# SELECT: For node  7  best x:  0.12060953308871175  best tead:  0.6864949738494579
# SELECT: For node  8  best x:  0.49694425437469086  best tead:  0.8818726299028489
# SELECT: Found  8  as best with score  0.8818726299028489
# Running local search
# LOCALSEARCH: Running search in node  8
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.2990686656182406  and  0.2994017343248855
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.3385786366505163  and  0.35000548780389
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.5627, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.3358, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.6324, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.6342, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.8860, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  8  for split with score  0.8860365794902182
# Running partition
# PARTITION: Splitting node  8  from  0.25  to  0.375  to  0.5
# PARTITION: New node  9  new edge from  8  to  9
# PARTITION: New node  10  new edge from  8  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.7312789355209508  best tead:  0.7077035499768164
# SELECT: For node  5  best x:  0.8333501441167525  best tead:  0.3527609394169572
# SELECT: For node  6  best x:  0.9447641239993446  best tead:  0.29405084389598707
# SELECT: For node  7  best x:  0.0684601834337972  best tead:  0.5710741589007023
# SELECT: For node  9  best x:  0.2595061069875392  best tead:  0.10006938204025226
# SELECT: For node  10  best x:  0.4520018326260231  best tead:  0.08269391902637582
# SELECT: Found  3  as best with score  0.7077035499768164
# Running local search
# LOCALSEARCH: Running search in node  3
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5323682644219168  and  0.532661403639178
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.6430042185112118  and  0.652003124751079
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(1.0276, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(1.0130, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.8691, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(1.1487, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(1.0510, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.9307, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  7  for split with score  1.1486829664150675
# Running partition
# PARTITION: Splitting node  7  from  0.0  to  0.125  to  0.25
# PARTITION: New node  11  new edge from  7  to  11
# PARTITION: New node  12  new edge from  7  to  12
# Running subdomain selection
# SELECT: For node  3  best x:  0.7313816696485993  best tead:  1.314807235646955
# SELECT: For node  5  best x:  0.8326556118538114  best tead:  1.0907839348949728
# SELECT: For node  6  best x:  0.9446028449364093  best tead:  1.3665504803603643
# SELECT: For node  9  best x:  0.2524504959120737  best tead:  1.140332790740304
# SELECT: For node  10  best x:  0.451802654801118  best tead:  1.1597369707167497
# SELECT: For node  11  best x:  0.04230641515813169  best tead:  0.8540267550518782
# SELECT: For node  12  best x:  0.21432252023207765  best tead:  1.1557122250655074
# SELECT: Found  6  as best with score  1.3665504803603643
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.3614228266154524  and  0.555246072614579
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.9040964171297509  and  0.9199646021886855
# Observed 4 peaks
# Function evaluations to find all peaks: 63
# Time to complete search: 660.125
#
# Trial  3 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.2590, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.2589992202065128
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.32231898500192246  best tead:  0.6265439267452303
# SELECT: For node  2  best x:  0.928588696087007  best tead:  1.1942181816491935
# SELECT: Found  2  as best with score  1.1942181816491935
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.8382616452766386  and  0.8389859533987077
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.914344615241914  and  0.929743160432606
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.8391, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.1480, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.1480125348132417
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.2053276701855239  best tead:  0.833750858807103
# SELECT: For node  3  best x:  0.7070343755650254  best tead:  1.411689673115236
# SELECT: For node  4  best x:  0.7616752758544963  best tead:  0.7685743392454465
# SELECT: Found  3  as best with score  1.411689673115236
# Running local search
# LOCALSEARCH: Running search in node  3
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.6099838664803049  and  0.7840148325198426
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.6470053833266012  and  0.662401393457245
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.7955, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.8106, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.7165, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  3  for split with score  0.8105664731576033
# Running partition
# PARTITION: Splitting node  3  from  0.5  to  0.625  to  0.75
# PARTITION: New node  5  new edge from  3  to  5
# PARTITION: New node  6  new edge from  3  to  6
# Running subdomain selection
# SELECT: For node  1  best x:  0.10852784320013699  best tead:  0.7665022903172439
# SELECT: For node  4  best x:  0.8043380568039656  best tead:  0.6299274876820723
# SELECT: For node  5  best x:  0.5032908895067186  best tead:  0.5990912281479863
# SELECT: For node  6  best x:  0.7067009357263679  best tead:  0.5992588203481309
# SELECT: Found  1  as best with score  0.7665022903172439
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.658485594958534  and  0.8638488247409122
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.29259535681953674  and  0.35263020393935984
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.7520, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.6454, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.6432, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.6098, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  0.7520058218593076
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  7  new edge from  1  to  7
# PARTITION: New node  8  new edge from  1  to  8
# Running subdomain selection
# SELECT: For node  4  best x:  0.8040459273172549  best tead:  0.644488822309392
# SELECT: For node  5  best x:  0.5051928510856425  best tead:  0.6445892928360499
# SELECT: For node  6  best x:  0.7067135109202549  best tead:  0.6070221174813812
# SELECT: For node  7  best x:  0.14311136638942035  best tead:  0.7980000728471475
# SELECT: For node  8  best x:  0.49873925901970745  best tead:  0.9114890455930744
# SELECT: Found  8  as best with score  0.9114890455930744
# Running local search
# LOCALSEARCH: Running search in node  8
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.42329978750356606  and  0.4233265273359439
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.34966874064443654  and  0.3499175723412449
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  4  tead score:  tensor(0.6518, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.6132, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.5986, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.7388, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.9153, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  8  for split with score  0.9153132649879107
# Running partition
# PARTITION: Splitting node  8  from  0.25  to  0.375  to  0.5
# PARTITION: New node  9  new edge from  8  to  9
# PARTITION: New node  10  new edge from  8  to  10
# Running subdomain selection
# SELECT: For node  4  best x:  0.8041261489569543  best tead:  0.5452557395990253
# SELECT: For node  5  best x:  0.5032970517305918  best tead:  0.4214733100398113
# SELECT: For node  6  best x:  0.7066042184092436  best tead:  0.4853358114062256
# SELECT: For node  7  best x:  0.16573039731093267  best tead:  0.6199030232818648
# SELECT: For node  9  best x:  0.2591395187926249  best tead:  0.46606184247214344
# SELECT: For node  10  best x:  0.4983394430566695  best tead:  0.47422190496207145
# SELECT: Found  7  as best with score  0.6199030232818648
# Running local search
# LOCALSEARCH: Running search in node  7
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.38511256870538635  and  0.791061044994426
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.038583673592868406  and  0.04628902399933632
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  4  tead score:  tensor(0.6747, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.4008, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.5082, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.2575, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.4583, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.3465, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  0.674675712480641
# Running partition
# PARTITION: Splitting node  4  from  0.75  to  0.875  to  1.0
# PARTITION: New node  11  new edge from  4  to  11
# PARTITION: New node  12  new edge from  4  to  12
# Running subdomain selection
# SELECT: For node  5  best x:  0.6204950835425167  best tead:  0.4042062205358584
# SELECT: For node  6  best x:  0.7065690258193904  best tead:  0.5047002602837669
# SELECT: For node  7  best x:  0.000335437256183499  best tead:  0.2548190456741711
# SELECT: For node  9  best x:  0.25863864447574514  best tead:  0.456584164521723
# SELECT: For node  10  best x:  0.4523649815833162  best tead:  0.34709736672240654
# SELECT: For node  11  best x:  0.8160996264862388  best tead:  0.3997471343877486
# SELECT: For node  12  best x:  0.89609038952895  best tead:  0.7112135519345
# SELECT: Found  12  as best with score  0.7112135519345
# Running local search
# LOCALSEARCH: Running search in node  12
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.2678508536120524  and  0.4155395457952411
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  10  new turbo evaluations between  0.24140914191246232  and  0.26148144725464484
# Observed 4 peaks
# Function evaluations to find all peaks: 52
# Time to complete search: 656.7179999999971
#
# Trial  4 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.2799, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.2798767063475713
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.0001843081066540329  best tead:  0.9593009983507399
# SELECT: For node  2  best x:  0.614950660554841  best tead:  1.131204135083767
# SELECT: Found  2  as best with score  1.131204135083767
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.1356373169493153  and  0.3294134111159948
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.5806279251557738  and  0.6719321419225037
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.8919, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.0169, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.0168772463809517
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.4805028714312982  best tead:  1.4240402408577795
# SELECT: For node  3  best x:  0.5053637875625697  best tead:  0.39909182983211605
# SELECT: For node  4  best x:  0.8013012195969736  best tead:  0.5255199633517246
# SELECT: Found  1  as best with score  1.4240402408577795
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5997625773095284  and  0.867513518638449
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.0046474392585517795  and  0.045299753271380756
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.5926, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.5543, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.5349, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  0.5926443703277274
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  5  new edge from  1  to  5
# PARTITION: New node  6  new edge from  1  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.5053438362491962  best tead:  0.5733325008726571
# SELECT: For node  4  best x:  0.8021784796611177  best tead:  0.6614520487273253
# SELECT: For node  5  best x:  0.22808632275030974  best tead:  0.447439010063459
# SELECT: For node  6  best x:  0.26347347415713257  best tead:  0.5821438272722895
# SELECT: Found  4  as best with score  0.6614520487273253
# Running local search
# LOCALSEARCH: Running search in node  4
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.25552888734920187  and  0.5246414573782339
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.23743993750496073  and  0.28677845521552725
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.5786, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.5241, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.1879, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.6978, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  0.6978102472291999
# Running partition
# PARTITION: Splitting node  6  from  0.25  to  0.375  to  0.5
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.5022772893009491  best tead:  0.5389347531522959
# SELECT: For node  4  best x:  0.8396797655640088  best tead:  0.44283961114010106
# SELECT: For node  5  best x:  0.22777014998251632  best tead:  0.17883812804412919
# SELECT: For node  7  best x:  0.3689032358653384  best tead:  0.23153126376693023
# SELECT: For node  8  best x:  0.41544659272492784  best tead:  0.41472125673935745
# SELECT: Found  3  as best with score  0.5389347531522959
# Running local search
# LOCALSEARCH: Running search in node  3
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5900293501520766  and  0.5902905423231476
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.649543976105839  and  0.6554599261582792
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.2730, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.3538, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.2702, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.2292, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.3021, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  0.3538090895602059
# Running partition
# PARTITION: Splitting node  4  from  0.75  to  0.875  to  1.0
# PARTITION: New node  9  new edge from  4  to  9
# PARTITION: New node  10  new edge from  4  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.5024605583045694  best tead:  0.27096860964393565
# SELECT: For node  5  best x:  0.0603773591278304  best tead:  0.27226119027841955
# SELECT: For node  7  best x:  0.3689258201797259  best tead:  0.22918921323117886
# SELECT: For node  8  best x:  0.4522588663942598  best tead:  0.31080244819096153
# SELECT: For node  9  best x:  0.8452735573974309  best tead:  0.24536400711091558
# SELECT: For node  10  best x:  0.9126659324949408  best tead:  0.3258146103131106
# SELECT: Found  10  as best with score  0.3258146103131106
# Running local search
# LOCALSEARCH: Running search in node  10
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.21243221392965111  and  0.43042191457440737
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.1970163743988907  and  0.2744587034556845
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.5194, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.3698, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.1634, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.4054, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.4323, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.4735, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  3  for split with score  0.5194059244697257
# Running partition
# PARTITION: Splitting node  3  from  0.5  to  0.625  to  0.75
# PARTITION: New node  11  new edge from  3  to  11
# PARTITION: New node  12  new edge from  3  to  12
# Running subdomain selection
# SELECT: For node  5  best x:  0.060244972990331866  best tead:  0.41477182896013354
# SELECT: For node  7  best x:  0.3690051224750337  best tead:  0.2481833551802419
# SELECT: For node  8  best x:  0.4518097014365716  best tead:  0.42182691428916647
# SELECT: For node  9  best x:  0.8452126663996535  best tead:  0.685891152532829
# SELECT: For node  10  best x:  0.9439050734979032  best tead:  0.7533450744494432
# SELECT: For node  11  best x:  0.618073809316147  best tead:  0.6113681125209434
# SELECT: For node  12  best x:  0.7497693128344501  best tead:  0.7541035878318867
# SELECT: Found  12  as best with score  0.7541035878318867
# Running local search
# LOCALSEARCH: Running search in node  12
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.29791384373321345  and  0.388476673859413
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.6497785632238686  and  0.650218570299536
# Observed 3 peaks
# Function evaluations to find all peaks: 137
# Time to complete search: 663.2660000000033
#
# Trial  5 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.3587, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.3587426780658207
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.1640876318059772  best tead:  1.185976397306696
# SELECT: For node  2  best x:  0.9275313340641451  best tead:  1.2117884314468836
# SELECT: Found  2  as best with score  1.2117884314468836
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.36089487203245707  and  0.5363217864973854
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.649757467485779  and  0.711966432906502
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.0486, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.0493, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.049301761734595
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.16491255956578554  best tead:  1.0362069590764864
# SELECT: For node  3  best x:  0.6432758572272124  best tead:  0.2565048436772303
# SELECT: For node  4  best x:  0.9194485710678155  best tead:  0.811383013793302
# SELECT: Found  1  as best with score  1.0362069590764864
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.6432817043634449  and  0.8748881108830969
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.2913715283037258  and  0.41225624295185337
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.4942, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(1.4335, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.2167, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.49417355042683
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  5  new edge from  1  to  5
# PARTITION: New node  6  new edge from  1  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.5603801041810588  best tead:  1.4183384287402143
# SELECT: For node  4  best x:  0.8898408848325856  best tead:  1.2204926629701704
# SELECT: For node  5  best x:  0.1376559494236512  best tead:  1.2412673082111458
# SELECT: For node  6  best x:  0.4608771402797465  best tead:  1.5095258644286145
# SELECT: Found  6  as best with score  1.5095258644286145
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.43514483648904323  and  0.529118906524236
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.34972942458699474  and  0.3500858640880419
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(1.0602, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.2193, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(1.2285, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(1.2270, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  5  for split with score  1.2285189054763106
# Running partition
# PARTITION: Splitting node  5  from  0.0  to  0.125  to  0.25
# PARTITION: New node  7  new edge from  5  to  7
# PARTITION: New node  8  new edge from  5  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.5144637546013959  best tead:  1.0628422777512405
# SELECT: For node  4  best x:  0.889542081268662  best tead:  1.21386169960202
# SELECT: For node  6  best x:  0.4531963233715193  best tead:  1.2384495234217083
# SELECT: For node  7  best x:  0.028273824992494374  best tead:  1.201551264860419
# SELECT: For node  8  best x:  0.20467799354801947  best tead:  1.0283029392991108
# SELECT: Found  6  as best with score  1.2384495234217083
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.4905411779049119  and  0.49058216472484417
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.34963768000016937  and  0.3499698138446642
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(1.1699, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.2708, dtype=torch.float64, grad_fn=<MaxBackward1>)
# ...
# PRESELECT: For node  3  tead score:  tensor(1.2043, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.0576, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(1.1170, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(1.1979, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  3  for split with score  1.20428902593919
# Running partition
# PARTITION: Splitting node  3  from  0.0  to  0.125  to  0.25
# PARTITION: New node  7  new edge from  3  to  7
# PARTITION: New node  8  new edge from  3  to  8
# Running subdomain selection
# SELECT: For node  4  best x:  0.4672413396245265  best tead:  1.0964049069763784
# SELECT: For node  5  best x:  0.6085294031612489  best tead:  1.186949913474466
# SELECT: For node  6  best x:  0.8330213704256436  best tead:  1.2302105251528754
# SELECT: For node  7  best x:  0.04523863480558763  best tead:  0.5357911018487175
# SELECT: For node  8  best x:  0.19136969796023592  best tead:  1.1141051594324562
# SELECT: Found  6  as best with score  1.2302105251528754
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.20611704919455062  and  0.5971451328426651
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.18137469682577487  and  0.2578887272250415
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  4  tead score:  tensor(0.1019, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(1.0017, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.9033, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.0677, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.0566, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  5  for split with score  1.0017272548798946
# Running partition
# PARTITION: Splitting node  5  from  0.5  to  0.625  to  0.75
# PARTITION: New node  9  new edge from  5  to  9
# PARTITION: New node  10  new edge from  5  to  10
# Running subdomain selection
# SELECT: For node  4  best x:  0.39135161131740553  best tead:  0.10210228298173243
# SELECT: For node  6  best x:  0.8738482778621469  best tead:  0.9151359999635662
# SELECT: For node  7  best x:  0.04511949911262705  best tead:  0.06765695825168672
# SELECT: For node  8  best x:  0.1945405192463842  best tead:  0.05644956084363134
# SELECT: For node  9  best x:  0.5186035596347355  best tead:  0.6550506133783318
# SELECT: For node  10  best x:  0.7280385863877666  best tead:  0.6210217548305854
# SELECT: Found  6  as best with score  0.9151359999635662
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.20501058985511236  and  0.5978361420061599
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.21548029704982807  and  0.2551033056251185
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  4  tead score:  tensor(0.1019, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.6699, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.0675, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.0587, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.6065, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.6140, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  0.6699358645409654
# Running partition
# PARTITION: Splitting node  6  from  0.75  to  0.875  to  1.0
# PARTITION: New node  11  new edge from  6  to  11
# PARTITION: New node  12  new edge from  6  to  12
# Running subdomain selection
# SELECT: For node  4  best x:  0.39131392441475277  best tead:  0.10187196100364457
# SELECT: For node  7  best x:  0.04522973438652697  best tead:  0.06748133082733088
# SELECT: For node  8  best x:  0.19487187026275807  best tead:  0.0577071406989119
# SELECT: For node  9  best x:  0.5630572341620459  best tead:  0.6075962516371956
# SELECT: For node  10  best x:  0.7283861777929392  best tead:  0.6199869552428218
# SELECT: For node  11  best x:  0.7971910978041653  best tead:  0.4929635506462765
# SELECT: For node  12  best x:  0.882640914837157  best tead:  0.5916761795519697
# SELECT: Found  10  as best with score  0.6199869552428218
# Running local search
# LOCALSEARCH: Running search in node  10
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.1569563136835946  and  0.4062950187481719
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.6490582660592686  and  0.6570433820418607
# Observed 3 peaks
# Function evaluations to find all peaks: 141
# Time to complete search: 648.5469999999987
#
# Trial 15 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.3108, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.3107646423552293
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.4596978000859915  best tead:  0.9149276043511666
# SELECT: For node  2  best x:  0.9280046437196069  best tead:  1.2629939666593288
# SELECT: Found  2  as best with score  1.2629939666593288
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.08072347778214713  and  0.45380769375101354
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  4.8970542964484985e-05  and  0.1429498477591445
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.1685, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.2645, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.2644857417003277
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.35806231223438045  best tead:  1.2428938074481084
# SELECT: For node  3  best x:  0.5952637187915407  best tead:  1.437517569385481
# SELECT: For node  4  best x:  0.9167841930953097  best tead:  1.077378183367287
# SELECT: Found  3  as best with score  1.437517569385481
# Running local search
# LOCALSEARCH: Running search in node  3
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5187060075827847  and  0.5757851066426787
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.6311018734624688  and  0.6747611870443527
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.2521, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.9359, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.1604, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.2520750360676345
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  5  new edge from  1  to  5
# PARTITION: New node  6  new edge from  1  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.749603384615265  best tead:  0.9381016659623616
# SELECT: For node  4  best x:  0.9165129679293934  best tead:  1.1542105081352843
# SELECT: For node  5  best x:  0.19357286832660636  best tead:  0.45810731033500274
# SELECT: For node  6  best x:  0.4749089152508186  best tead:  0.9462673660410924
# SELECT: Found  4  as best with score  1.1542105081352843
# Running local search
# LOCALSEARCH: Running search in node  4
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.15165084994073966  and  0.6924033804650915
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.005403482332611482  and  0.152532868298255
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.9566, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.0793, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.4676, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.8554, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  1.0793418763661715
# Running partition
# PARTITION: Splitting node  4  from  0.75  to  0.875  to  1.0
# PARTITION: New node  7  new edge from  4  to  7
# PARTITION: New node  8  new edge from  4  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.7495873456569399  best tead:  0.9821692499467861
# SELECT: For node  5  best x:  0.19357704446504406  best tead:  0.47881604931089905
# SELECT: For node  6  best x:  0.47484799972822567  best tead:  0.8695008838502873
# SELECT: For node  7  best x:  0.8032557250872455  best tead:  0.7091981251979247
# SELECT: For node  8  best x:  0.8944453036848726  best tead:  1.034639382187651
# SELECT: Found  8  as best with score  1.034639382187651
# Running local search
# LOCALSEARCH: Running search in node  8
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.3971806970091223  and  0.434519272802621
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  10  new turbo evaluations between  0.9162348605975252  and  0.9261856613963586
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.4936, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.2753, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.5160, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.2592, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.5155, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  0.5159939620584978
# Running partition
# PARTITION: Splitting node  6  from  0.25  to  0.375  to  0.5
# PARTITION: New node  9  new edge from  6  to  9
# PARTITION: New node  10  new edge from  6  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.5076588787882194  best tead:  0.4624816076111824
# SELECT: For node  5  best x:  0.18688459032299562  best tead:  0.2739010061478424
# SELECT: For node  7  best x:  0.7501067754129421  best tead:  0.2619764971333235
# SELECT: For node  8  best x:  0.9179600127864792  best tead:  0.5146594308558242
# SELECT: For node  9  best x:  0.3420073288995231  best tead:  0.7494937277866995
# SELECT: For node  10  best x:  0.4750966289980156  best tead:  0.42686936243345897
# SELECT: Found  9  as best with score  0.7494937277866995
# Running local search
# LOCALSEARCH: Running search in node  9
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5871304573450495  and  0.8385942159305616
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.3318022642233213  and  0.35762963629162775
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.4120, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.2742, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.2651, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.5041, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.4890, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.2228, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  8  for split with score  0.5040902766646383
# Running partition
# PARTITION: Splitting node  8  from  0.875  to  0.9375  to  1.0
# PARTITION: New node  11  new edge from  8  to  11
# PARTITION: New node  12  new edge from  8  to  12
# Running subdomain selection
# SELECT: For node  3  best x:  0.7493372066594022  best tead:  0.43440956718829
# SELECT: For node  5  best x:  0.1870389670395148  best tead:  0.27986425606096843
# SELECT: For node  7  best x:  0.7500005300291267  best tead:  0.26997604419980614
# SELECT: For node  9  best x:  0.3540684602003917  best tead:  0.5448992594578571
# SELECT: For node  10  best x:  0.47514829333489433  best tead:  0.2344530287748003
# SELECT: For node  11  best x:  0.9306323357991725  best tead:  0.477029326533573
# SELECT: For node  12  best x:  0.9576683596349224  best tead:  0.36368914301457045
# SELECT: Found  9  as best with score  0.5448992594578571
# Running local search
# LOCALSEARCH: Running search in node  9
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5811548757093038  and  0.9514078363729334
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.3420893032634435  and  0.358833498310511
# Observed 4 peaks
# Function evaluations to find all peaks: 82
# Time to complete search: 654.4209999999985

# %%
# calculate summary metrics
# peak ratio
num_known_peaks = 4
# n_replications = 15
peak_ratio = sum(distinct_peaks) / (num_known_peaks * n_replications)
print("Peak ratio: {}".format(peak_ratio))
# success rate
num_successes = 0
for i in range(n_replications):
    if distinct_peaks[i] == 4:
        num_successes += 1
success_ratio = num_successes / n_replications
print("Success ratio: {}".format(success_ratio))
print("Average function evaluations: {}".format(sum(function_evaluations)/n_replications))
# Out:
# Peak ratio: 0.9333333333333333
# Success ratio: 0.7333333333333333
# Average function evaluations: 81.0
