# %%
# notebook for first canonical problem for multimodal optimization looking for localized extreme
# events with agent-based military simulation
# Experiment 2.2 - Stochastic, jump discontinuity multimodal localized extrema test problem
# Part 2 - Balanced strategy approach (PIONEER)
#
# Author: Alex Braafladt
# Initial creation: 3/10/23
#
# Goal: Benchmark state-of-the-art Bayesian Optimization approaches (and QMC/MCS) on a multimodal
#       optimization test function focused on localized extrema
#
# Notes:
# -Using the BoTorch framework [1] and NEI from [4]
# -TEAD technique from [2]
# -TuRBO technique from [3]
#
# References:
# [1] M. Balandat et al., “BOTORCH: A framework for efficient Monte-Carlo Bayesian optimization,”
#     Adv. Neural Inf. Process. Syst., vol. 2020-Decem, no. MC, 2020.
# [2] S. Mo et al., “A Taylor Expansion-Based Adaptive Design Strategy for Global Surrogate
#     Modeling With Applications in Groundwater Modeling,” Water Resour. Res., vol. 53, no.
#     12, pp. 10802–10823, 2017, doi: 10.1002/2017WR021622.
# [3] D. Eriksson, M. Pearce, J. R. Gardner, R. Turner, and M. Poloczek, “Scalable global
#     optimization via local Bayesian optimization,” Adv. Neural Inf. Process. Syst., vol.
#     32, no. NeurIPS, 2019.
# [4] B. Letham, B. Karrer, G. Ottoni, and E. Bakshy, “Constrained Bayesian optimization with noisy
#     experiments,” Bayesian Anal., vol. 14, no. 2, pp. 495–519, 2019, doi: 10.1214/18-BA1110.

# %%
# imports
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from extremasearch.globalmm.globalsearch import MultimodalExtremaSearch
from botorch import fit_gpytorch_mll
from botorch.models.gp_regression import SingleTaskGP
from gpytorch.mlls import ExactMarginalLogLikelihood
import numpy as np
import networkx as nx
from botorch.models.transforms import Normalize, Standardize
import time


# setup
dtype = torch.double
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import warnings
from botorch.exceptions import BadInitialCandidatesWarning
warnings.filterwarnings('ignore', category=BadInitialCandidatesWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# %%
# setup file i/o
import os as os
import datetime as dt
# get current working directory
wrkdir = os.getcwd()
print('Current working directory: '+wrkdir)
# set up a data save directory for all future runs
newoutputdir = wrkdir+'\output'
if not os.path.exists(newoutputdir):
    os.makedirs(newoutputdir)
# set up a new directory to store files for the current run - updates at each new full run of notebook
curDatetime = dt.datetime.now()
datasavedir = newoutputdir + r'\\' + 'exp2.2_balanced_mme_noisyjump' + str(curDatetime.strftime('%Y%m%d%H%M%S'))
if not os.path.exists(datasavedir):
    os.makedirs(datasavedir)
print('Data save directory: '+datasavedir)
# Out:
# Current working directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks\iter4_exp2
# Data save directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks\iter4_exp2\output\\exp2.2_balanced_mme_noisyjump20230310211026

# %%
# canonical problem
def mme_noise_jump_1d_mean(x):
    y = torch.zeros(x.shape)
    y += 0.66*(-1.*x + 0.1*torch.sin(30.*x) + torch.exp(-(100.*(x-0.65))**2.)) * (x >= 0.6)
    y += 0.66*(-1.*x + 0.1*torch.sin(30.*x) - 0.25 + torch.exp(-(100.*(x-0.65))**2.)) * (x < 0.6) * (x >= 0.2)
    y += 0.66*(-1.*x + 0.1*torch.sin(30.*x) + 0.2 + torch.exp(-(100.*(x-0.65))**2.)) * (x < 0.2)
    y += 0.7 * ( torch.exp(-(100.*(x-0.35))**2.) )
    y += 0.4 * ( torch.exp(-(100.*(x-0.92))**2.) )
    y += 0.9
    return y


sigma_max = 0.12
sigma_min = 0.02


def mme_noise_jump_1d(x):
    # mean
    y = mme_noise_jump_1d_mean(x)
    # noise
    noise = torch.zeros(x.shape)
    noise += (torch.randn(x.shape) * sigma_max) * (x >= 0.61) * (x < 0.71)
    noise += (torch.randn(x.shape) * 0.5*sigma_max) * (x >= 0.31) * (x < 0.41)
    noise += (torch.randn(x.shape) * 0.8*sigma_max) * (x >= 0.90) * (x < 0.94)
    noise += (torch.randn(x.shape) * (sigma_max - sigma_min) / (1. + torch.exp(-10.*(x-0.2))) )* (x < 0.61)
    noise += (torch.randn(x.shape) * (sigma_max - sigma_min) / (1. + torch.exp(10.*(x-0.75))) ) * (x >= 0.71)
    # combined
    y_out = y + noise
    # any_neg = y_out < 0
    # if any_neg:
    #     y_out = torch.tensor(0.0)
    return y_out


x1 = torch.linspace(0,1.0,200)
y1 = mme_noise_jump_1d(x1)
fig, ax = plt.subplots(1, 1, figsize=(8,6))
sns.lineplot(x=x1, y=y1, ax=ax, color='r')
plt.savefig(datasavedir + '/'+'full_test_problem_one_realization'+'.png')

# %%
# plot noise bounds as 99% confidence interval
# generate realizations of the function
num_reals = 500
num_x = 200
x1 = torch.linspace(0,1.0,num_x)
y_reps = torch.DoubleTensor(num_x, num_reals)
y_deter = mme_noise_jump_1d_mean(x1)
for i in range(num_reals):
    y_reps[:,i] = mme_noise_jump_1d(x1)

fig, ax = plt.subplots(1, 1, figsize=(8,6))
sns.lineplot(x=x1, y=y_deter, ax=ax)
upper_99 = torch.quantile(y_reps, 0.995, dim=1)
lower_01 = torch.quantile(y_reps, 0.005, dim=1)
ax.fill_between(x1, lower_01, upper_99, color='b', alpha=0.3, label=r'99% quantiles')
plt.savefig(datasavedir + '/'+'full_test_problem_bounds'+'.png')

# %%
def outcome_objective(x):
    """wrapper for the outcome objective function"""
    # return mme_torch(X).type_as(X)
    return mme_noise_jump_1d(x).type_as(x)

# %%
# functions for getting and working with data from searches
def get_bounds(graph):
    """Get the bounds for each node in a graph to be able to plot them"""
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    bound_list = []
    node_list = []
    for n in graph_leaves:
        # get current leaf node
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_bounds = current_state.local_bounds
        node_list.append(n)
        bound_list.append(current_bounds)
    return node_list, bound_list


def get_bounds_all(graph):
    """Get the bounds for each node in a graph to be able to plot them"""
    graph_nodes = [n for n in graph]
    bound_list = []
    node_list = []
    for n in graph_nodes:
        # get current node
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_bounds = current_state.local_bounds
        node_list.append(n)
        bound_list.append(current_bounds)
    return node_list, bound_list


def fit_local_models(graph):
    """Go through leaf nodes and update LocalSearchState to have local {x, y}
    based on global {x, y} that are within bounds"""
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    for n in graph_leaves:
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_state.local_model = SingleTaskGP(current_state.x_local, current_state.y_local,
                                                 input_transform=Normalize(d=current_state.x_local.shape[-1]),
                                                 outcome_transform=Standardize(m=current_state.y_local.shape[-1]))
        current_state.local_mll = ExactMarginalLogLikelihood(current_state.local_model.likelihood,
                                                             current_state.local_model)
        fit_gpytorch_mll(current_state.local_mll)


def plot_local_models_1d(graph, x_search, y_search, rep):
    """Go through leaf nodes and plot the local models only within the bounds of the node"""
    fit_local_models(graph)
    nodes, bnds = get_bounds(graph)
    x_test = torch.linspace(0, 1, 400)
    f, ax = plt.subplots(1, 1, figsize=(8, 6))
    # true objective
    sns.lineplot(x=x1, y=y_deter, ax=ax, color='r')
    upper_99 = torch.quantile(y_reps, 0.995, dim=1)
    lower_01 = torch.quantile(y_reps, 0.005, dim=1)
    ax.fill_between(x1, lower_01, upper_99, color='r', alpha=0.3, label=r'99% quantiles')
    # local models
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    for n in graph_leaves:
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_model = current_state.local_model
        current_bounds = current_state.local_bounds
        current_x_test_mask = torch.ge(x_test, current_bounds[0]) & torch.lt(x_test, current_bounds[1])
        current_x_test = x_test[current_x_test_mask]
        mean_test = current_model.posterior(current_x_test.unsqueeze(-1)).mean.detach().numpy()
        ax.plot(current_x_test.numpy(), mean_test, 'b-', alpha=0.9, label='surrogate mean')
        var_test = current_model.posterior(current_x_test.unsqueeze(-1)).variance.detach().numpy()
        sd_test = np.sqrt(var_test)
        upper_test = mean_test + 2.0 * sd_test
        lower_test = mean_test - 2.0 * sd_test
        ax.fill_between(current_x_test.numpy(), lower_test.squeeze(), upper_test.squeeze(), color='b', alpha=0.3,
                        label=r'surrogate 2$\sigma$')
    # training points
    ax.plot(x_search.numpy()[0:10], y_search[0:10].numpy(), '.', color='tab:orange', label='initial data')
    ax.plot(x_search.numpy()[10:], y_search[10:].numpy(), '.', color='g', label='bo data')
    # partitions
    for n, b in zip(nodes, bnds):
        ax.plot([b[0].numpy(), b[0].numpy()], [-0.05, 1.45], 'k-')
    # ax.legend()
    # ax.set_ylim([-0.02, 1.02])
    ax.set_title('PIONEER_rep{}'.format(rep))
    # ax.set_xlim([0.915, 0.925])
    plt.savefig(datasavedir + '/'+'1d_results_local_models_rep{}'.format(rep)+'.png')


def plot_current_tree(global_search: MultimodalExtremaSearch, rep):
    """Save a plot of the tree structure after the search"""
    # tree figure
    T = global_search.global_state.partition_graph
    pos = nx.nx_agraph.graphviz_layout(T, prog="dot")
    # bounds to put on nodes on plot
    all_nodes, all_bounds = get_bounds_all(global_search.global_state.partition_graph)
    # positioning of bound text
    pos_attrs = {}
    for node, coords in pos.items():
        pos_attrs[node] = (coords[0]-15, coords[1])
    custom_node_attrs = {}
    for node, attrs in zip(all_nodes, all_bounds):
        custom_node_attrs[node] = str(attrs.numpy().round(decimals=3))
    # plot commands
    f, ax = plt.subplots(1, 1, figsize=(12, 8), constrained_layout=True)
    nx.draw(T, pos, with_labels=True, font_weight='bold', ax=ax)
    nx.draw_networkx_labels(T, pos_attrs, labels=custom_node_attrs, ax=ax)
    ax.set_title('PIONEER Partition Tree')
    plt.savefig(datasavedir + '/'+'partition_tree_rep{}'.format(rep)+'.png')

# %%
# metrics functions
def count_number_peaks_observed(x_obs, y_obs, num_known_peaks=4):
    """Function to count the number of peaks observed for the mme_noise_jump_1d function"""
    peak1, peak2, peak3, peak4 = False, False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.03 <= x <= 0.07:
            if y >= 1.065:
                peak1 = True
        elif 0.345 <= x <= 0.355:
            if y >= 1.12:
                peak2 = True
        elif 0.645 <= x <= 0.655:
            if y >= 1.145:
                peak3 = True
        elif 0.915 <= x <= 0.925:
            if y >= 0.734:
                peak4 = True
    num_peaks_observed = peak1 + peak2 + peak3 + peak4
    return num_peaks_observed


def count_evaluations_for_all_peaks(x_obs, y_obs):
    """Count the number of function evaluations before finding all peaks"""
    i = 0
    num_evals_for_all_peaks = x_obs.shape[0]
    peak1, peak2, peak3, peak4 = False, False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.03 <= x <= 0.07:
            if y >= 1.065:
                peak1 = True
        elif 0.345 <= x <= 0.355:
            if y >= 1.12:
                peak2 = True
        elif 0.645 <= x <= 0.655:
            if y >= 1.145:
                peak3 = True
        elif 0.915 <= x <= 0.925:
            if y >= 0.734:
                peak4 = True
        i += 1
        if peak1 and peak2 and peak3 and peak4:
            num_evals_for_all_peaks = i
            break
    return num_evals_for_all_peaks

# %%
# replicated searches

# search and experiment settings
n_replications = 15
global_bounds = torch.tensor([0.0, 1.0], dtype=dtype)
n_evals = 130

# data holders
x_observed_all = []
y_observed_all = []
distinct_peaks = []
function_evaluations = []

# experiment loop
for rep in range(1, n_replications + 1):
    print(f"\nTrial {rep:>2} of {n_replications} ", end="")
    t0 = time.monotonic()
    # initialize search
    current_global_search = MultimodalExtremaSearch(60,global_bounds,outcome_objective,total_iteration_limit=n_evals)
    # run search
    current_global_search.run_global_search()

    # collect data
    x_observed_all.append(current_global_search.global_state.x_global)
    y_observed_all.append(current_global_search.global_state.y_global)

    # run and save plots
    # results with local model
    plot_local_models_1d(current_global_search.global_state.partition_graph,
                         current_global_search.global_state.x_global,
                         current_global_search.global_state.y_global,
                         rep)
    # partitioning results tree
    plot_current_tree(current_global_search, rep)

    # calculate metrics
    num_peaks_observed = count_number_peaks_observed(current_global_search.global_state.x_global,
                                                     current_global_search.global_state.y_global)
    print("Observed {num:} peaks".format(num=num_peaks_observed),)
    distinct_peaks.append(num_peaks_observed)
    fe = count_evaluations_for_all_peaks(current_global_search.global_state.x_global,
                                         current_global_search.global_state.y_global)
    print("Function evaluations to find all peaks: {}".format(fe))
    function_evaluations.append(fe)
    # time for search
    t1 = time.monotonic()
    print("Time to complete search: {}".format(t1-t0))
# Out:
# Trial  1 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.5176, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.5175782189411424
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.1448041960758096  best tead:  0.9601090018529512
# SELECT: For node  2  best x:  0.9827585893589175  best tead:  1.239811028253773
# SELECT: Found  2  as best with score  1.239811028253773
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.0819682219727239  and  0.4302276982936986
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.010020801162333535  and  0.07222288117839902
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.1919, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.2578, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.2578422776665321
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.4996477351428652  best tead:  1.232507114990923
# SELECT: For node  3  best x:  0.6480221472451917  best tead:  0.8527622477200008
# SELECT: For node  4  best x:  0.8465225865388906  best tead:  1.215237473110879
# SELECT: Found  1  as best with score  1.232507114990923
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.3383724436152446  and  0.33888107827720376
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.00032758527192199965  and  0.06946402986262992
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.2169, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(1.0539, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.1957, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.2169309215341089
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  5  new edge from  1  to  5
# PARTITION: New node  6  new edge from  1  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.6478513965471788  best tead:  1.0614301170233418
# SELECT: For node  4  best x:  0.7989189796719073  best tead:  1.2034545111488626
# SELECT: For node  5  best x:  0.12226266227562847  best tead:  0.951837049136538
# SELECT: For node  6  best x:  0.40278947714185653  best tead:  0.7482534233171529
# SELECT: Found  4  as best with score  1.2034545111488626
# Running local search
# LOCALSEARCH: Running search in node  4
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.31666142335167313  and  0.33580750147674526
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.3213513875599235  and  0.3670503526446625
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.8653, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.9334, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.8499, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.7776, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  0.9333586562234244
# Running partition
# PARTITION: Splitting node  4  from  0.75  to  0.875  to  1.0
# PARTITION: New node  7  new edge from  4  to  7
# PARTITION: New node  8  new edge from  4  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.70447759209161  best tead:  0.8753898232808872
# SELECT: For node  5  best x:  0.2325908066539377  best tead:  0.8462215858482321
# SELECT: For node  6  best x:  0.2501268767964912  best tead:  0.7879494187052513
# SELECT: For node  7  best x:  0.8583252121403436  best tead:  0.5495315112329919
# SELECT: For node  8  best x:  0.8819187707482785  best tead:  0.8464844285841866
# SELECT: Found  3  as best with score  0.8753898232808872
# Running local search
# LOCALSEARCH: Running search in node  3
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.2754463163259646  and  0.609171158873953
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.4737516078322688  and  0.5206363778717378
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.5864, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.6731, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.4610, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.5452, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.7753, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  8  for split with score  0.7753221406821216
# Running partition
# PARTITION: Splitting node  8  from  0.875  to  0.9375  to  1.0
# PARTITION: New node  9  new edge from  8  to  9
# PARTITION: New node  10  new edge from  8  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.6933978629297507  best tead:  0.5889544945227099
# SELECT: For node  5  best x:  0.16213914571741198  best tead:  0.6788623231516774
# SELECT: For node  6  best x:  0.3765902799170175  best tead:  0.4740238733895683
# SELECT: For node  7  best x:  0.8580255434740696  best tead:  0.5354642729400232
# SELECT: For node  9  best x:  0.9247539347741766  best tead:  0.6349921218142078
# SELECT: For node  10  best x:  0.957731352795172  best tead:  0.7166504328025365
# SELECT: Found  10  as best with score  0.7166504328025365
# Running local search
# LOCALSEARCH: Running search in node  10
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.16552330885322747  and  0.470490315051026
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.15150604902017378  and  0.1638117853290912
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.4660, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.2855, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.5352, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.5408, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.5801, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.6445, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  10  for split with score  0.6444996309517861
# Running partition
# PARTITION: Splitting node  10  from  0.9375  to  0.96875  to  1.0
# PARTITION: New node  11  new edge from  10  to  11
# PARTITION: New node  12  new edge from  10  to  12
# Running subdomain selection
# SELECT: For node  3  best x:  0.6401157003451257  best tead:  0.47114279694360073
# SELECT: For node  5  best x:  0.19367729362175543  best tead:  0.28901754059159607
# SELECT: For node  6  best x:  0.3791327734468036  best tead:  0.5510728269532527
# SELECT: For node  7  best x:  0.8582294788649845  best tead:  0.5387625222109053
# SELECT: For node  9  best x:  0.9163274209959995  best tead:  0.5810813133405506
# SELECT: For node  11  best x:  0.9687223428967816  best tead:  0.7226528317212149
# SELECT: For node  12  best x:  0.9701341069591836  best tead:  0.5314474781553226
# SELECT: Found  11  as best with score  0.7226528317212149
# Running local search
# LOCALSEARCH: Running search in node  11
#
# TuRBO restart triggered
# tead
# LOCALSEARCH: Completed  1  new tead evaluations between  0.49313280792297054  and  0.49313280792297054
#
# TuRBO restart triggered
# turbo
# LOCALSEARCH: Completed  1  new turbo evaluations between  0.5140481671816223  and  0.5140481671816223
# Fitting global model
# Exploring full space
# Observed 4 peaks
# Function evaluations to find all peaks: 105
# Time to complete search: 429.1399999999994
#
# Trial  2 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.1540, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.1539832965856938
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.09059521612953975  best tead:  0.8770483920510611
# SELECT: For node  2  best x:  0.7586503854933035  best tead:  1.1742129605195566
# SELECT: Found  2  as best with score  1.1742129605195566
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.08108926365836062  and  0.24459624468513771
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.5852545336083057  and  0.6733928849416333
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.0119, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.1093, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.1093112130887293
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.4224693599840831  best tead:  1.0329193679107223
# SELECT: For node  3  best x:  0.7423685490506426  best tead:  0.8735729700057093
# SELECT: For node  4  best x:  0.9112887195498086  best tead:  1.3235698005328052
# SELECT: Found  4  as best with score  1.3235698005328052
# Running local search
# LOCALSEARCH: Running search in node  4
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.2679011487285244  and  0.3354807585733318
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.23600386114554578  and  0.293406475416814
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.9440, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.7076, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.0739, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  1.073901960029719
# Running partition
# PARTITION: Splitting node  4  from  0.75  to  0.875  to  1.0
# PARTITION: New node  5  new edge from  4  to  5
# PARTITION: New node  6  new edge from  4  to  6
# Running subdomain selection
# SELECT: For node  1  best x:  0.14819096549899202  best tead:  0.9880793697535433
# SELECT: For node  3  best x:  0.5035050872042186  best tead:  0.7714142437352112
# SELECT: For node  5  best x:  0.8066802545938933  best tead:  0.669867838562413
# SELECT: For node  6  best x:  0.916109470924744  best tead:  1.0835396209872155
# SELECT: Found  6  as best with score  1.0835396209872155
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.40359013057593895  and  0.44282944678384717
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.9128071013480573  and  0.9269713692708089
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.5535, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.4470, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.2726, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.5498, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  0.5535364983766401
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  7  new edge from  1  to  7
# PARTITION: New node  8  new edge from  1  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.7420862003987201  best tead:  0.4287355176165315
# SELECT: For node  5  best x:  0.812937103205072  best tead:  0.26144669163467665
# SELECT: For node  6  best x:  0.8827833289805016  best tead:  0.5097438737372694
# SELECT: For node  7  best x:  0.10044347350272023  best tead:  0.356605637171086
# SELECT: For node  8  best x:  0.42371206728362637  best tead:  0.7732361433086876
# SELECT: Found  8  as best with score  0.7732361433086876
# Running local search
# LOCALSEARCH: Running search in node  8
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.45675771228995743  and  0.5376400188877773
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.3445371113628206  and  0.3538795675993023
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.4595, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.2775, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.5225, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.3406, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.4518, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  0.5224566728655891
# Running partition
# PARTITION: Splitting node  6  from  0.875  to  0.9375  to  1.0
# PARTITION: New node  9  new edge from  6  to  9
# PARTITION: New node  10  new edge from  6  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.742293485174926  best tead:  0.5105006330223957
# SELECT: For node  5  best x:  0.8127560323649878  best tead:  0.3125076192020342
# SELECT: For node  7  best x:  0.10072640178892968  best tead:  0.3483273647501251
# SELECT: For node  8  best x:  0.4234528288664349  best tead:  0.4771482559601703
# SELECT: For node  9  best x:  0.9286566034603326  best tead:  0.265002706171852
# SELECT: For node  10  best x:  0.9917469564816869  best tead:  0.37278671108765615
# SELECT: Found  3  as best with score  0.5105006330223957
# Running local search
# LOCALSEARCH: Running search in node  3
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.18115266158258747  and  0.3913503897961971
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.6477102335038143  and  0.6555173858495909
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.4726, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.3157, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.3884, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.4308, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.2904, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.4011, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  3  for split with score  0.4726216952619964
# Running partition
# PARTITION: Splitting node  3  from  0.5  to  0.625  to  0.75
# PARTITION: New node  11  new edge from  3  to  11
# PARTITION: New node  12  new edge from  3  to  12
# Running subdomain selection
# SELECT: For node  5  best x:  0.8642911352300587  best tead:  0.2755128478646941
# SELECT: For node  7  best x:  0.10084004630744911  best tead:  0.3865633610204548
# SELECT: For node  8  best x:  0.4672321351316786  best tead:  0.38875392978739665
# SELECT: For node  9  best x:  0.9353987177328895  best tead:  0.2388333394564328
# SELECT: For node  10  best x:  0.9919676210281401  best tead:  0.34905300762877733
# SELECT: For node  11  best x:  0.5717274310609238  best tead:  0.4379203927504667
# SELECT: For node  12  best x:  0.6505665321881989  best tead:  0.5045702258295662
# SELECT: Found  12  as best with score  0.5045702258295662
# Running local search
# LOCALSEARCH: Running search in node  12
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.3057268586306518  and  0.3689361769158029
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.6399198597054709  and  0.6491927425804096
# Observed 4 peaks
# Function evaluations to find all peaks: 82
# Time to complete search: 452.92200000000594
#
# Trial  3 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.4179, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.4178895265769031
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.27244694823031845  best tead:  0.6831295127841345
# SELECT: For node  2  best x:  0.9570704272994065  best tead:  1.3785555854484772
# SELECT: Found  2  as best with score  1.3785555854484772
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.20075095459383588  and  0.5152564700474368
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.6025504575064767  and  0.6787004259368766
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.9986, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.2194, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.2194408949836044
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.2346335529942189  best tead:  1.0204585266015358
# SELECT: For node  3  best x:  0.5301321640588867  best tead:  1.0222936307414623
# SELECT: For node  4  best x:  0.7929387778102739  best tead:  1.5322801466831875
# SELECT: Found  4  as best with score  1.5322801466831875
# Running local search
# LOCALSEARCH: Running search in node  4
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5706101954067014  and  0.756978405035972
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.9031012424211853  and  0.947070441482579
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.6549, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.6989, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.6392, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  3  for split with score  0.6988645707636755
# Running partition
# PARTITION: Splitting node  3  from  0.5  to  0.625  to  0.75
# PARTITION: New node  5  new edge from  3  to  5
# PARTITION: New node  6  new edge from  3  to  6
# Running subdomain selection
# SELECT: For node  1  best x:  0.38038542309637663  best tead:  0.6151356829817821
# SELECT: For node  4  best x:  0.8523273765636945  best tead:  0.5881356330511521
# SELECT: For node  5  best x:  0.5002669636399221  best tead:  0.5726164488060147
# SELECT: For node  6  best x:  0.7038185791353686  best tead:  0.5592537152374646
# SELECT: Found  1  as best with score  0.6151356829817821
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.6365106533792638  and  0.8769692239052235
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.0035715550999372153  and  0.07839808283608694
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.5338, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.5432, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.5224, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.5059, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  0.5431825503876425
# Running partition
# PARTITION: Splitting node  4  from  0.75  to  0.875  to  1.0
# PARTITION: New node  7  new edge from  4  to  7
# PARTITION: New node  8  new edge from  4  to  8
# Running subdomain selection
# SELECT: For node  1  best x:  0.3252958416264166  best tead:  0.514034610024239
# SELECT: For node  5  best x:  0.6214136568919414  best tead:  0.48617815306570245
# SELECT: For node  6  best x:  0.6477501407645632  best tead:  0.46229109025889986
# SELECT: For node  7  best x:  0.8660132859916625  best tead:  0.1719941840223223
# SELECT: For node  8  best x:  0.9134730425530939  best tead:  0.5016035678566843
# SELECT: Found  1  as best with score  0.514034610024239
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.49746868336632416  and  0.6147494271029013
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.0070445096004038005  and  0.07291057003896971
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.7796, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.4984, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.5071, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.2592, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.4639, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  0.7796212752688283
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  9  new edge from  1  to  9
# PARTITION: New node  10  new edge from  1  to  10
# Running subdomain selection
# SELECT: For node  5  best x:  0.588848816285764  best tead:  0.6686130395642881
# SELECT: For node  6  best x:  0.6944709153963142  best tead:  0.5916997888906769
# SELECT: For node  7  best x:  0.8669351540761355  best tead:  0.3358403972182517
# SELECT: For node  8  best x:  0.9888916119559404  best tead:  0.5843060205750934
# SELECT: For node  9  best x:  0.11531337838919907  best tead:  0.25381501979868654
# SELECT: For node  10  best x:  0.296444520182328  best tead:  0.7128220976907046
# SELECT: Found  10  as best with score  0.7128220976907046
# Running local search
# LOCALSEARCH: Running search in node  10
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.29137351637562386  and  0.29154783576982646
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.34016771406054225  and  0.37051061704873767
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  5  tead score:  tensor(0.9801, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(1.0181, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.6235, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.5877, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.2499, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.7623, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  1.0180661081560414
# Running partition
# PARTITION: Splitting node  6  from  0.625  to  0.6875  to  0.75
# PARTITION: New node  11  new edge from  6  to  11
# PARTITION: New node  12  new edge from  6  to  12
# Running subdomain selection
# SELECT: For node  5  best x:  0.5957096431468604  best tead:  1.0560255921042574
# SELECT: For node  7  best x:  0.8123128052202615  best tead:  0.6369018012199221
# SELECT: For node  8  best x:  0.988622064385607  best tead:  0.621619989967217
# SELECT: For node  9  best x:  0.1154875133363071  best tead:  0.25242406130647804
# SELECT: For node  10  best x:  0.46309453914048215  best tead:  0.7961785747479341
# SELECT: For node  11  best x:  0.6479581846708222  best tead:  1.0074261074256519
# SELECT: For node  12  best x:  0.6877489005238971  best tead:  0.3212380224643203
# SELECT: Found  5  as best with score  1.0560255921042574
# Running local search
# LOCALSEARCH: Running search in node  5
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.7114250316051807  and  0.7652045656139113
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  9  new turbo evaluations between  0.5988483142605673  and  0.6213737780376959
# Observed 4 peaks
# Function evaluations to find all peaks: 113
# Time to complete search: 477.32799999999406
#
# Trial  4 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.2366, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.236581103690673
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.48803628118257575  best tead:  0.9200791608314358
# SELECT: For node  2  best x:  0.9045543901043591  best tead:  1.5478394559040116
# SELECT: Found  2  as best with score  1.5478394559040116
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.1357807756393049  and  0.347164480685655
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.28481110718047986  and  0.3620686891669668
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.0993, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.1548, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.1547643060605708
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.4885978331660827  best tead:  1.352649381553882
# SELECT: For node  3  best x:  0.6897163223708674  best tead:  1.5381084037201893
# SELECT: For node  4  best x:  0.9277475732814747  best tead:  1.1514134804344134
# SELECT: Found  3  as best with score  1.5381084037201893
# Running local search
# LOCALSEARCH: Running search in node  3
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.6669926149315275  and  0.7718599994730783
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.6260284188571781  and  0.6845133365965843
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.7218, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.6624, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.0330, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  1.0330033876352964
# Running partition
# PARTITION: Splitting node  4  from  0.75  to  0.875  to  1.0
# PARTITION: New node  5  new edge from  4  to  5
# PARTITION: New node  6  new edge from  4  to  6
# Running subdomain selection
# SELECT: For node  1  best x:  0.2429292286665953  best tead:  0.7191226281498765
# SELECT: For node  3  best x:  0.7118073162442621  best tead:  0.6522694631434756
# SELECT: For node  5  best x:  0.8231075210617106  best tead:  0.5738601221121995
# SELECT: For node  6  best x:  0.9524991217137774  best tead:  1.039569430064147
# SELECT: Found  6  as best with score  1.039569430064147
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.38958860712925253  and  0.4089009540600798
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.9043949225340705  and  0.9223366120311632
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.4839, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.4312, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.1386, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.5017, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  0.5016725603791172
# Running partition
# PARTITION: Splitting node  6  from  0.875  to  0.9375  to  1.0
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  1  best x:  0.43434104475455493  best tead:  0.4441264199511291
# SELECT: For node  3  best x:  0.5779292372093706  best tead:  0.3995938762263914
# SELECT: For node  5  best x:  0.7545395766744036  best tead:  0.11912105423270894
# SELECT: For node  7  best x:  0.9256839681627897  best tead:  0.5193025376861545
# SELECT: For node  8  best x:  0.9608048983570544  best tead:  0.3189927327434253
# SELECT: Found  7  as best with score  0.5193025376861545
# Running local search
# LOCALSEARCH: Running search in node  7
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.9106499068077983  and  0.9111176418833363
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  3  new turbo evaluations between  0.9172325014549508  and  0.9200145827087775
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.6123, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.6220, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.2402, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.2599, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.1614, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  3  for split with score  0.6220224951697761
# Running partition
# PARTITION: Splitting node  3  from  0.5  to  0.625  to  0.75
# PARTITION: New node  9  new edge from  3  to  9
# PARTITION: New node  10  new edge from  3  to  10
# Running subdomain selection
# SELECT: For node  1  best x:  0.24325988204998797  best tead:  0.6033891593525053
# SELECT: For node  5  best x:  0.7554884758340642  best tead:  0.21983563730901567
# SELECT: For node  7  best x:  0.9256032966806512  best tead:  0.2508989151200612
# SELECT: For node  8  best x:  0.9605578954480777  best tead:  0.15523305344275978
# SELECT: For node  9  best x:  0.5055768446751794  best tead:  0.36160275690967986
# SELECT: For node  10  best x:  0.7496712892028633  best tead:  0.31181164448951865
# SELECT: Found  1  as best with score  0.6033891593525053
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.6937630846020882  and  0.8260512011566495
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.33880509689396987  and  0.37361262991971145
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.6713, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.4077, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.2833, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.1963, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.5684, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.4329, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  0.6712979282657385
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  11  new edge from  1  to  11
# PARTITION: New node  12  new edge from  1  to  12
# Running subdomain selection
# SELECT: For node  5  best x:  0.7554793388448705  best tead:  0.39819356572511044
# SELECT: For node  7  best x:  0.8964975428278449  best tead:  0.2867237059538698
# SELECT: For node  8  best x:  0.9608501690280068  best tead:  0.1993596857004581
# SELECT: For node  9  best x:  0.5417728846656704  best tead:  0.5678253041964076
# SELECT: For node  10  best x:  0.7497037364692275  best tead:  0.4293604053949216
# SELECT: For node  11  best x:  0.061222024298998416  best tead:  0.5820851076088582
# SELECT: For node  12  best x:  0.4924709770314969  best tead:  0.7783021139447264
# SELECT: Found  12  as best with score  0.7783021139447264
# Running local search
# LOCALSEARCH: Running search in node  12
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.15206396446843654  and  0.2054401259920432
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.3173844915879219  and  0.3504411864275373
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Observed 4 peaks
# Function evaluations to find all peaks: 59
# Time to complete search: 476.01600000000326
#
# Trial  5 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.5777, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.5776586586009225
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.3471688751768437  best tead:  0.8831080784108383
# SELECT: For node  2  best x:  0.971537574029763  best tead:  1.3511979396325604
# SELECT: Found  2  as best with score  1.3511979396325604
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.22237741359630342  and  0.23070981592418338
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.0012209048124563898  and  0.15993810288263227
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.4999, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.5225, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.5224952952547615
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.3473332882927675  best tead:  1.6851054344085725
# SELECT: For node  3  best x:  0.5643386466173415  best tead:  0.7720131442880325
# SELECT: For node  4  best x:  0.8057692351070109  best tead:  1.4042211385442247
# SELECT: Found  1  as best with score  1.6851054344085725
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.42624989435921873  and  0.7772626551819144
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  4.144099636178516e-05  and  0.06138067205000385
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.1992, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.7868, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.4168, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  1.416777294559565
# Running partition
# PARTITION: Splitting node  4  from  0.75  to  0.875  to  1.0
# PARTITION: New node  5  new edge from  4  to  5
# PARTITION: New node  6  new edge from  4  to  6
# Running subdomain selection
# SELECT: For node  1  best x:  0.4877602419430743  best tead:  1.201188371356762
# SELECT: For node  3  best x:  0.5638718763975008  best tead:  0.7943840974611777
# SELECT: For node  5  best x:  0.7599401827742813  best tead:  1.2415157752068193
# SELECT: For node  6  best x:  0.9025001199548068  best tead:  1.2120675600247015
# SELECT: Found  5  as best with score  1.2415157752068193
# Running local search
# LOCALSEARCH: Running search in node  5
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.34160660178457336  and  0.8356243844794292
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.32602552001770535  and  0.3628546927968128
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.2185, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.9636, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(1.1357, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(1.2913, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  1.291269786772511
# Running partition
# PARTITION: Splitting node  6  from  0.875  to  0.9375  to  1.0
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  1  best x:  0.2500258321738508  best tead:  1.2216550651587579
# SELECT: For node  3  best x:  0.563613317545452  best tead:  0.9550522934614719
# SELECT: For node  5  best x:  0.7600352563703475  best tead:  1.158033150686268
# SELECT: For node  7  best x:  0.8820289326816979  best tead:  0.5181081181329527
# SELECT: For node  8  best x:  0.9504053871873238  best tead:  1.1007225811346026
# SELECT: Found  1  as best with score  1.2216550651587579
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5919198777287158  and  0.9198201656182617
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.3004134797403677  and  0.3502581843087538
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.2345, dtype=torch.float64, grad_fn=<MaxBackward1>)
# ...
# PRESELECT: For node  6  tead score:  tensor(1.0173, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  1.0172607558820592
# Running partition
# PARTITION: Splitting node  6  from  0.75  to  0.875  to  1.0
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.17567714597790848  best tead:  0.26461075084281477
# SELECT: For node  4  best x:  0.3072737222607486  best tead:  0.4455649353816378
# SELECT: For node  5  best x:  0.6827949463644291  best tead:  0.6097280325590286
# SELECT: For node  7  best x:  0.8191876858077134  best tead:  0.6106686278027926
# SELECT: For node  8  best x:  0.9208854703413234  best tead:  1.0127800669324643
# SELECT: Found  8  as best with score  1.0127800669324643
# Running local search
# LOCALSEARCH: Running search in node  8
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.40040613362430993  and  0.41266637362827724
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.9161992262084975  and  0.92175348060811
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.2624, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.6087, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.5541, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.1530, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.5001, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  0.6086940367246616
# Running partition
# PARTITION: Splitting node  4  from  0.25  to  0.375  to  0.5
# PARTITION: New node  9  new edge from  4  to  9
# PARTITION: New node  10  new edge from  4  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.1757554520662525  best tead:  0.26231839770591453
# SELECT: For node  5  best x:  0.6823297356574912  best tead:  0.5506501990026109
# SELECT: For node  7  best x:  0.8679991061468173  best tead:  0.15482010263766088
# SELECT: For node  8  best x:  0.9201437228526006  best tead:  0.5034174060672956
# SELECT: For node  9  best x:  0.3454246401525607  best tead:  0.9828625056829227
# SELECT: For node  10  best x:  0.38805294393208395  best tead:  0.42569653755620385
# SELECT: Found  9  as best with score  0.9828625056829227
# Running local search
# LOCALSEARCH: Running search in node  9
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5896984778884706  and  0.7682966444895105
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.3454742209207836  and  0.3678342037521872
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.1654, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.8130, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.2860, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.5013, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.4802, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.2972, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  5  for split with score  0.8129853790649257
# Running partition
# PARTITION: Splitting node  5  from  0.5  to  0.625  to  0.75
# PARTITION: New node  11  new edge from  5  to  11
# PARTITION: New node  12  new edge from  5  to  12
# Running subdomain selection
# SELECT: For node  3  best x:  0.012723037666910728  best tead:  0.1652537686220612
# SELECT: For node  7  best x:  0.7562560760597332  best tead:  0.2888242098299874
# SELECT: For node  8  best x:  0.9203143691831315  best tead:  0.501152049191537
# SELECT: For node  9  best x:  0.3599596674525455  best tead:  0.4847140693193076
# SELECT: For node  10  best x:  0.479841745530711  best tead:  0.2942197058245949
# SELECT: For node  11  best x:  0.6011242430194007  best tead:  0.6343509541656447
# SELECT: For node  12  best x:  0.6446455969299106  best tead:  0.960749745299128
# SELECT: Found  12  as best with score  0.960749745299128
# Running local search
# LOCALSEARCH: Running search in node  12
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.33922132749124234  and  0.3820365301901396
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.6436504609611845  and  0.6528802786799176
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Observed 4 peaks
# Function evaluations to find all peaks: 83
# Time to complete search: 492.7809999999881
#
# Trial 15 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.5176, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.5176221628266093
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.37092001110565787  best tead:  1.391015976135889
# SELECT: For node  2  best x:  0.9451751653515773  best tead:  1.093634112096884
# SELECT: Found  1  as best with score  1.391015976135889
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.7860460447841027  and  0.7988851455793118
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  8.495235911646947e-05  and  0.06916772800122668
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.0144, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.1701, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.1701236447538612
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.37028846367704654  best tead:  1.067916726855365
# SELECT: For node  3  best x:  0.513856323856583  best tead:  1.2940393591999182
# SELECT: For node  4  best x:  0.8738674302579791  best tead:  1.2438588706120315
# SELECT: Found  3  as best with score  1.2940393591999182
# Running local search
# LOCALSEARCH: Running search in node  3
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.6207730034185424  and  0.6358543749547952
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.5895248053531013  and  0.6312784300936236
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.1570, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.4900, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.0960, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.1570374955137162
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  5  new edge from  1  to  5
# PARTITION: New node  6  new edge from  1  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.7499084269024207  best tead:  0.4877642907698774
# SELECT: For node  4  best x:  0.9226414355872324  best tead:  1.098217836305752
# SELECT: For node  5  best x:  0.24951189949946387  best tead:  0.6424029029820272
# SELECT: For node  6  best x:  0.25034735865646907  best tead:  0.6472280402845247
# SELECT: Found  4  as best with score  1.098217836305752
# Running local search
# LOCALSEARCH: Running search in node  4
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.3183633158138695  and  0.4127928212967857
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.8786970300426123  and  0.922546267829684
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.3353, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.5035, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.3004, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.7491, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  0.7490561799073424
# Running partition
# PARTITION: Splitting node  6  from  0.25  to  0.375  to  0.5
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.6564841599126887  best tead:  0.3352314684478289
# SELECT: For node  4  best x:  0.9192501519050179  best tead:  0.5023773508989675
# SELECT: For node  5  best x:  0.24997540771005672  best tead:  0.30012115280238083
# SELECT: For node  7  best x:  0.3475382159913751  best tead:  0.8597721278428203
# SELECT: For node  8  best x:  0.4438218438120282  best tead:  0.287637298465617
# SELECT: Found  7  as best with score  0.8597721278428203
# Running local search
# LOCALSEARCH: Running search in node  7
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5605362876375619  and  0.6695573190113188
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  9  new turbo evaluations between  0.33548557731461215  and  0.3514928568261533
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.2899, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.4365, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.4504, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.5005, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.1490, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  7  for split with score  0.5005250810856828
# Running partition
# PARTITION: Splitting node  7  from  0.25  to  0.3125  to  0.375
# PARTITION: New node  9  new edge from  7  to  9
# PARTITION: New node  10  new edge from  7  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.6965269228877277  best tead:  0.2886515328791178
# SELECT: For node  4  best x:  0.919447573343342  best tead:  0.4266347748710743
# SELECT: For node  5  best x:  0.13283752388846906  best tead:  0.4423568710529211
# SELECT: For node  8  best x:  0.3860368174278024  best tead:  0.14390882018031478
# SELECT: For node  9  best x:  0.2503711994141195  best tead:  0.14898492876042094
# SELECT: For node  10  best x:  0.35062787942135076  best tead:  0.5000953576896378
# SELECT: Found  10  as best with score  0.5000953576896378
# Running local search
# LOCALSEARCH: Running search in node  10
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.16485589832902633  and  0.37372068587267937
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  3  new turbo evaluations between  0.34723411473583865  and  0.35111233052935886
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.4930, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.8235, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.9507, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.2160, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.2942, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.2796, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  5  for split with score  0.9507101537353455
# Running partition
# PARTITION: Splitting node  5  from  0.0  to  0.125  to  0.25
# PARTITION: New node  11  new edge from  5  to  11
# PARTITION: New node  12  new edge from  5  to  12
# Running subdomain selection
# SELECT: For node  3  best x:  0.6965755262151808  best tead:  0.48506981209949385
# SELECT: For node  4  best x:  0.7637816357427737  best tead:  0.7699839047412106
# SELECT: For node  8  best x:  0.44415224853396656  best tead:  0.21318687835770123
# SELECT: For node  9  best x:  0.2504105397166624  best tead:  0.2805921586574773
# SELECT: For node  10  best x:  0.3273503542735383  best tead:  0.26228751995810173
# SELECT: For node  11  best x:  0.1185569108259897  best tead:  1.0849262234305495
# SELECT: For node  12  best x:  0.194843576993149  best tead:  0.6209050804128572
# SELECT: Found  11  as best with score  1.0849262234305495
# Running local search
# LOCALSEARCH: Running search in node  11
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5614597118196324  and  0.8350661326575556
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  9  new turbo evaluations between  0.04007553038087146  and  0.05899418153699891
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Observed 3 peaks
# Function evaluations to find all peaks: 130
# Time to complete search: 526.4850000000006

# %%
# calculate summary metrics
# peak ratio
num_known_peaks = 4
# n_replications = 15
peak_ratio = sum(distinct_peaks) / (num_known_peaks * n_replications)
print("Peak ratio: {}".format(peak_ratio))
# success rate
num_successes = 0
for i in range(n_replications):
    if distinct_peaks[i] == 4:
        num_successes += 1
success_ratio = num_successes / n_replications
print("Success ratio: {}".format(success_ratio))
print("Average function evaluations: {}".format(sum(function_evaluations)/n_replications))
# Out:
# Peak ratio: 0.9166666666666666
# Success ratio: 0.6666666666666666
# Average function evaluations: 108.26666666666667

# %%
# save data to file for potential future use
methods_list = ['PIONEER']
pr_list = [peak_ratio]
sr_list = [success_ratio]
fe_list = [function_evaluations]
import pickle
with open(datasavedir + '/' + 'mme_metrics.pkl', 'wb') as f:
    pickle.dump([methods_list, pr_list, sr_list, fe_list], f)
# to retrieve
# with open(datasavedir + '/' + 'mme_metrics.pkl') as f:
#     methods_list, pr_list, sr_list, fe_list = pickle.load(f)
