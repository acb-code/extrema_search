# %%
# notebook for first canonical problem for multimodal optimization looking for localized extreme
# events with agent-based military simulation
# Experiment 2.1 - Deterministic literature test problem "five-uneven-peak-trap" [5]
# Part 1 - balanced strategy (PIONEER)
#
# Author: Alex Braafladt
# Initial creation: 3/11/23
#
# Goal: Benchmark state-of-the-art Bayesian Optimization approaches (and QMC/MCS) on a multimodal
#       optimization test function focused on localized extrema
#
# Notes:
# -Using the BoTorch framework [1] and NEI from [4]
# -TEAD technique from [2]
# -TuRBO technique from [3]
#
# References:
# [1] M. Balandat et al., “BOTORCH: A framework for efficient Monte-Carlo Bayesian optimization,”
#     Adv. Neural Inf. Process. Syst., vol. 2020-Decem, no. MC, 2020.
# [2] S. Mo et al., “A Taylor Expansion-Based Adaptive Design Strategy for Global Surrogate
#     Modeling With Applications in Groundwater Modeling,” Water Resour. Res., vol. 53, no.
#     12, pp. 10802–10823, 2017, doi: 10.1002/2017WR021622.
# [3] D. Eriksson, M. Pearce, J. R. Gardner, R. Turner, and M. Poloczek, “Scalable global
#     optimization via local Bayesian optimization,” Adv. Neural Inf. Process. Syst., vol.
#     32, no. NeurIPS, 2019.
# [4] B. Letham, B. Karrer, G. Ottoni, and E. Bakshy, “Constrained Bayesian optimization with noisy
#     experiments,” Bayesian Anal., vol. 14, no. 2, pp. 495–519, 2019, doi: 10.1214/18-BA1110.
# [5] X. Li, A. Engelbrecht, and M. G. Epitropakis, “Benchmark Functions for CEC’2013 Special
#     Session and Competition on Niching Methods for Multimodal Function Optimization,” 2016.

# %%
# imports
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from extremasearch.globalmm.globalsearch import MultimodalExtremaSearch
from botorch import fit_gpytorch_mll
from botorch.models.gp_regression import SingleTaskGP
from gpytorch.mlls import ExactMarginalLogLikelihood
import numpy as np
import networkx as nx
from botorch.models.transforms import Normalize, Standardize
import time


# setup
dtype = torch.double
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import warnings
from botorch.exceptions import BadInitialCandidatesWarning
warnings.filterwarnings('ignore', category=BadInitialCandidatesWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# %%
# setup file i/o
import os as os
import datetime as dt
# get current working directory
wrkdir = os.getcwd()
print('Current working directory: '+wrkdir)
# set up a data save directory for all future runs
newoutputdir = wrkdir+'\output'
if not os.path.exists(newoutputdir):
    os.makedirs(newoutputdir)
# set up a new directory to store files for the current run - updates at each new full run of notebook
curDatetime = dt.datetime.now()
datasavedir = newoutputdir + r'\\' + 'exp2.1_balanced_lit1' + str(curDatetime.strftime('%Y%m%d%H%M%S'))
if not os.path.exists(datasavedir):
    os.makedirs(datasavedir)
print('Data save directory: '+datasavedir)
# Out:
# Current working directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks\iter4_exp2
# Data save directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks\iter4_exp2\output\\exp2.1_balanced_lit120230311215912

# %%
# test function
def fupt_torch(x):
    x = x
    y = torch.zeros(x.shape)
    y += ((1.0/200.0) * 80.0 * (2.5 - 30.0*x)) * (x >= 0.0) * (x < 2.5/30.0)
    y += ((1.0/200.0) * 64.0 * (30.0*x - 2.5)) * (x >= 2.5/30.0) * (x < 5.0/30.0)
    y += ((1.0/200.0) * 64.0 * (7.5 - 30.0*x)) * (x >= 5.0/30.0) * (x < 7.5/30.0)
    y += ((1.0/200.0) * 28.0 * (30.0*x - 7.5)) * (x >= 7.5/30.0) * (x < 12.5/30.0)
    y += ((1.0/200.0) * 28.0 * (17.5 - 30.0*x)) * (x >= 12.5/30.0) * (x < 17.5/30.0)
    y += ((1.0/200.0) * 32.0 * (30.0*x - 17.5)) * (x >= 17.5/30.0) * (x < 22.5/30.0)
    y += ((1.0/200.0) * 32.0 * (27.5 - 30.0*x)) * (x >= 22.5/30.0) * (x < 27.5/30.0)
    y += ((1.0/200.0) * 80.0 * (30.0*x - 27.5)) * (x >= 27.5/30.0) * (x < 30.0/30.0)
    return y

# %%
# plot the test function
x1 = torch.linspace(0,1.0,200)
y1 = fupt_torch(x1)
fig, ax = plt.subplots(1, 1, figsize=(8,6))
sns.lineplot(x=x1, y=y1, ax=ax, color='r')
# ax.set_xlim([0.0, 0.005])
# ax.set_ylim([0.6, 1.0])
plt.savefig(datasavedir + '/'+'deterministic_test_problem'+'.png')

# %%
# wrapper for use in optimization loop
def outcome_objective(x):
    """wrapper for the outcome objective function"""
    # return mme_torch(X).type_as(X)
    return fupt_torch(x).type_as(x)

# %%
# functions for getting and working with data from searches
def get_bounds(graph):
    """Get the bounds for each node in a graph to be able to plot them"""
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    bound_list = []
    node_list = []
    for n in graph_leaves:
        # get current leaf node
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_bounds = current_state.local_bounds
        node_list.append(n)
        bound_list.append(current_bounds)
    return node_list, bound_list


def get_bounds_all(graph):
    """Get the bounds for each node in a graph to be able to plot them"""
    graph_nodes = [n for n in graph]
    bound_list = []
    node_list = []
    for n in graph_nodes:
        # get current node
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_bounds = current_state.local_bounds
        node_list.append(n)
        bound_list.append(current_bounds)
    return node_list, bound_list


def fit_local_models(graph):
    """Go through leaf nodes and update LocalSearchState to have local {x, y}
    based on global {x, y} that are within bounds"""
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    for n in graph_leaves:
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_state.local_model = SingleTaskGP(current_state.x_local, current_state.y_local,
                                                 input_transform=Normalize(d=current_state.x_local.shape[-1]),
                                                 outcome_transform=Standardize(m=current_state.y_local.shape[-1]))
        current_state.local_mll = ExactMarginalLogLikelihood(current_state.local_model.likelihood,
                                                             current_state.local_model)
        fit_gpytorch_mll(current_state.local_mll)


def plot_local_models_1d(graph, x_search, y_search, rep):
    """Go through leaf nodes and plot the local models only within the bounds of the node"""
    fit_local_models(graph)
    nodes, bnds = get_bounds(graph)
    x_test = torch.linspace(0, 1, 400)
    f, ax = plt.subplots(1, 1, figsize=(8, 6))
    # true objective
    ax.plot(x_test.numpy(), outcome_objective(x_test).numpy(), 'r-', alpha=0.9, label='true objective')
    # local models
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    for n in graph_leaves:
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_model = current_state.local_model
        current_bounds = current_state.local_bounds
        current_x_test_mask = torch.ge(x_test, current_bounds[0]) & torch.lt(x_test, current_bounds[1])
        current_x_test = x_test[current_x_test_mask]
        mean_test = current_model.posterior(current_x_test.unsqueeze(-1)).mean.detach().numpy()
        ax.plot(current_x_test.numpy(), mean_test, 'b-', alpha=0.9, label='surrogate mean')
        var_test = current_model.posterior(current_x_test.unsqueeze(-1)).variance.detach().numpy()
        sd_test = np.sqrt(var_test)
        upper_test = mean_test + 2.0 * sd_test
        lower_test = mean_test - 2.0 * sd_test
        ax.fill_between(current_x_test.numpy(), lower_test.squeeze(), upper_test.squeeze(), color='b', alpha=0.3,
                        label=r'surrogate 2$\sigma$')
    # training points
    ax.plot(x_search.numpy()[0:10], y_search[0:10].numpy(), '.', color='tab:orange', label='initial data')
    ax.plot(x_search.numpy()[10:], y_search[10:].numpy(), '.', color='g', label='bo data')
    # partitions
    for n, b in zip(nodes, bnds):
        ax.plot([b[0].numpy(), b[0].numpy()], [-0.05, 1.45], 'k-')
    # ax.legend()
    ax.set_ylim([-0.02, 1.02])
    ax.set_title('PIONEER_rep{}'.format(rep))
    # ax.set_xlim([0.915, 0.925])
    plt.savefig(datasavedir + '/'+'1d_results_local_models_rep{}'.format(rep)+'.png')


def plot_current_tree(global_search: MultimodalExtremaSearch, rep):
    """Save a plot of the tree structure after the search"""
    # tree figure
    T = global_search.global_state.partition_graph
    pos = nx.nx_agraph.graphviz_layout(T, prog="dot")
    # bounds to put on nodes on plot
    all_nodes, all_bounds = get_bounds_all(global_search.global_state.partition_graph)
    # positioning of bound text
    pos_attrs = {}
    for node, coords in pos.items():
        pos_attrs[node] = (coords[0]-15, coords[1])
    custom_node_attrs = {}
    for node, attrs in zip(all_nodes, all_bounds):
        custom_node_attrs[node] = str(attrs.numpy().round(decimals=3))
    # plot commands
    f, ax = plt.subplots(1, 1, figsize=(12, 8), constrained_layout=True)
    nx.draw(T, pos, with_labels=True, font_weight='bold', ax=ax)
    nx.draw_networkx_labels(T, pos_attrs, labels=custom_node_attrs, ax=ax)
    ax.set_title('PIONEER Partition Tree')
    plt.savefig(datasavedir + '/'+'partition_tree_rep{}'.format(rep)+'.png')

# %%
# experiment functions to calculate metrics
# metrics functions
def count_number_peaks_observed(x_obs, y_obs, num_known_peaks=5):
    """Function to count the number of peaks observed for the mme_noise_jump_1d function"""
    peak1, peak2, peak3, peak4, peak5 = False, False, False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.000 <= x <= 0.005:
            if y >= 0.95:
                peak1 = True
        elif 0.162 <= x <= 0.172:
            if y >= 0.75:
                peak2 = True
        elif 0.412 <= x <= 0.422:
            if y >= 0.67:
                peak3 = True
        elif 0.745 <= x <= 0.755:
            if y >= 0.75:
                peak4 = True
        elif 0.995 <= x <= 1.000:
            if y >= 0.89:
                peak5 = True
    num_peaks_observed = peak1 + peak2 + peak3 + peak4 + peak5
    return num_peaks_observed


def count_evaluations_for_all_peaks(x_obs, y_obs):
    """Count the number of function evaluations before finding all peaks"""
    i = 0
    num_evals_for_all_peaks = x_obs.shape[0]
    peak1, peak2, peak3, peak4, peak5 = False, False, False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.000 <= x <= 0.005:
            if y >= 0.95:
                peak1 = True
        elif 0.162 <= x <= 0.172:
            if y >= 0.75:
                peak2 = True
        elif 0.412 <= x <= 0.422:
            if y >= 0.67:
                peak3 = True
        elif 0.745 <= x <= 0.755:
            if y >= 0.75:
                peak4 = True
        elif 0.995 <= x <= 1.000:
            if y >= 0.89:
                peak5 = True
        i += 1
        if peak1 and peak2 and peak3 and peak4 and peak5:
            num_evals_for_all_peaks = i
            break
    return num_evals_for_all_peaks

# %%
# replicated searches

# search and experiment settings
n_replications = 15
global_bounds = torch.tensor([0.0, 1.0], dtype=dtype)
n_evals = 130

# data holders
x_observed_all = []
y_observed_all = []
distinct_peaks = []
function_evaluations = []

# experiment loop
for rep in range(1, n_replications + 1):
    print(f"\nTrial {rep:>2} of {n_replications} ", end="")
    t0 = time.monotonic()
    # initialize search
    current_global_search = MultimodalExtremaSearch(60,global_bounds,outcome_objective,total_iteration_limit=n_evals)
    # run search
    current_global_search.run_global_search()

    # collect data
    x_observed_all.append(current_global_search.global_state.x_global)
    y_observed_all.append(current_global_search.global_state.y_global)

    # run and save plots
    # results with local model
    plot_local_models_1d(current_global_search.global_state.partition_graph,
                         current_global_search.global_state.x_global,
                         current_global_search.global_state.y_global,
                         rep)
    # partitioning results tree
    plot_current_tree(current_global_search, rep)

    # calculate metrics
    num_peaks_observed = count_number_peaks_observed(current_global_search.global_state.x_global,
                                                     current_global_search.global_state.y_global)
    print("Observed {num:} peaks".format(num=num_peaks_observed),)
    distinct_peaks.append(num_peaks_observed)
    fe = count_evaluations_for_all_peaks(current_global_search.global_state.x_global,
                                         current_global_search.global_state.y_global)
    print("Function evaluations to find all peaks: {}".format(fe))
    function_evaluations.append(fe)
    # time for search
    t1 = time.monotonic()
    print("Time to complete search: {}".format(t1-t0))
# Out:
# Trial  1 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.0440, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.0440466073533763
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.47046137470776783  best tead:  1.358490091004279
# SELECT: For node  2  best x:  0.5357462866635382  best tead:  0.6912422656543982
# SELECT: Found  1  as best with score  1.358490091004279
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.7375999702489542  and  0.9199469294877151
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  1.06542441687438e-06  and  0.020708907469840356
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.0077, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(0.9483, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.00770256878107
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  3  new edge from  1  to  3
# PARTITION: New node  4  new edge from  1  to  4
# Running subdomain selection
# SELECT: For node  2  best x:  0.5517601527562487  best tead:  1.0100069606424777
# SELECT: For node  3  best x:  0.24603565205464406  best tead:  0.8157239665217855
# SELECT: For node  4  best x:  0.40281510472795135  best tead:  0.9500839834214012
# SELECT: Found  2  as best with score  1.0100069606424777
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.704838613940535  and  0.7048802241817115
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.722490412067287  and  0.7793012195039917
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  2  tead score:  tensor(0.5097, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.5152, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.4884, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  3  for split with score  0.5151683963985785
# Running partition
# PARTITION: Splitting node  3  from  0.0  to  0.125  to  0.25
# PARTITION: New node  5  new edge from  3  to  5
# PARTITION: New node  6  new edge from  3  to  6
# Running subdomain selection
# SELECT: For node  2  best x:  0.5204427265833375  best tead:  0.4979729725437281
# SELECT: For node  4  best x:  0.38788514015010983  best tead:  0.49121761705339295
# SELECT: For node  5  best x:  0.11583343346631317  best tead:  0.1681320446787348
# SELECT: For node  6  best x:  0.24951326576610794  best tead:  0.5636530321605574
# SELECT: Found  6  as best with score  0.5636530321605574
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.22254671274702437  and  0.22301043431246648
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.15596515481823395  and  0.17920486891174028
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  2  tead score:  tensor(0.7824, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.6944, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.1390, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.1830, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  0.7824457604379654
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  7  new edge from  2  to  7
# PARTITION: New node  8  new edge from  2  to  8
# Running subdomain selection
# SELECT: For node  4  best x:  0.36129082877301666  best tead:  0.7751039174389038
# SELECT: For node  5  best x:  0.0745702766245217  best tead:  0.15398210333923348
# SELECT: For node  6  best x:  0.2497692094388492  best tead:  0.22198797680864024
# SELECT: For node  7  best x:  0.5121330665225725  best tead:  0.9688897663561031
# SELECT: For node  8  best x:  0.9522585669973657  best tead:  0.7371965973413881
# SELECT: Found  7  as best with score  0.9688897663561031
# Running local search
# LOCALSEARCH: Running search in node  7
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.6330601844047986  and  0.6332223527101665
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.7444161934551228  and  0.7707301200140644
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  4  tead score:  tensor(0.6313, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.1425, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.1949, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.6717, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.6573, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  7  for split with score  0.6717202586196451
# Running partition
# PARTITION: Splitting node  7  from  0.5  to  0.625  to  0.75
# PARTITION: New node  9  new edge from  7  to  9
# PARTITION: New node  10  new edge from  7  to  10
# Running subdomain selection
# SELECT: For node  4  best x:  0.4101372079098452  best tead:  0.6256195822019828
# SELECT: For node  5  best x:  0.07457466005340417  best tead:  0.14445431023378286
# SELECT: For node  6  best x:  0.24960473061701485  best tead:  0.19608390483327726
# SELECT: For node  8  best x:  0.9524902879223457  best tead:  0.6411440004433027
# SELECT: For node  9  best x:  0.5590759016900541  best tead:  0.8972529812006189
# SELECT: For node  10  best x:  0.6487601355198397  best tead:  0.17105677859959761
# SELECT: Found  9  as best with score  0.8972529812006189
# Running local search
# LOCALSEARCH: Running search in node  9
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.6847010928136467  and  0.8004984158429957
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.7757610080403916  and  0.8161028969440318
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  4  tead score:  tensor(0.7963, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.3531, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.2838, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.7502, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.7675, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.0810, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  0.7963155603375794
# Running partition
# PARTITION: Splitting node  4  from  0.25  to  0.375  to  0.5
# PARTITION: New node  11  new edge from  4  to  11
# PARTITION: New node  12  new edge from  4  to  12
# Running subdomain selection
# SELECT: For node  5  best x:  0.005776812830200811  best tead:  0.35801111876523783
# SELECT: For node  6  best x:  0.14724912649215305  best tead:  0.2885872481364692
# SELECT: For node  8  best x:  0.9525748503133451  best tead:  0.7480575421113347
# SELECT: For node  9  best x:  0.5717551682817799  best tead:  0.7734696610160956
# SELECT: For node  10  best x:  0.648440316592811  best tead:  0.08138194381256811
# SELECT: For node  11  best x:  0.3190600706482917  best tead:  0.5799149123226484
# SELECT: For node  12  best x:  0.3950002627920188  best tead:  0.42739516078355416
# SELECT: Found  9  as best with score  0.7734696610160956
# Running local search
# LOCALSEARCH: Running search in node  9
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.68464436586781  and  0.8002452823350105
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.7431244952679045  and  0.7917999520216036
# Observed 5 peaks
# Function evaluations to find all peaks: 85
# Time to complete search: 612.9840000000258
#
# Trial  2 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.3594, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.3594205799069323
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.49226364022870295  best tead:  1.3625733648565987
# SELECT: For node  2  best x:  0.6611744378080942  best tead:  0.7263887410823201
# SELECT: Found  1  as best with score  1.3625733648565987
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.7841162218424944  and  0.8210791746414569
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  9.966160031139603e-07  and  0.04774941609455026
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.9666, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(0.9601, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  0.9665886746539218
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  3  new edge from  1  to  3
# PARTITION: New node  4  new edge from  1  to  4
# Running subdomain selection
# SELECT: For node  2  best x:  0.8874586473224066  best tead:  0.9703593586862554
# SELECT: For node  3  best x:  0.24731377678575325  best tead:  0.6570839420066713
# SELECT: For node  4  best x:  0.35344527230206624  best tead:  0.8359326022886269
# SELECT: Found  2  as best with score  0.9703593586862554
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.7997377846960241  and  0.8002214928147177
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.981494694987774  and  0.9999967807510667
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  2  tead score:  tensor(0.9064, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.4442, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.8363, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  0.9063778840594483
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  5  new edge from  2  to  5
# PARTITION: New node  6  new edge from  2  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.21354774490538037  best tead:  0.5037607328481062
# SELECT: For node  4  best x:  0.35325304327903034  best tead:  1.2693556503791967
# SELECT: For node  5  best x:  0.5941426366367364  best tead:  1.162549263490944
# SELECT: For node  6  best x:  0.7599213209695241  best tead:  0.4333052872775538
# SELECT: Found  4  as best with score  1.2693556503791967
# Running local search
# LOCALSEARCH: Running search in node  4
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.41137134702906475  and  0.4116417364280449
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.4044701935032847  and  0.42280551495575336
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.5290, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.5813, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.5369, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.4540, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  0.5813211408996144
# Running partition
# PARTITION: Splitting node  4  from  0.25  to  0.375  to  0.5
# PARTITION: New node  7  new edge from  4  to  7
# PARTITION: New node  8  new edge from  4  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.1299317234171959  best tead:  0.53182181975721
# SELECT: For node  5  best x:  0.6412202155045329  best tead:  0.5361317448921004
# SELECT: For node  6  best x:  0.7598345875224387  best tead:  0.45286124636994735
# SELECT: For node  7  best x:  0.2878138716962121  best tead:  0.41977119835787835
# SELECT: For node  8  best x:  0.4345695430596625  best tead:  0.38709256085485544
# SELECT: Found  5  as best with score  0.5361317448921004
# Running local search
# LOCALSEARCH: Running search in node  5
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.21476828812005855  and  0.3534673720943669
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.7424474829274328  and  0.7768212636399181
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.3349, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.2449, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.3617, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.3563, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.3095, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  0.3616741873102909
# Running partition
# PARTITION: Splitting node  6  from  0.75  to  0.875  to  1.0
# PARTITION: New node  9  new edge from  6  to  9
# PARTITION: New node  10  new edge from  6  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.14067963770390823  best tead:  0.49802714442835516
# SELECT: For node  5  best x:  0.6417351270719209  best tead:  0.3548812497580059
# SELECT: For node  7  best x:  0.3113178598570336  best tead:  0.5207873211204163
# SELECT: For node  8  best x:  0.4350232202902691  best tead:  0.46685246937548097
# SELECT: For node  9  best x:  0.8438798179700102  best tead:  0.42050465095153117
# SELECT: For node  10  best x:  0.9629623999689723  best tead:  0.27412502334193484
# SELECT: Found  7  as best with score  0.5207873211204163
# Running local search
# LOCALSEARCH: Running search in node  7
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.3119313281074626  and  0.31218163420406114
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.37480419399657955  and  0.4244085377126347
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.9187, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.7088, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.7251, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.2041, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.8467, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.5130, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  3  for split with score  0.9187353655514796
# Running partition
# PARTITION: Splitting node  3  from  0.0  to  0.125  to  0.25
# PARTITION: New node  11  new edge from  3  to  11
# PARTITION: New node  12  new edge from  3  to  12
# Running subdomain selection
# SELECT: For node  5  best x:  0.6037622492252521  best tead:  0.740787436926071
# SELECT: For node  7  best x:  0.25669680752347324  best tead:  0.7332568643838082
# SELECT: For node  8  best x:  0.43518030965243676  best tead:  0.19968562300971207
# SELECT: For node  9  best x:  0.8434990585428888  best tead:  0.8483778326002195
# SELECT: For node  10  best x:  0.9628346815807574  best tead:  0.5200184261651409
# SELECT: For node  11  best x:  0.09714304820068648  best tead:  0.6871321548760987
# SELECT: For node  12  best x:  0.14127401797834316  best tead:  0.7586798955144607
# SELECT: Found  9  as best with score  0.8483778326002195
# Running local search
# LOCALSEARCH: Running search in node  9
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.8343753956959227  and  0.862461964678902
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.7345004463966103  and  0.7500239671605737
# Observed 5 peaks
# Function evaluations to find all peaks: 103
# Time to complete search: 550.5939999999828
#
# Trial  3 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.1426, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.1426010697530062
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.46297560917472663  best tead:  1.7446396015967927
# SELECT: For node  2  best x:  0.9726268996228565  best tead:  1.259392890490107
# SELECT: Found  1  as best with score  1.7446396015967927
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.3628698689783038  and  0.36309967665636533
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.16617360522119984  and  0.16712016050784573
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.1779, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.1957, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.1957482490254625
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.46987039251613  best tead:  1.1793392904473654
# SELECT: For node  3  best x:  0.6805289298132527  best tead:  0.6190276041717634
# SELECT: For node  4  best x:  0.9181993213894674  best tead:  0.9988523721553645
# SELECT: Found  1  as best with score  1.1793392904473654
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.36252834888464053  and  0.36261658513826867
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.16647420634596333  and  0.1669619530168055
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.0873, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.5954, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.9896, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.0873456777415933
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  5  new edge from  1  to  5
# PARTITION: New node  6  new edge from  1  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.680597491511456  best tead:  0.5993126745435702
# SELECT: For node  4  best x:  0.8099316810024443  best tead:  1.0946224320747828
# SELECT: For node  5  best x:  0.0001743557433845193  best tead:  0.20466330713091263
# SELECT: For node  6  best x:  0.42527080255667377  best tead:  0.42076897005665137
# SELECT: Found  4  as best with score  1.0946224320747828
# Running local search
# LOCALSEARCH: Running search in node  4
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.13179642438346098  and  0.667585479651749
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.9688726148776202  and  0.9999991472822511
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.8682, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.0577, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.1288, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.3079, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  1.057725975885177
# Running partition
# PARTITION: Splitting node  4  from  0.75  to  0.875  to  1.0
# PARTITION: New node  7  new edge from  4  to  7
# PARTITION: New node  8  new edge from  4  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.7476961912757808  best tead:  1.0585412703496069
# SELECT: For node  5  best x:  0.00017100735196657756  best tead:  0.13062952920951215
# SELECT: For node  6  best x:  0.38384512464254295  best tead:  0.3244562044788616
# SELECT: For node  7  best x:  0.8096426815952719  best tead:  0.40309224836433316
# SELECT: For node  8  best x:  0.8753372336814741  best tead:  0.21025635220777517
# SELECT: Found  3  as best with score  1.0585412703496069
# Running local search
# LOCALSEARCH: Running search in node  3
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.7844335700378746  and  0.8916502806102486
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.7365955267443498  and  0.778567471016868
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.4282, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.3877, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.3564, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.3873, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.1418, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  3  for split with score  0.4282311609659877
# Running partition
# PARTITION: Splitting node  3  from  0.5  to  0.625  to  0.75
# PARTITION: New node  9  new edge from  3  to  9
# PARTITION: New node  10  new edge from  3  to  10
# Running subdomain selection
# SELECT: For node  5  best x:  0.2031361038425131  best tead:  0.3863437685448631
# SELECT: For node  6  best x:  0.424981970956414  best tead:  0.3627622923997077
# SELECT: For node  7  best x:  0.7501335960354  best tead:  0.4071615555882313
# SELECT: For node  8  best x:  0.9586799657135088  best tead:  0.14563295863426914
# SELECT: For node  9  best x:  0.5331311646763871  best tead:  0.363185547964638
# SELECT: For node  10  best x:  0.7157291042381683  best tead:  0.26192898673682424
# SELECT: Found  7  as best with score  0.4071615555882313
# Running local search
# LOCALSEARCH: Running search in node  7
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.18833453963983132  and  0.6972720257377786
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.7376257772694704  and  0.7503830762717304
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  5  tead score:  tensor(0.6606, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.5877, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.2504, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.1966, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.4517, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.1709, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  5  for split with score  0.6606104416642249
# Running partition
# PARTITION: Splitting node  5  from  0.0  to  0.125  to  0.25
# PARTITION: New node  11  new edge from  5  to  11
# PARTITION: New node  12  new edge from  5  to  12
# Running subdomain selection
# SELECT: For node  6  best x:  0.2844027953378222  best tead:  0.6318882659639653
# SELECT: For node  7  best x:  0.7911690276677809  best tead:  0.29954776304883163
# SELECT: For node  8  best x:  0.9585418208150694  best tead:  0.20697336920157838
# SELECT: For node  9  best x:  0.5335057796535063  best tead:  0.5244917803405198
# SELECT: For node  10  best x:  0.7154393793129779  best tead:  0.19012496763119435
# SELECT: For node  11  best x:  0.0584222053502515  best tead:  0.5184036617577191
# SELECT: For node  12  best x:  0.1542869243420308  best tead:  0.35362580968630364
# SELECT: Found  6  as best with score  0.6318882659639653
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.3101499401666891  and  0.3174503046323326
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.41032952337508344  and  0.41821451519598507
# Observed 5 peaks
# Function evaluations to find all peaks: 120
# Time to complete search: 573.1560000000172
#
# Trial  4 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.1467, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.1466586478293117
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.48266596525236805  best tead:  1.3635040051978993
# SELECT: For node  2  best x:  0.8285668943087465  best tead:  0.7149022889722058
# SELECT: Found  1  as best with score  1.3635040051978993
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.24205039448542318  and  0.24244050064619738
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.16010186848496927  and  0.18240470466470254
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.2240, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.2324, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.2324480834522271
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.39594695341625963  best tead:  1.2212736988799833
# SELECT: For node  3  best x:  0.5150562423676922  best tead:  0.9297040614871739
# SELECT: For node  4  best x:  0.9249393922166425  best tead:  0.6987970841495238
# SELECT: Found  1  as best with score  1.2212736988799833
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.22968287151615713  and  0.2303098628167739
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.13741954815840257  and  0.18035345924353136
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.0865, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.7791, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.5998, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.0864607590010629
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  5  new edge from  1  to  5
# PARTITION: New node  6  new edge from  1  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.5156105148618969  best tead:  0.8407313915148868
# SELECT: For node  4  best x:  0.965652665915955  best tead:  0.6602173385853494
# SELECT: For node  5  best x:  0.020138125341545618  best tead:  1.1759134691955095
# SELECT: For node  6  best x:  0.34789509697219484  best tead:  0.8293935365360863
# SELECT: Found  5  as best with score  1.1759134691955095
# Running local search
# LOCALSEARCH: Running search in node  5
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.10068020730936655  and  0.10087083884503784
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.16657535386538042  and  0.17573834796702398
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.9168, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.8863, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.7359, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.9184, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  0.9183790918814032
# Running partition
# PARTITION: Splitting node  6  from  0.25  to  0.375  to  0.5
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.5228233096788323  best tead:  0.9221876381486269
# SELECT: For node  4  best x:  0.9248703394647284  best tead:  0.8689170017400516
# SELECT: For node  5  best x:  0.02021095943644373  best tead:  0.7342998124385129
# SELECT: For node  7  best x:  0.3574785836810496  best tead:  0.7518482425445964
# SELECT: For node  8  best x:  0.37549802251985687  best tead:  0.5042020471535721
# SELECT: Found  3  as best with score  0.9221876381486269
# Running local search
# LOCALSEARCH: Running search in node  3
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.6774349138783802  and  0.6967935171398678
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.7124356721016922  and  0.7721961010667839
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.7321, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.7613, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.7339, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.7310, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.7128, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  0.7613355689148091
# Running partition
# PARTITION: Splitting node  4  from  0.75  to  0.875  to  1.0
# PARTITION: New node  9  new edge from  4  to  9
# PARTITION: New node  10  new edge from  4  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.5701156005314443  best tead:  0.692953509702825
# SELECT: For node  5  best x:  0.010972167401719487  best tead:  0.6494975903790505
# SELECT: For node  7  best x:  0.37447726777037527  best tead:  0.6570062496104072
# SELECT: For node  8  best x:  0.3887727971172858  best tead:  0.6468416600516151
# SELECT: For node  9  best x:  0.847584820436437  best tead:  0.7925013031691357
# SELECT: For node  10  best x:  0.896230798955084  best tead:  1.1390773039278277
# SELECT: Found  10  as best with score  1.1390773039278277
# Running local search
# LOCALSEARCH: Running search in node  10
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.15906029378114303  and  0.4264810119255702
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  9  new turbo evaluations between  0.9948860518842042  and  0.9999998304668158
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.3603, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.2501, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.3019, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.8077, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.2441, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.2467, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  8  for split with score  0.8076519992781552
# Running partition
# PARTITION: Splitting node  8  from  0.375  to  0.4375  to  0.5
# PARTITION: New node  11  new edge from  8  to  11
# PARTITION: New node  12  new edge from  8  to  12
# Running subdomain selection
# SELECT: For node  3  best x:  0.6481044859796105  best tead:  0.3763874922811543
# SELECT: For node  5  best x:  0.0685154772930276  best tead:  0.26415077743665144
# SELECT: For node  7  best x:  0.37113568143900705  best tead:  0.29814609265079045
# SELECT: For node  9  best x:  0.8477986850678357  best tead:  0.265429101786913
# SELECT: For node  10  best x:  0.8952365589345374  best tead:  0.2464535827210814
# SELECT: For node  11  best x:  0.4184480127726583  best tead:  0.3965654539424698
# SELECT: For node  12  best x:  0.44931748726098003  best tead:  0.2708174710702962
# SELECT: Found  11  as best with score  0.3965654539424698
# Running local search
# LOCALSEARCH: Running search in node  11
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.4715030257146978  and  0.8115379486253816
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  5  new turbo evaluations between  0.4152476317007915  and  0.4216242315937654
# Observed 5 peaks
# Function evaluations to find all peaks: 129
# Time to complete search: 650.6559999999881
#
# Trial  5 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.5468, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.5468173495039368
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.0370278740431556  best tead:  1.1193757727242493
# SELECT: For node  2  best x:  0.9619736547038169  best tead:  1.5542462128459715
# SELECT: Found  2  as best with score  1.5542462128459715
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.923728402466816  and  0.9237741163386157
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.9459207074184166  and  0.999996063083632
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.2966, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.1944, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.2965705730362653
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  3  new edge from  1  to  3
# PARTITION: New node  4  new edge from  1  to  4
# Running subdomain selection
# SELECT: For node  2  best x:  0.795335344982667  best tead:  1.3471150093074948
# SELECT: For node  3  best x:  0.055337676024143724  best tead:  0.9209903843889412
# SELECT: For node  4  best x:  0.4612402538309016  best tead:  0.6853291511962214
# SELECT: Found  2  as best with score  1.3471150093074948
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.769310897546902  and  0.7695259598605347
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.9999632178920999  and  0.9999989679645865
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  2  tead score:  tensor(1.1435, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.8921, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.6353, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.1434507071834679
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  5  new edge from  2  to  5
# PARTITION: New node  6  new edge from  2  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.05535472104935733  best tead:  0.8403174713327064
# SELECT: For node  4  best x:  0.46170431782656374  best tead:  0.6329549602674102
# SELECT: For node  5  best x:  0.6750310526037775  best tead:  0.8027164636249047
# SELECT: For node  6  best x:  0.7504885405477146  best tead:  1.069129208291637
# SELECT: Found  6  as best with score  1.069129208291637
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.23147116460545927  and  0.5420683272813945
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.9999770795758822  and  0.9999998840472222
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.6631, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.5202, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.5699, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(1.0157, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  1.015744256023697
# Running partition
# PARTITION: Splitting node  6  from  0.75  to  0.875  to  1.0
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.10474250884235874  best tead:  0.7372859259209064
# SELECT: For node  4  best x:  0.4611435390658673  best tead:  0.5525341426109545
# SELECT: For node  5  best x:  0.6747649633455883  best tead:  0.6255808118242753
# SELECT: For node  7  best x:  0.7503874935079996  best tead:  1.0062328904416207
# SELECT: For node  8  best x:  0.9055047527216632  best tead:  0.04574372672349082
# SELECT: Found  7  as best with score  1.0062328904416207
# Running local search
# LOCALSEARCH: Running search in node  7
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.0986376460923005  and  0.7251369784724254
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.7344465166786911  and  0.750144943663873
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(1.2183, dtype=torch.float64, grad_fn=<MaxBackward1>)
# ...
# PRESELECT: For node  4  tead score:  tensor(0.6503, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.7790, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(1.0002, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  1.0002366204945656
# Running partition
# PARTITION: Splitting node  6  from  0.75  to  0.875  to  1.0
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.07189731114956768  best tead:  0.6207031509266188
# SELECT: For node  4  best x:  0.29305994571152577  best tead:  0.5991471194418716
# SELECT: For node  5  best x:  0.6324794986869093  best tead:  0.7275787346933763
# SELECT: For node  7  best x:  0.7524422966641037  best tead:  0.9710560233299905
# SELECT: For node  8  best x:  0.9051501495827388  best tead:  0.050622876128656215
# SELECT: Found  7  as best with score  0.9710560233299905
# Running local search
# LOCALSEARCH: Running search in node  7
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.2560237582281947  and  0.41076486130584694
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new turbo evaluations between  0.7346027055541473  and  0.750053123404081
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(1.0323, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.8188, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(1.0646, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(1.1869, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.5610, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  7  for split with score  1.1868631506751202
# Running partition
# PARTITION: Splitting node  7  from  0.75  to  0.8125  to  0.875
# PARTITION: New node  9  new edge from  7  to  9
# PARTITION: New node  10  new edge from  7  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.14893395740086993  best tead:  1.012741521729249
# SELECT: For node  4  best x:  0.3280232265251247  best tead:  0.8012115956297532
# SELECT: For node  5  best x:  0.5831416096074066  best tead:  1.0303223540744182
# SELECT: For node  8  best x:  0.9050442358600158  best tead:  0.5520777645500844
# SELECT: For node  9  best x:  0.8032452408265962  best tead:  0.6402480673244273
# SELECT: For node  10  best x:  0.8491501500163551  best tead:  0.6371072429114831
# SELECT: Found  5  as best with score  1.0303223540744182
# Running local search
# LOCALSEARCH: Running search in node  5
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.14857071775422645  and  0.4474045987205059
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.7488428650617553  and  0.7811369130581571
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(1.0753, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.9950, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(1.1302, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.7197, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.3189, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.6869, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  5  for split with score  1.1302086881937154
# Running partition
# PARTITION: Splitting node  5  from  0.5  to  0.625  to  0.75
# PARTITION: New node  11  new edge from  5  to  11
# PARTITION: New node  12  new edge from  5  to  12
# Running subdomain selection
# SELECT: For node  3  best x:  0.16383684326741804  best tead:  1.0851272143197155
# SELECT: For node  4  best x:  0.29295283331556493  best tead:  1.0040035799371847
# SELECT: For node  8  best x:  0.9054041607744971  best tead:  0.7053774843966357
# SELECT: For node  9  best x:  0.8033240003792045  best tead:  0.34389957840558266
# SELECT: For node  10  best x:  0.8498165092735532  best tead:  0.7337033718364938
# SELECT: For node  11  best x:  0.6204749415720814  best tead:  1.0733224694394727
# SELECT: For node  12  best x:  0.6684771147100668  best tead:  0.703289165420653
# SELECT: Found  3  as best with score  1.0851272143197155
# Running local search
# LOCALSEARCH: Running search in node  3
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.3262018913778359  and  0.8579636172539316
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  1.650605399057967e-07  and  0.04598386807024684
# Observed 3 peaks
# Function evaluations to find all peaks: 137
# Time to complete search: 659.6710000000021
#
# Trial 15 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.1751, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.1751379346161868
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.015111352468789484  best tead:  1.1890833944056411
# SELECT: For node  2  best x:  0.7959505288295373  best tead:  1.252684942218605
# SELECT: Found  2  as best with score  1.252684942218605
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.24960300535081764  and  0.7863772827869565
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.7185420239443513  and  0.7810075098864356
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.2624, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.3182, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.318185428428762
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  3  new edge from  2  to  3
# PARTITION: New node  4  new edge from  2  to  4
# Running subdomain selection
# SELECT: For node  1  best x:  0.04434005883506398  best tead:  1.2592217384307796
# SELECT: For node  3  best x:  0.5000759391584908  best tead:  0.8312695416459732
# SELECT: For node  4  best x:  0.8970070347307019  best tead:  1.0446946253841798
# SELECT: Found  1  as best with score  1.2592217384307796
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.3692224788357323  and  0.36940819060783536
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  2.0150668422037692e-06  and  0.010578970171238333
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(0.7187, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.4954, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.7104, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  0.7187261259160433
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  5  new edge from  1  to  5
# PARTITION: New node  6  new edge from  1  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.690968911697672  best tead:  0.5779035147015101
# SELECT: For node  4  best x:  0.9820808530246081  best tead:  0.8075530918340359
# SELECT: For node  5  best x:  0.19814283036563696  best tead:  0.7258961937238577
# SELECT: For node  6  best x:  0.4960404727832903  best tead:  0.5091307743578979
# SELECT: Found  4  as best with score  0.8075530918340359
# Running local search
# LOCALSEARCH: Running search in node  4
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.2974727653025024  and  0.3224582278824506
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.9687484128112891  and  0.9999988835020877
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.3398, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.3298, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.2936, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.3678, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  0.36782277129571556
# Running partition
# PARTITION: Splitting node  6  from  0.25  to  0.375  to  0.5
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.6765862214039023  best tead:  0.3406627533146166
# SELECT: For node  4  best x:  0.7677904781695137  best tead:  0.3264802785598847
# SELECT: For node  5  best x:  0.1287452359453767  best tead:  0.29478623614676747
# SELECT: For node  7  best x:  0.2832777769015114  best tead:  0.41796795938555176
# SELECT: For node  8  best x:  0.3793471814201661  best tead:  0.2982774417149441
# SELECT: Found  7  as best with score  0.41796795938555176
# Running local search
# LOCALSEARCH: Running search in node  7
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.5888480244489077  and  0.8349667129806688
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.385014426320602  and  0.4174410629866615
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.3215, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.3294, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.3243, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.3377, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.2677, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  7  for split with score  0.33771024924381476
# Running partition
# PARTITION: Splitting node  7  from  0.25  to  0.3125  to  0.375
# PARTITION: New node  9  new edge from  7  to  9
# PARTITION: New node  10  new edge from  7  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.7046852459008524  best tead:  0.32395122722731345
# SELECT: For node  4  best x:  0.7674055025477822  best tead:  0.32926474981506026
# SELECT: For node  5  best x:  0.14870457125651376  best tead:  0.32029422129255325
# SELECT: For node  8  best x:  0.4635549504558817  best tead:  0.26295414024080976
# SELECT: For node  9  best x:  0.29044411348996996  best tead:  0.2341070240609402
# SELECT: For node  10  best x:  0.36093964967906805  best tead:  0.12687976702941997
# SELECT: Found  4  as best with score  0.32926474981506026
# Running local search
# LOCALSEARCH: Running search in node  4
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.19760677520956815  and  0.5870520324318793
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new turbo evaluations between  0.9999846171772433  and  0.9999989884391407
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.3659, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.3364, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.2982, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.2614, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.2135, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.1357, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  3  for split with score  0.36590797478326087
# Running partition
# PARTITION: Splitting node  3  from  0.5  to  0.625  to  0.75
# PARTITION: New node  11  new edge from  3  to  11
# PARTITION: New node  12  new edge from  3  to  12
# Running subdomain selection
# SELECT: For node  4  best x:  0.8974041383344591  best tead:  0.3325765776321671
# SELECT: For node  5  best x:  0.14832831053192816  best tead:  0.2989234448001512
# SELECT: For node  8  best x:  0.464149158398874  best tead:  0.25858860978333037
# SELECT: For node  9  best x:  0.2904830360242857  best tead:  0.21637874594155898
# SELECT: For node  10  best x:  0.36135399910789406  best tead:  0.13392229629655433
# SELECT: For node  11  best x:  0.6121038480758152  best tead:  0.37205680144210596
# SELECT: For node  12  best x:  0.6979664865446317  best tead:  0.3381160815136042
# SELECT: Found  11  as best with score  0.37205680144210596
# Running local search
# LOCALSEARCH: Running search in node  11
# tead
# tead
# LOCALSEARCH: Completed  2  new tead evaluations between  0.6758862208187109  and  0.7495483661908225
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  10  new turbo evaluations between  0.7357450967095361  and  0.7651534247118549
# Observed 5 peaks
# Function evaluations to find all peaks: 104
# Time to complete search: 664.875

# %%
# calculate summary metrics
# peak ratio
num_known_peaks = 5
# n_replications = 15
peak_ratio = sum(distinct_peaks) / (num_known_peaks * n_replications)
print("Peak ratio: {}".format(peak_ratio))
# success rate
num_successes = 0
for i in range(n_replications):
    if distinct_peaks[i] == num_known_peaks:
        num_successes += 1
success_ratio = num_successes / n_replications
print("Success ratio: {}".format(success_ratio))
print("Average function evaluations: {}".format(sum(function_evaluations)/n_replications))
# Out:
# Peak ratio: 0.9333333333333333
# Success ratio: 0.7333333333333333
# Average function evaluations: 116.13333333333334

# %%
# save data to file for potential future use
methods_list = ['PIONEER']
pr_list = [peak_ratio]
sr_list = [success_ratio]
fe_list = [function_evaluations]
import pickle
with open(datasavedir + '/' + 'mme_metrics.pkl', 'wb') as f:
    pickle.dump([methods_list, pr_list, sr_list, fe_list], f)
# to retrieve
# with open(datasavedir + '/' + 'mme_metrics.pkl') as f:
#     methods_list, pr_list, sr_list, fe_list = pickle.load(f)
