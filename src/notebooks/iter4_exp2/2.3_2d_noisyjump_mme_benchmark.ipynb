# %%
# notebook for third canonical problem for multimodal optimization looking for localized extreme
# events with agent-based military simulation
# Experiment 2.3 - Stochastic, jump discontinuity multimodal localized extrema test problem with 2d input dimension
# Part 1 - benchmark approaches (MCS, QMC, NEI, TEAD, TuRBO)
#
# Author: Alex Braafladt
# Initial creation: 3/17/23
#
# Goal: Benchmark state-of-the-art Bayesian Optimization approaches (and QMC/MCS) on a multimodal
#       optimization test function focused on localized extrema - in 2d
#
# Notes:
# -Using the BoTorch framework [1] and NEI from [4]
# -TEAD technique from [2]
# -TuRBO technique from [3]
#
# References:
# [1] M. Balandat et al., “BOTORCH: A framework for efficient Monte-Carlo Bayesian optimization,”
#     Adv. Neural Inf. Process. Syst., vol. 2020-Decem, no. MC, 2020.
# [2] S. Mo et al., “A Taylor Expansion-Based Adaptive Design Strategy for Global Surrogate
#     Modeling With Applications in Groundwater Modeling,” Water Resour. Res., vol. 53, no.
#     12, pp. 10802–10823, 2017, doi: 10.1002/2017WR021622.
# [3] D. Eriksson, M. Pearce, J. R. Gardner, R. Turner, and M. Poloczek, “Scalable global
#     optimization via local Bayesian optimization,” Adv. Neural Inf. Process. Syst., vol.
#     32, no. NeurIPS, 2019.
# [4] B. Letham, B. Karrer, G. Ottoni, and E. Bakshy, “Constrained Bayesian optimization with noisy
#     experiments,” Bayesian Anal., vol. 14, no. 2, pp. 495–519, 2019, doi: 10.1214/18-BA1110.

# %%
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from botorch import fit_gpytorch_mll
from botorch.models.gp_regression import SingleTaskGP
from gpytorch.mlls import ExactMarginalLogLikelihood
import numpy as np
import networkx as nx
from botorch.models.transforms import Normalize, Standardize


# setup
dtype = torch.double
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import warnings
from botorch.exceptions import BadInitialCandidatesWarning
warnings.filterwarnings('ignore', category=BadInitialCandidatesWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# %%
# setup file i/o
import os as os
import datetime as dt
# get current working directory
wrkdir = os.getcwd()
print('Current working directory: '+wrkdir)
# set up a data save directory for all future runs
newoutputdir = wrkdir+'\output'
if not os.path.exists(newoutputdir):
    os.makedirs(newoutputdir)
# set up a new directory to store files for the current run - updates at each new full run of notebook
curDatetime = dt.datetime.now()
datasavedir = newoutputdir + r'\\' + '2.3_mme_2d_benchmark' + str(curDatetime.strftime('%Y%m%d%H%M%S'))
if not os.path.exists(datasavedir):
    os.makedirs(datasavedir)
print('Data save directory: '+datasavedir)
# Out:
# Current working directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks\iter4_exp2
# Data save directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks\iter4_exp2\output\\2.3_mme_2d_benchmark20230317154808

# %%
# visualize canonical problem
def mme_add_2d_plot(x1, x2):
    y = (torch.exp(-(100.*(x1-0.65))**2.)) * (torch.exp(-(50.*(x2-0.65))**2.))
    y += 0.7*(torch.exp(-(100.*(x1-0.25))**2.)) * (torch.exp(-(50.*(x2-0.35))**2.))
    y += 0.8*(torch.exp(-(100.*(x1-0.8))**2.)) * (torch.exp(-(50.*(x2-0.15))**2.))
    y += 0.66*(-1.*x2*x1 + 0.1*torch.sin(30.*x1*x2)) + 0.73
    return y

x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z = mme_add_2d_plot(X1, X2)
from matplotlib import ticker, cm
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(8,6))

from matplotlib.colors import LightSource
ls = LightSource(270, 45)
rgb = ls.shade(Z.numpy(), cmap=cm.gist_earth, vert_exag=0.1, blend_mode='soft')
surf = ax.plot_surface(X1, X2, Z, cmap='Blues', shade=False, cstride=1, rstride=1, linewidth=0)
# surf = ax.plot_surface(X1, X2, Z, facecolors=rgb, shade=False)
plt.savefig(datasavedir + '/'+'2d_mean_behavior_surface'+'.png')
# Out:
# C:\Users\alexb\PycharmProjects\extrema_search\venv\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3191.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# visualizing with noise added
sigma_max = 0.12
sigma_min = 0.02
def noise_1_2d(x1, x2):
    # mean
    y = mme_add_2d_plot(x1, x2)
    # noise
    noise = torch.zeros(y.shape)
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.61) * (x1 < 0.71) * (x2 >= 0.61) * (x2 < 0.71)  # peak 1
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.21) * (x1 < 0.31) * (x2 >= 0.31) * (x2 < 0.41)  # peak 2
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.76) * (x1 < 0.84) * (x2 >= 0.11) * (x2 < 0.21)  # peak 3
    # noise += (torch.randn(y.shape) * (sigma_max - sigma_min) / (1. + torch.exp(-10.*(x1-0.2))) + sigma_min) * (x1 < 0.5) * (x2 < 0.5)
    # noise += (torch.randn(y.shape) * (sigma_max - sigma_min) / (1. + torch.exp(10.*(x1-0.75))) + sigma_min) * (x1 >= 0.5) * (x2 >= 0.5)
    noise += torch.randn(y.shape) * (sigma_max - sigma_min) * (0.4 / (torch.abs(1.25*y - 0.5) + 0.4))
    # jump
    y1 = y + noise
    y_jump = 0.2 * y1 * (x1 <= 0.45) * (x2 <= 0.58)
    y2 = y1 - y_jump
    return y2

x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z = noise_1_2d(X1, X2)
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(10,8))
surf = ax.plot_surface(X1, X2, Z, cmap='Blues', shade=False, cstride=1, rstride=1, linewidth=0)
plt.savefig(datasavedir + '/'+'2d_mme_noisyjump_surface'+'.png')

# %%
# formatting objective function to match the input format for botorch
sigma_max = 0.12
sigma_min = 0.02
def mme_add_2d(X):
    x1, x2 = X[..., 0], X[..., 1]
    y = (torch.exp(-(100.*(x1-0.65))**2.)) * (torch.exp(-(50.*(x2-0.65))**2.))
    y += 0.7*(torch.exp(-(100.*(x1-0.25))**2.)) * (torch.exp(-(50.*(x2-0.35))**2.))
    y += 0.8*(torch.exp(-(100.*(x1-0.8))**2.)) * (torch.exp(-(50.*(x2-0.15))**2.))
    y += 0.66*(-1.*x2*x1 + 0.1*torch.sin(30.*x1*x2)) + 0.73
    return y

def mme_2d(X):
    x1, x2 = X[..., 0], X[..., 1]
    # mean
    y = mme_add_2d(X)
    # noise
    noise = torch.zeros(y.shape)
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.61) * (x1 < 0.71) * (x2 >= 0.61) * (x2 < 0.71)  # peak 1
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.21) * (x1 < 0.31) * (x2 >= 0.31) * (x2 < 0.41)  # peak 2
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.76) * (x1 < 0.84) * (x2 >= 0.11) * (x2 < 0.21)  # peak 3
    # noise += (torch.randn(y.shape) * (sigma_max - sigma_min) / (1. + torch.exp(-10.*(x1-0.2))) + sigma_min) * (x1 < 0.5) * (x2 < 0.5)
    # noise += (torch.randn(y.shape) * (sigma_max - sigma_min) / (1. + torch.exp(10.*(x1-0.75))) + sigma_min) * (x1 >= 0.5) * (x2 >= 0.5)
    noise += torch.randn(y.shape) * (sigma_max - sigma_min) * (0.4 / (torch.abs(1.25*y - 0.5) + 0.4))
    # jump
    y1 = y + noise
    y_jump = 0.2 * y1 * (x1 <= 0.45) * (x2 <= 0.58)
    y2 = y1 - y_jump
    return y2

def outcome_objective(x):
    """wrapper for the outcome objective function"""
    return mme_2d(x).type_as(x).unsqueeze(-1)

# %%
# set up the GP models for use
def initialize_model(train_x, train_obj, state_dict=None):
    """function to initialize the GP model"""
    model_obj = SingleTaskGP(train_x, train_obj)
    mll = ExactMarginalLogLikelihood(model_obj.likelihood, model_obj)
    # load state_dict if it is not passed
    if state_dict is not None:
        model_obj.load_state_dict(state_dict)
    return mll, model_obj

# set up the initial data set
def generate_initial_data(n=10):
    """generate initial set of data to get started with BO loop"""
    train_x = torch.rand(10, 2, device=device, dtype=dtype)
    exact_obj = outcome_objective(train_x)
    train_obj = exact_obj
    best_observed_value = exact_obj.max().item()
    return train_x, train_obj, best_observed_value

# set up the acquisition function operations for botorch
BATCH_SIZE = 1  # only doing one parallel objective function evaluation
from botorch.optim import optimize_acqf
NUM_RESTARTS = 10
RAW_SAMPLES = 512
bounds = torch.tensor([[0.0, 1.0],[0.0, 1.0]], device=device, dtype=dtype)
def optimize_acqf_and_get_observation(acq_func):
    """Optimizes the acquisition function, and returns a new candidate and a noisy observation"""
    # optimize
    candidates, _ = optimize_acqf(
        acq_function=acq_func,
        bounds=bounds,
        q=BATCH_SIZE,
        num_restarts=NUM_RESTARTS,
        raw_samples=RAW_SAMPLES,# initialization heuristic
        options={"batch_limit": 5, "maxiter": 200},
    )
    # observe new values
    new_x = candidates.detach()
    new_obj = outcome_objective(new_x)
    return new_x, new_obj

def update_random_observation():
    """Simulates a random policy by taking the current list of best values observed
    randomly, drawing a new random point, observing its value, and updating the list
    """
    rand_x = torch.rand(BATCH_SIZE, 2)  # drawing from random uniform
    next_random_best = outcome_objective(rand_x)
    return  rand_x, next_random_best

# %%
# metrics functions
def count_number_peaks_observed_2d(x_obs, y_obs, num_known_peaks=3):
    """Function to count the number of peaks observed for the mme_noise_jump_1d function"""
    peak1, peak2, peak3 = False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.64 <= x[0] <= 0.66 and 0.64 <= x[1] <= 0.66:
            if y >= 1.37:
                peak1 = True
        elif 0.24 <= x[0] <= 0.26 and 0.34 <= x[1] <= 0.36:
            if y >= 1.06:
                peak2 = True
        elif 0.79 <= x[0] <= 0.81 and 0.14 <= x[1] <= 0.16:
            if y >= 1.36:
                peak3 = True
    num_peaks_observed = peak1 + peak2 + peak3
    return num_peaks_observed


def count_evaluations_for_all_peaks_2d(x_obs, y_obs):
    """Count the number of function evaluations before finding all peaks"""
    i = 0
    num_evals_for_all_peaks = x_obs.shape[0]
    peak1, peak2, peak3 = False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.64 <= x[0] <= 0.66 and 0.64 <= x[1] <= 0.66:
            if y >= 1.37:
                peak1 = True
        elif 0.24 <= x[0] <= 0.26 and 0.34 <= x[1] <= 0.36:
            if y >= 1.06:
                peak2 = True
        elif 0.79 <= x[0] <= 0.81 and 0.14 <= x[1] <= 0.16:
            if y >= 1.36:
                peak3 = True
        i += 1
        if peak1 and peak2 and peak3:
            num_evals_for_all_peaks = i
            break
    return num_evals_for_all_peaks

# %%
# set up Bayesian optimization loop
from extremasearch.acquisition.nturbo import ngenerate_batch, NdTurboState, nd_new_update_state
from extremasearch.acquisition.qtead import nglobal_tead
import time
from botorch.sampling import SobolQMCNormalSampler
from botorch.acquisition.monte_carlo import qNoisyExpectedImprovement
from extremasearch.local.localsearch import initialize_scaled_model

N_TRIALS = 1
N_BATCH = 390 # note +10 for total iteration limit
MC_SAMPLES = 256
dim = 2
N_CANDIDATES = min(5000, max(2000, 200 * dim))
BATCH_SIZE = 1

verbose = True
import warnings
warnings.filterwarnings('ignore', category=BadInitialCandidatesWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# set up arrays to hold arrays of data
# best values
best_observed_all_nei, best_observed_random_all, best_observed_all_tead = [], [], []
best_observed_all_turbo = []
# {x, y} values
x_observed_all_random, x_observed_all_nei, x_observed_all_tead = [], [], []
y_observed_all_random, y_observed_all_nei, y_observed_all_tead = [], [], []
x_observed_all_turbo = []
y_observed_all_turbo = []

# mmo results
distinct_peaks_random, distinct_peaks_nei, distinct_peaks_tead = [], [], []
function_evals_random, function_evals_nei, function_evals_tead = [], [], []
distinct_peaks_turbo = []
function_evals_turbo = []

# going to average over N_TRIALS
for trial in range(1, N_TRIALS + 1):
    print(f"\nTrial {trial:>2} of {N_TRIALS} ", end="")
    # set up arrays to hold data for this trial
    best_observed_nei, best_observed_random, best_observed_tead = [], [], []
    best_observed_turbo = []

    # generate initial training data and initial model for this trial
    # nei
    # use same initial training points
    train_x_nei, train_obj_nei, best_observed_value_nei = generate_initial_data(n=10)
    mll_nei, model_nei = initialize_model(train_x_nei, train_obj_nei)
    # tead
    # use same initial points
    train_x_tead, train_obj_tead = train_x_nei, train_obj_nei
    best_observed_value_tead = best_observed_value_nei
    mll_tead, model_tead = initialize_model(train_x_tead, train_obj_tead)
    # turbo
    train_x_turbo, train_obj_turbo = train_x_nei, train_obj_nei
    best_observed_value_turbo = best_observed_value_nei
    # turbo initialization
    state = NdTurboState(dim=2, batch_size=BATCH_SIZE, center=torch.tensor(0.5), lb=torch.tensor(0.0), ub=torch.tensor(1.0))
    state = nd_new_update_state(state, train_x_turbo, train_obj_turbo, torch.DoubleTensor([best_observed_value_turbo]))
    tr_x_turbo, tr_obj_turbo = state.get_training_samples_in_region()
    mll_turbo, model_turbo = initialize_scaled_model(tr_x_turbo, tr_obj_turbo)
    # random
    train_x_random, train_obj_random = train_x_nei, train_obj_nei
    best_observed_value_random = best_observed_value_nei

    # start collection of results from random initialization
    best_observed_nei.append(best_observed_value_nei)
    best_observed_random.append(best_observed_value_nei)
    best_observed_tead.append(best_observed_value_tead)
    best_observed_turbo.append(best_observed_value_turbo)
    best_observed_random.append(best_observed_value_random)

    # for N_BATCH rounds of BO after the initial random batch
    for iteration in range(1, N_BATCH + 1):
        t0 = time.monotonic()
        # fit models
        fit_gpytorch_mll(mll_nei)
        fit_gpytorch_mll(mll_tead)
        fit_gpytorch_mll(mll_turbo)

        # set up the sampler to use with the acq funcs
        qmc_sampler = SobolQMCNormalSampler(sample_shape=MC_SAMPLES)

        # set up the acquisition functions
        qNEI = qNoisyExpectedImprovement(
            model=model_nei,
            X_baseline=train_x_nei,
            sampler=qmc_sampler,
        )

        # optimize the acquisition functions
        new_x_nei, new_obj_nei = optimize_acqf_and_get_observation(qNEI)
        new_x_tead = nglobal_tead(model_tead)
        new_obj_tead = outcome_objective(new_x_tead)
        new_x_turbo = ngenerate_batch(
            state=state,
            model=model_turbo,
            dim=state.train_x.shape[-1],
            x=state.train_x,
            y=state.train_y,
            batch_size=BATCH_SIZE,
            n_candidates=N_CANDIDATES,
            num_restarts=NUM_RESTARTS,
            raw_samples=RAW_SAMPLES,
            acqf='ts',
        )
        new_obj_turbo = outcome_objective(new_x_turbo)
        # random
        new_x_random, new_obj_random = update_random_observation()

        # update training points
        train_x_nei = torch.cat([train_x_nei, new_x_nei])
        train_obj_nei = torch.cat([train_obj_nei, new_obj_nei])
        train_x_tead = torch.cat([train_x_tead, new_x_tead])
        train_obj_tead = torch.cat([train_obj_tead, new_obj_tead])
        train_x_turbo = torch.cat([train_x_turbo, new_x_turbo])
        train_obj_turbo = torch.cat([train_obj_turbo, new_obj_turbo])
        train_x_random = torch.cat([train_x_random, new_x_random])
        train_obj_random = torch.cat([train_obj_random, new_obj_random])

        # update trust region
        state = nd_new_update_state(state, x_train=train_x_turbo, y_train=train_obj_turbo, y_next=new_obj_turbo)

        # update progress data
        best_value_random = train_obj_random.max()
        best_observed_random.append(best_value_random)
        best_value_nei = train_obj_nei.max()
        best_observed_nei.append(best_value_nei)
        best_value_tead = train_obj_tead.max()
        best_observed_tead.append(best_value_tead)
        best_value_turbo = train_obj_turbo.max()
        best_observed_turbo.append(best_value_turbo)

        # reinitialize the models so that they're ready to fit on the next iteration
        # state dict passed to speed up fitting
        mll_nei, model_nei = initialize_model(
            train_x_nei,
            train_obj_nei,
            model_nei.state_dict(),
        )
        mll_tead, model_tead = initialize_model(
            train_x_tead,
            train_obj_tead,
            model_tead.state_dict(),
        )
        # update trust region model
        tr_x_turbo, tr_obj_turbo = state.get_training_samples_in_region()
        mll_turbo, model_turbo = initialize_scaled_model(tr_x_turbo, tr_obj_turbo)

        t1 = time.monotonic()

        if verbose:
            print(
                f"\nBatch {iteration:>2}: best_value (random, qNEI, TEAD, TuRBO) = "
                f"({best_value_random:>4.2f}, {best_value_nei:>4.2f}, {best_value_tead:>4.2f}, {state.best_value:>4.2f}), "
                f"time = {t1-t0:>4.2f}.", end=""
            )
        else:
            print(".", end="")

    # collect observations from trial
    best_observed_all_nei.append(best_observed_nei)
    best_observed_random_all.append(best_observed_random)
    best_observed_all_tead.append(best_observed_tead)
    best_observed_all_turbo.append(best_observed_turbo)
    x_observed_all_random.append(train_x_random)
    x_observed_all_nei.append(train_x_nei)
    x_observed_all_tead.append(train_x_tead)
    x_observed_all_turbo.append(train_x_turbo)
    y_observed_all_random.append(train_obj_random)
    y_observed_all_nei.append(train_obj_nei)
    y_observed_all_tead.append(train_obj_tead)
    y_observed_all_turbo.append(train_obj_turbo)
    # collect metrics
    distinct_peaks_random.append(count_number_peaks_observed_2d(train_x_random, train_obj_random))
    distinct_peaks_nei.append(count_number_peaks_observed_2d(train_x_nei, train_obj_nei))
    distinct_peaks_tead.append(count_number_peaks_observed_2d(train_x_tead, train_obj_tead))
    distinct_peaks_turbo.append(count_number_peaks_observed_2d(train_x_turbo, train_obj_turbo))
    function_evals_random.append(count_evaluations_for_all_peaks_2d(train_x_random, train_obj_random))
    function_evals_nei.append(count_evaluations_for_all_peaks_2d(train_x_nei, train_obj_nei))
    function_evals_tead.append(count_evaluations_for_all_peaks_2d(train_x_tead, train_obj_tead))
    function_evals_turbo.append(count_evaluations_for_all_peaks_2d(train_x_turbo, train_obj_turbo))
# Out:
# Trial  1 of 1
# Batch  1: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.78, 0.67, 0.67), time = 8.80.
# Batch  2: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.78, 0.67, 0.67), time = 8.28.
# Batch  3: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.78, 0.67, 0.67), time = 8.28.
# Batch  4: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.78, 0.67, 0.67), time = 9.14.
# Batch  5: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.78, 0.67, 0.67), time = 9.38.
# Batch  6: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.78, 0.67, 0.67), time = 8.36.
# Batch  7: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.78, 0.82, 0.67), time = 9.33.
# Batch  8: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.80, 0.82, 0.67), time = 8.25.
# Batch  9: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.80, 0.82, 0.67), time = 8.12.
# Batch 10: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.80, 0.82, 0.67), time = 8.02.
# Batch 11: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.80, 0.82, 0.67), time = 8.05.
# Batch 12: best_value (random, qNEI, TEAD, TuRBO) = (0.73, 0.80, 0.82, 0.67), time = 8.02.
# Batch 13: best_value (random, qNEI, TEAD, TuRBO) = (0.77, 0.80, 0.82, 0.67), time = 10.62.
# Batch 14: best_value (random, qNEI, TEAD, TuRBO) = (0.77, 0.80, 0.82, 0.67), time = 8.20.
# Batch 15: best_value (random, qNEI, TEAD, TuRBO) = (0.77, 0.80, 0.82, 0.67), time = 10.17.
# Batch 16: best_value (random, qNEI, TEAD, TuRBO) = (0.77, 0.80, 0.82, 0.67), time = 9.28.
# Batch 17: best_value (random, qNEI, TEAD, TuRBO) = (0.77, 0.80, 0.82, 0.67), time = 9.23.
# Batch 18: best_value (random, qNEI, TEAD, TuRBO) = (0.77, 0.80, 0.82, 0.67), time = 8.94.
# TuRBO restart triggered
#
# Batch 19: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.80, 0.82, 0.67), time = 11.11.
# Batch 20: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.81, 0.82, 0.67), time = 9.19.
# Batch 21: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.81, 0.82, 0.67), time = 11.62.
# Batch 22: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.81, 0.82, 0.67), time = 9.45.
# Batch 23: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 8.38.
# Batch 24: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 12.31.
# Batch 25: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 11.67.
# Batch 26: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 12.28.
# Batch 27: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 14.11.
# Batch 28: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 9.27.
# Batch 29: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.89.
# Batch 30: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.59.
# Batch 31: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 8.70.
# Batch 32: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 9.80.
# Batch 33: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 11.89.
# Batch 34: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.33.
# Batch 35: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 11.31.
# Batch 36: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 15.77.
# Batch 37: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 8.55.
# Batch 38: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.98.
# Batch 39: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 8.44.
# Batch 40: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.50.
# Batch 41: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 8.92.
# Batch 42: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 8.80.
# TuRBO restart triggered
#
# Batch 43: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 8.58.
# Batch 44: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 8.77.
# Batch 45: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 9.66.
# Batch 46: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 8.89.
# Batch 47: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 8.77.
# Batch 48: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.75.
# Batch 49: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 9.34.
# Batch 50: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.17.
# Batch 51: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.38.
# Batch 52: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 11.83.
# Batch 53: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.39.
# Batch 54: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 11.38.
# Batch 55: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 12.31.
# Batch 56: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.30.
# Batch 57: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.41.
# Batch 58: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 13.09.
# Batch 59: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 11.84.
# Batch 60: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 9.86.
# Batch 61: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.33.
# Batch 62: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 9.62.
# Batch 63: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 10.03.
# Batch 64: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 12.17.
# Batch 65: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.67), time = 15.58.
# Batch 66: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 9.53.
# Batch 67: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 10.36.
# Batch 68: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 15.03.
# Batch 69: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 14.16.
# TuRBO restart triggered
#
# Batch 70: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 11.72.
# Batch 71: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 14.59.
# Batch 72: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 13.28.
# Batch 73: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 14.92.
# Batch 74: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 10.83.
# Batch 75: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 10.00.
# Batch 76: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 15.80.
# Batch 77: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 11.91.
# Batch 78: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 13.69.
# Batch 79: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 11.64.
# Batch 80: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 13.58.
# Batch 81: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 15.66.
# Batch 82: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 11.33.
# Batch 83: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 10.66.
# Batch 84: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 13.94.
# Batch 85: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 16.58.
# Batch 86: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.83, 0.82, 0.69), time = 13.42.
# Batch 87: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.84, 0.82, 0.69), time = 14.20.
# Batch 88: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.84, 0.82, 0.69), time = 14.06.
# Batch 89: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.84, 0.82, 0.69), time = 16.75.
# Batch 90: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.84, 0.82, 0.69), time = 17.03.
# Batch 91: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.84, 0.82, 0.69), time = 16.50.
# Batch 92: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.84, 0.82, 0.69), time = 14.09.
# Batch 93: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 13.74.
# TuRBO restart triggered
#
# Batch 94: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 15.12.
# Batch 95: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 18.78.
# Batch 96: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 14.59.
# Batch 97: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.23.
# Batch 98: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 15.08.
# Batch 99: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 16.66.
# Batch 100: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 14.50.
# Batch 101: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 14.22.
# Batch 102: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 16.28.
# Batch 103: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 12.14.
# Batch 104: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 12.84.
# Batch 105: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.39.
# Batch 106: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 17.50.
# Batch 107: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 17.45.
# Batch 108: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 16.84.
# Batch 109: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 17.39.
# Batch 110: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 16.39.
# Batch 111: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.36.
# Batch 112: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 18.25.
# Batch 113: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 18.41.
# Batch 114: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.02.
# Batch 115: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 17.27.
# Batch 116: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 16.83.
# Batch 117: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 15.78.
# TuRBO restart triggered
#
# Batch 118: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 17.77.
# Batch 119: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 21.00.
# Batch 120: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 23.70.
# Batch 121: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 22.28.
# Batch 122: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 17.89.
# Batch 123: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 17.62.
# Batch 124: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 17.92.
# Batch 125: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 17.84.
# Batch 126: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 17.98.
# Batch 127: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 17.84.
# Batch 128: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 18.36.
# Batch 129: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 18.81.
# Batch 130: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.00.
# Batch 131: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.05.
# Batch 132: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 18.27.
# Batch 133: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.38.
# Batch 134: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.31.
# Batch 135: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.19.
# Batch 136: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.50.
# Batch 137: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 21.25.
# Batch 138: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.94.
# Batch 139: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.77.
# Batch 140: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 21.53.
# Batch 141: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.38.
# TuRBO restart triggered
#
# Batch 142: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.00.
# Batch 143: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.86.
# Batch 144: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.44.
# Batch 145: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.59.
# Batch 146: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.06.
# Batch 147: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.58.
# Batch 148: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.95.
# Batch 149: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.59.
# Batch 150: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.92.
# Batch 151: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.38.
# Batch 152: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.84.
# Batch 153: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.14.
# Batch 154: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 22.03.
# Batch 155: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.17.
# Batch 156: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 19.91.
# Batch 157: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.31.
# Batch 158: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.55.
# Batch 159: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.27.
# Batch 160: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 22.38.
# Batch 161: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.75.
# Batch 162: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.59.
# Batch 163: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 21.01.
# Batch 164: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 20.99.
# Batch 165: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 21.30.
# TuRBO restart triggered
#
# Batch 166: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 23.14.
# Batch 167: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 21.44.
# Batch 168: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 21.38.
# Batch 169: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 21.81.
# Batch 170: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 21.31.
# Batch 171: best_value (random, qNEI, TEAD, TuRBO) = (0.84, 0.85, 0.82, 0.69), time = 21.70.
# Batch 172: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.85, 0.82, 0.69), time = 21.98.
# Batch 173: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.85, 0.82, 0.69), time = 23.19.
# Batch 174: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.85, 0.82, 0.69), time = 21.59.
# Batch 175: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.85, 0.82, 0.69), time = 21.78.
# Batch 176: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.85, 0.82, 0.69), time = 22.00.
# Batch 177: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.85, 0.82, 0.69), time = 22.06.
# Batch 178: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 22.59.
# Batch 179: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 24.34.
# Batch 180: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 22.19.
# Batch 181: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 22.97.
# Batch 182: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 22.69.
# Batch 183: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 22.58.
# Batch 184: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 22.86.
# Batch 185: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 23.34.
# Batch 186: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 25.20.
# Batch 187: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 22.97.
# Batch 188: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 23.27.
# Batch 189: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 23.73.
# TuRBO restart triggered
#
# Batch 190: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 23.97.
# Batch 191: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 23.69.
# Batch 192: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 25.91.
# Batch 193: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 24.66.
# Batch 194: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 24.16.
# Batch 195: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 24.64.
# Batch 196: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 24.80.
# Batch 197: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 24.89.
# Batch 198: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 25.09.
# Batch 199: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 26.92.
# Batch 200: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 25.02.
# Batch 201: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 24.94.
# Batch 202: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 25.69.
# Batch 203: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 24.81.
# Batch 204: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 25.61.
# Batch 205: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 26.16.
# Batch 206: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 28.59.
# Batch 207: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 25.92.
# Batch 208: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 26.00.
# Batch 209: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 26.02.
# Batch 210: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 26.17.
# Batch 211: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 26.19.
# Batch 212: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 27.17.
# Batch 213: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 28.16.
# TuRBO restart triggered
#
# Batch 214: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 27.02.
# Batch 215: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 27.00.
# Batch 216: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 27.34.
# Batch 217: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 27.80.
# Batch 218: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 27.59.
# Batch 219: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 27.50.
# Batch 220: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 29.72.
# Batch 221: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 27.88.
# Batch 222: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 27.59.
# Batch 223: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 28.69.
# Batch 224: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 37.05.
# Batch 225: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 28.80.
# Batch 226: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 30.11.
# Batch 227: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 30.41.
# Batch 228: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 28.23.
# Batch 229: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 28.48.
# Batch 230: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 28.66.
# Batch 231: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 29.00.
# Batch 232: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 29.17.
# Batch 233: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 29.30.
# Batch 234: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 31.55.
# Batch 235: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 29.36.
# Batch 236: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 29.28.
# Batch 237: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 29.81.
# TuRBO restart triggered
#
# Batch 238: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 30.09.
# Batch 239: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.69), time = 30.19.
# Batch 240: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 30.83.
# Batch 241: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 33.77.
# Batch 242: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 31.47.
# Batch 243: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 31.41.
# Batch 244: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 31.31.
# Batch 245: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 31.06.
# Batch 246: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 32.33.
# Batch 247: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 31.69.
# Batch 248: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 33.55.
# Batch 249: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 24.42.
# Batch 250: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 24.91.
# Batch 251: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 24.83.
# Batch 252: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 24.70.
# Batch 253: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 24.84.
# Batch 254: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 25.23.
# Batch 255: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 24.84.
# Batch 256: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 25.39.
# Batch 257: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 25.55.
# Batch 258: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 25.94.
# Batch 259: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 25.94.
# Batch 260: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 25.81.
# Batch 261: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 26.05.
# Batch 262: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 26.23.
# Batch 263: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 26.89.
# TuRBO restart triggered
#
# Batch 264: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 28.62.
# Batch 265: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 26.72.
# Batch 266: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.70), time = 27.31.
# Batch 267: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.74), time = 27.38.
# Batch 268: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.74), time = 27.53.
# Batch 269: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.74), time = 27.50.
# Batch 270: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.74), time = 27.27.
# Batch 271: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 27.50.
# Batch 272: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 28.03.
# Batch 273: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 27.84.
# Batch 274: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 28.03.
# Batch 275: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 32.55.
# Batch 276: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 31.73.
# Batch 277: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 34.97.
# Batch 278: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 38.08.
# Batch 279: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 34.28.
# Batch 280: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 38.14.
# Batch 281: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 39.42.
# Batch 282: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 37.48.
# Batch 283: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 37.38.
# Batch 284: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 37.81.
# Batch 285: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 37.98.
# Batch 286: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 39.19.
# Batch 287: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 37.81.
# Batch 288: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 38.44.
# Batch 289: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 40.31.
# Batch 290: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.80), time = 39.59.
# Batch 291: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.86, 0.82, 0.81), time = 39.31.
# Batch 292: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 40.78.
# Batch 293: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 40.08.
# Batch 294: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 39.70.
# Batch 295: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 42.31.
# Batch 296: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 40.98.
# Batch 297: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 41.17.
# Batch 298: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 40.94.
# TuRBO restart triggered
#
# Batch 299: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 42.42.
# Batch 300: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 40.77.
# Batch 301: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 41.38.
# Batch 302: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 41.01.
# Batch 303: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 43.00.
# Batch 304: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 40.97.
# Batch 305: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 41.78.
# Batch 306: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 43.36.
# Batch 307: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 42.25.
# Batch 308: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 42.01.
# Batch 309: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 42.14.
# Batch 310: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 43.95.
# Batch 311: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 44.33.
# Batch 312: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 42.91.
# Batch 313: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 43.38.
# Batch 314: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 44.34.
# Batch 315: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 45.50.
# Batch 316: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.81), time = 44.22.
# Batch 317: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.82), time = 44.19.
# Batch 318: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.82), time = 44.98.
# Batch 319: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.82), time = 45.02.
# Batch 320: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 47.26.
# Batch 321: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 45.03.
# Batch 322: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 46.14.
# Batch 323: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 45.58.
# Batch 324: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 48.39.
# Batch 325: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 47.06.
# Batch 326: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 46.33.
# Batch 327: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 46.88.
# TuRBO restart triggered
#
# Batch 328: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 47.47.
# Batch 329: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 49.20.
# Batch 330: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 47.00.
# Batch 331: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 47.33.
# Batch 332: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 47.91.
# Batch 333: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 47.31.
# Batch 334: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 50.62.
# Batch 335: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 48.34.
# Batch 336: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 48.02.
# Batch 337: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 49.30.
# Batch 338: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 52.59.
# Batch 339: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 53.83.
# Batch 340: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 54.08.
# Batch 341: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 53.64.
# Batch 342: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.82, 0.88), time = 59.80.
# Batch 343: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 62.05.
# Batch 344: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 55.12.
# Batch 345: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 51.09.
# Batch 346: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 58.45.
# Batch 347: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 59.47.
# Batch 348: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 61.45.
# Batch 349: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 57.14.
# Batch 350: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 56.91.
# Batch 351: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 55.91.
# TuRBO restart triggered
#
# Batch 352: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 65.05.
# Batch 353: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 67.89.
# Batch 354: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 67.75.
# Batch 355: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 67.69.
# Batch 356: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 70.36.
# Batch 357: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 68.89.
# Batch 358: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 69.08.
# Batch 359: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 69.97.
# Batch 360: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 66.09.
# Batch 361: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 69.66.
# Batch 362: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 70.91.
# Batch 363: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 71.98.
# Batch 364: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 71.31.
# Batch 365: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 73.08.
# Batch 366: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 73.55.
# Batch 367: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 71.78.
# Batch 368: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 74.45.
# Batch 369: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 73.27.
# Batch 370: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 74.55.
# Batch 371: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 74.00.
# Batch 372: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 76.81.
# Batch 373: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 74.58.
# Batch 374: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 77.44.
# Batch 375: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 75.11.
# TuRBO restart triggered
#
# Batch 376: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 76.81.
# Batch 377: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 75.06.
# Batch 378: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 77.34.
# Batch 379: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 76.73.
# Batch 380: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 76.58.
# Batch 381: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 78.19.
# Batch 382: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 78.75.
# Batch 383: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 78.84.
# Batch 384: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 77.91.
# Batch 385: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 79.83.
# Batch 386: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 77.72.
# Batch 387: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 78.69.
# Batch 388: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 80.33.
# Batch 389: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 79.16.
# Batch 390: best_value (random, qNEI, TEAD, TuRBO) = (0.89, 0.88, 0.87, 0.88), time = 80.78.

# %%
# abbreviated QMC loop with Sobol sequences
from torch.quasirandom import SobolEngine

best_observed_all_sobol = []
x_observed_all_sobol, y_observed_all_sobol = [], []
distinct_peaks_sobol = []
function_evals_sobol = []
for trial in range(1, N_TRIALS + 1):
    print(f"\nSobol Trial {trial:>2} of {N_TRIALS} ", end="")
    best_observed_sobol = []
    # get sobol random samples for the trial
    X_Sobol = SobolEngine(dimension=2, scramble=True).draw(N_BATCH+10).to(dtype=dtype, device=device)
    Y_Sobol = torch.tensor([outcome_objective(x) for x in X_Sobol], dtype=dtype, device=device)
    curMax = torch.max(Y_Sobol[:10])
    for y_val in Y_Sobol[10:]:
        curMax = torch.max(curMax,y_val)
        best_observed_sobol.append(curMax.squeeze())
    best_observed_all_sobol.append(best_observed_sobol)
    x_observed_all_sobol.append(X_Sobol)
    y_observed_all_sobol.append(Y_Sobol)
    distinct_peaks_sobol.append(count_number_peaks_observed_2d(X_Sobol, Y_Sobol))
    function_evals_sobol.append(count_evaluations_for_all_peaks_2d(X_Sobol, Y_Sobol))
# Out:
# Sobol Trial  1 of 1

# %%
# collect output data
# calculate summary metrics
# peak ratio
num_known_peaks = 3
peak_ratio_random = sum(distinct_peaks_random) / (num_known_peaks * N_TRIALS)
peak_ratio_nei = sum(distinct_peaks_nei) / (num_known_peaks * N_TRIALS)
peak_ratio_tead = sum(distinct_peaks_tead) / (num_known_peaks * N_TRIALS)
peak_ratio_turbo = sum(distinct_peaks_turbo) / (num_known_peaks * N_TRIALS)
peak_ratio_sobol = sum(distinct_peaks_sobol) / (num_known_peaks * N_TRIALS)
print(f"Peak ratio: Random {peak_ratio_random:>4.2f}, NEI {peak_ratio_nei:>4.2f}, TEAD {peak_ratio_tead:>4.2f}, TuRBO {peak_ratio_turbo:>4.2f}, QMC {peak_ratio_sobol:>4.2f} ")
# success rate
num_successes_random = 0
num_successes_nei = 0
num_successes_tead = 0
num_successes_turbo = 0
num_successes_sobol = 0
for i in range(N_TRIALS):
    if distinct_peaks_random[i] == 3:
        num_successes_random += 1
    if distinct_peaks_nei[i] == 3:
        num_successes_nei += 1
    if distinct_peaks_tead[i] == 3:
        num_successes_tead += 1
    if distinct_peaks_turbo[i] == 3:
        num_successes_turbo += 1
    if distinct_peaks_sobol[i] == 3:
        num_successes_sobol += 1
success_ratio_random = num_successes_random / N_TRIALS
success_ratio_nei = num_successes_nei / N_TRIALS
success_ratio_tead = num_successes_tead / N_TRIALS
success_ratio_turbo = num_successes_turbo / N_TRIALS
success_ratio_sobol = num_successes_sobol / N_TRIALS
print(f"Success ratio: Random {success_ratio_random:>4.2f}, NEI {success_ratio_nei:>4.2f}, TEAD {success_ratio_tead:>4.2f}, TuRBO {success_ratio_turbo:>4.2f}, Sobol {success_ratio_sobol:>4.2f}")
# function evaluations
fe_random = sum(function_evals_random)/N_TRIALS
fe_nei = sum(function_evals_nei)/N_TRIALS
fe_tead = sum(function_evals_tead)/N_TRIALS
fe_turbo = sum(function_evals_turbo)/N_TRIALS
fe_sobol = sum(function_evals_sobol)/N_TRIALS
print(f"Average function evaluations: Random {fe_random}, NEI {fe_nei}, TEAD {fe_tead}, TuRBO {fe_turbo}, Sobol {fe_sobol}")
# Out:
# Peak ratio: Random 0.00, NEI 0.00, TEAD 0.00, TuRBO 0.00, QMC 0.00
# Success ratio: Random 0.00, NEI 0.00, TEAD 0.00, TuRBO 0.00, Sobol 0.00
# Average function evaluations: Random 400.0, NEI 400.0, TEAD 400.0, TuRBO 400.0, Sobol 400.0

# %%
fit_gpytorch_mll(mll_nei)
fit_gpytorch_mll(mll_tead)
fit_gpytorch_mll(mll_turbo)
None

# %%
# plot evaluations for tead - surface
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z = noise_1_2d(X1, X2)
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(10,8))
surf = ax.plot_surface(X1, X2, Z, cmap='Blues', shade=False, cstride=1, rstride=1, linewidth=0, alpha=0.2)
ax.scatter(train_x_tead[:,0].numpy()[0:10], train_x_tead[:,1].numpy()[0:10], train_obj_tead.numpy()[0:10], marker='.', color='tab:orange', s=40)
ax.scatter(train_x_tead[:,0].numpy()[10:], train_x_tead[:,1].numpy()[10:], train_obj_tead.numpy()[10:], marker='.', color='g', s=40)
plt.savefig(datasavedir + '/'+'2d_mme_noise_tead_evals'+'.png')

# %%
# plot evaluations for tead contour
fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, Z, levels=15, cmap='Blues')
cbar = fig1.colorbar(CS)

ax1.scatter(train_x_tead[:,0].numpy()[0:10], train_x_tead[:,1].numpy()[0:10], s=15, marker='o', color='tab:orange', zorder=2)
ax1.scatter(train_x_tead[:,0].numpy()[10:], train_x_tead[:,1].numpy()[10:], s=15, marker='o', color='g', zorder=2)
ax1.set_xlim([-0.01,1.01])
ax1.set_ylim([-0.01,1.01])
plt.savefig(datasavedir + '/'+'2d_mme_noise_tead_evals_contour'+'.png')

# %%
# plot model contours tead - mean
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z_tead_model = model_tead.posterior(torch.stack([X1.flatten(), X2.flatten()], dim=1)).mean
Z_tead_shaped = Z_tead_model.unflatten(dim=0, sizes=(100,100)).squeeze()

fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, Z_tead_shaped.detach().numpy(), levels=15, cmap='viridis')
cbar = fig1.colorbar(CS)
plt.savefig(datasavedir + '/'+'2d_mme_noise_tead_model_mean_contour'+'.png')

# %%
# plot model contours tead - standard deviation
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z_tead_model = model_tead.posterior(torch.stack([X1.flatten(), X2.flatten()], dim=1)).variance
Z_tead_shaped = Z_tead_model.unflatten(dim=0, sizes=(100,100)).squeeze()

fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, np.sqrt(Z_tead_shaped.detach().numpy()), levels=15, cmap='viridis')
cbar = fig1.colorbar(CS)
plt.savefig(datasavedir + '/'+'2d_mme_noise_tead_model_stdev_contour'+'.png')

# %%
# plot evaluations for nei
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z = noise_1_2d(X1, X2)
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(10,8))
surf = ax.plot_surface(X1, X2, Z, cmap='Blues', shade=False, cstride=1, rstride=1, linewidth=0, alpha=0.2)
ax.scatter(train_x_nei[:,0].numpy(), train_x_nei[:,1].numpy(), train_obj_nei.numpy(), marker='.', color='g')
plt.savefig(datasavedir + '/'+'2d_mme_noise_nei_evals_surface'+'.png')

# %%
# plot evaluations for nei contour
fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, Z, levels=15, cmap='Blues')
cbar = fig1.colorbar(CS)
ax1.scatter(train_x_nei[:,0].numpy()[0:10], train_x_nei[:,1].numpy()[0:10], s=15, marker='o', color='tab:orange', zorder=2)
ax1.scatter(train_x_nei[:,0].numpy()[10:], train_x_nei[:,1].numpy()[10:], s=15, marker='o', color='g', zorder=2)
ax1.set_xlim([-0.01,1.01])
ax1.set_ylim([-0.01,1.01])
plt.savefig(datasavedir + '/'+'2d_mme_noise_nei_evals_contour'+'.png')

# %%
# plot model contours nei - mean
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z_nei_model = model_nei.posterior(torch.stack([X1.flatten(), X2.flatten()], dim=1)).mean
Z_nei_shaped = Z_nei_model.unflatten(dim=0, sizes=(100,100)).squeeze()

fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, Z_nei_shaped.detach().numpy(), levels=15, cmap='viridis')
cbar = fig1.colorbar(CS)
plt.savefig(datasavedir + '/'+'2d_mme_noise_nei_model_mean_contour'+'.png')

# %%
# plot model contours nei - stdev
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z_nei_model = model_nei.posterior(torch.stack([X1.flatten(), X2.flatten()], dim=1)).variance
Z_nei_shaped = Z_nei_model.unflatten(dim=0, sizes=(100,100)).squeeze()

fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, np.sqrt(Z_nei_shaped.detach().numpy()), levels=15, cmap='viridis')
cbar = fig1.colorbar(CS)
plt.savefig(datasavedir + '/'+'2d_mme_noise_nei_model_stdev_contour'+'.png')

# %%
# plot evaluations for turbo - surface
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z = noise_1_2d(X1, X2)
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(10,8))
surf = ax.plot_surface(X1, X2, Z, cmap='Blues', shade=False, cstride=1, rstride=1, linewidth=0, alpha=0.2)
ax.scatter(train_x_turbo[:,0].numpy()[0:10], train_x_turbo[:,1].numpy()[0:10], train_obj_turbo.numpy()[0:10], marker='.', color='tab:orange', s=40)
ax.scatter(train_x_turbo[:,0].numpy()[10:], train_x_turbo[:,1].numpy()[10:], train_obj_turbo.numpy()[10:], marker='.', color='g', s=40)
plt.savefig(datasavedir + '/'+'2d_mme_noise_turbo_evals_surface'+'.png')

# %%
# plot evaluations for turbo contour
fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, Z, levels=15, cmap='Blues')
cbar = fig1.colorbar(CS)

ax1.scatter(train_x_turbo[:,0].numpy()[0:10], train_x_turbo[:,1].numpy()[0:10], s=15, marker='o', color='tab:orange', zorder=2)
ax1.scatter(train_x_turbo[:,0].numpy()[10:], train_x_turbo[:,1].numpy()[10:], s=15, marker='o', color='g', zorder=2)
ax1.set_xlim([-0.01,1.01])
ax1.set_ylim([-0.01,1.01])
plt.savefig(datasavedir + '/'+'2d_mme_noise_turbo_evals_contour'+'.png')

# %%
# plot model contours turbo - mean
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z_tead_model = model_turbo.posterior(torch.stack([X1.flatten(), X2.flatten()], dim=1)).mean
Z_tead_shaped = Z_tead_model.unflatten(dim=0, sizes=(100,100)).squeeze()

fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, Z_tead_shaped.detach().numpy(), levels=15, cmap='viridis')
cbar = fig1.colorbar(CS)
plt.savefig(datasavedir + '/'+'2d_mme_noise_turbo_model_mean_contour'+'.png')

# %%
# plot model contours turbo - standard deviation
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z_tead_model = model_turbo.posterior(torch.stack([X1.flatten(), X2.flatten()], dim=1)).variance
Z_tead_shaped = Z_tead_model.unflatten(dim=0, sizes=(100,100)).squeeze()

fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, np.sqrt(Z_tead_shaped.detach().numpy()), levels=15, cmap='viridis')
cbar = fig1.colorbar(CS)
plt.savefig(datasavedir + '/'+'2d_mme_noise_turbo_model_stdev_contour'+'.png')

# %%
# plot evaluations for sobol - surface
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z = noise_1_2d(X1, X2)
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(10,8))
surf = ax.plot_surface(X1, X2, Z, cmap='Blues', shade=False, cstride=1, rstride=1, linewidth=0, alpha=0.2)
ax.scatter(X_Sobol[:,0].numpy(), X_Sobol[:,1].numpy(), Y_Sobol.numpy(), marker='.', color='g', s=40)
plt.savefig(datasavedir + '/'+'2d_mme_noise_qmc_sobol_evals_surface'+'.png')

# %%
# plot evaluations for sobol contour
fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, Z, levels=15, cmap='Blues')
cbar = fig1.colorbar(CS)

ax1.scatter(X_Sobol[:,0].numpy(), X_Sobol[:,1].numpy(), s=15, marker='o', color='g', zorder=2)
ax1.set_xlim([-0.01,1.01])
ax1.set_ylim([-0.01,1.01])
plt.savefig(datasavedir + '/'+'2d_mme_noise_qmc_evals_contour'+'.png')

# %%
# plot evaluations for mcs - surface
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z = noise_1_2d(X1, X2)
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(10,8))
surf = ax.plot_surface(X1, X2, Z, cmap='Blues', shade=False, cstride=1, rstride=1, linewidth=0, alpha=0.2)
ax.scatter(train_x_random[:,0].numpy(), train_x_random[:,1].numpy(), train_obj_random.numpy(), marker='.', color='g', s=40)
plt.savefig(datasavedir + '/'+'2d_mme_noise_mcs_evals_surface'+'.png')

# %%
# plot evaluations for mcs contour
fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, Z, levels=15, cmap='Blues')
cbar = fig1.colorbar(CS)
ax1.scatter(train_x_random[:,0].numpy(), train_x_random[:,1].numpy(), s=15, marker='o', color='g', zorder=2)
ax1.set_xlim([-0.01,1.01])
ax1.set_ylim([-0.01,1.01])
plt.savefig(datasavedir + '/'+'2d_mme_noise_mcs_evals_contour'+'.png')

# %%
# save data to file for potential future use
methods_list = ['MCS', 'NEI', 'TEAD', 'TuRBO', 'QMC']
pr_list = [peak_ratio_random, peak_ratio_nei, peak_ratio_tead, peak_ratio_turbo, peak_ratio_sobol]
sr_list = [success_ratio_random, success_ratio_nei, success_ratio_tead, success_ratio_turbo, success_ratio_sobol]
fe_list = [function_evals_random, function_evals_nei, function_evals_tead, function_evals_turbo, function_evals_sobol]
import pickle
with open(datasavedir + '/' + 'mme_metrics.pkl', 'wb') as f:
    pickle.dump([methods_list, pr_list, sr_list, fe_list], f)
# to retrieve
# with open(datasavedir + '/' + 'mme_metrics.pkl') as f:
#     methods_list, pr_list, sr_list, fe_list = pickle.load(f)
