# %%
# Benchmark setup for performance of balanced strategy on basic canonical problem
# Created: 2/27/23
# Author: Alex Braafladt

# %%
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from extremasearch.globalmm.globalsearch import MultimodalExtremaSearch
from botorch import fit_gpytorch_mll
from botorch.models.gp_regression import SingleTaskGP
from gpytorch.mlls import ExactMarginalLogLikelihood
import numpy as np
import networkx as nx
from botorch.models.transforms import Normalize, Standardize


# setup
dtype = torch.double
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import warnings
from botorch.exceptions import BadInitialCandidatesWarning
warnings.filterwarnings('ignore', category=BadInitialCandidatesWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# %%
# setup file i/o
import os as os
import datetime as dt
# get current working directory
wrkdir = os.getcwd()
print('Current working directory: '+wrkdir)
# set up a data save directory for all future runs
newoutputdir = wrkdir+'\output'
if not os.path.exists(newoutputdir):
    os.makedirs(newoutputdir)
# set up a new directory to store files for the current run - updates at each new full run of notebook
curDatetime = dt.datetime.now()
datasavedir = newoutputdir + r'\\' + 'mme_balanced_benchmark' + str(curDatetime.strftime('%Y%m%d%H%M%S'))
if not os.path.exists(datasavedir):
    os.makedirs(datasavedir)
print('Data save directory: '+datasavedir)
# Out:
# Current working directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks
# Data save directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks\output\\mme_balanced_benchmark20230227191215

# %%
def mme_torch(x):
    x = x
    y = torch.zeros(x.shape)
    y += 0.66*(-1.*x + 0.1*torch.sin(30.*x) + torch.exp(-(100.*(x-0.65))**2.))
    y += 0.5 * ( torch.exp(-(100.*(x-0.35))**2.) )
    y += 0.4 * ( torch.exp(-(100.*(x-0.92))**2.) )
    y += 0.73
    return y

x1 = torch.linspace(0,1.0,200)
y1 = mme_torch(x1)
fig, ax = plt.subplots(1, 1, figsize=(8,6))
sns.lineplot(x=x1, y=y1, ax=ax, color='r')
plt.savefig(datasavedir + '/'+'mean_test_problem'+'.png')

# %%
def mme_noise_jump_1d_mean(x):
    y = torch.zeros(x.shape)
    y += 0.66*(-1.*x + 0.1*torch.sin(30.*x) + torch.exp(-(100.*(x-0.65))**2.)) * (x >= 0.6)
    y += 0.66*(-1.*x + 0.1*torch.sin(30.*x) - 0.25 + torch.exp(-(100.*(x-0.65))**2.)) * (x < 0.6) * (x >= 0.2)
    y += 0.66*(-1.*x + 0.1*torch.sin(30.*x) + 0.2 + torch.exp(-(100.*(x-0.65))**2.)) * (x < 0.2)
    y += 0.7 * ( torch.exp(-(100.*(x-0.35))**2.) )
    y += 0.4 * ( torch.exp(-(100.*(x-0.92))**2.) )
    y += 0.9
    return y


sigma_max = 0.12
sigma_min = 0.02


def mme_noise_jump_1d(x):
    # mean
    y = mme_noise_jump_1d_mean(x)
    # noise
    noise = torch.zeros(x.shape)
    noise += (torch.randn(x.shape) * sigma_max) * (x >= 0.61) * (x < 0.71)
    noise += (torch.randn(x.shape) * 0.5*sigma_max) * (x >= 0.31) * (x < 0.41)
    noise += (torch.randn(x.shape) * 0.8*sigma_max) * (x >= 0.90) * (x < 0.94)
    noise += (torch.randn(x.shape) * (sigma_max - sigma_min) / (1. + torch.exp(-10.*(x-0.2))) )* (x < 0.61)
    noise += (torch.randn(x.shape) * (sigma_max - sigma_min) / (1. + torch.exp(10.*(x-0.75))) ) * (x >= 0.71)
    # combined
    y_out = y + noise
    # any_neg = y_out < 0
    # if any_neg:
    #     y_out = torch.tensor(0.0)
    return y_out


x1 = torch.linspace(0,1.0,200)
y1 = mme_noise_jump_1d(x1)
fig, ax = plt.subplots(1, 1, figsize=(8,6))
sns.lineplot(x=x1, y=y1, ax=ax, color='r')
plt.savefig(datasavedir + '/'+'full_test_problem_one_realization'+'.png')

# %%
# plot noise bounds as 99% confidence interval
# generate realizations of the function
num_reals = 500
num_x = 200
x1 = torch.linspace(0,1.0,num_x)
y_reps = torch.DoubleTensor(num_x, num_reals)
y_deter = mme_noise_jump_1d_mean(x1)
for i in range(num_reals):
    y_reps[:,i] = mme_noise_jump_1d(x1)

fig, ax = plt.subplots(1, 1, figsize=(8,6))
sns.lineplot(x=x1, y=y_deter, ax=ax)
upper_99 = torch.quantile(y_reps, 0.995, dim=1)
lower_01 = torch.quantile(y_reps, 0.005, dim=1)
ax.fill_between(x1, lower_01, upper_99, color='b', alpha=0.3, label=r'99% quantiles')
plt.savefig(datasavedir + '/'+'full_test_problem_bounds'+'.png')

# %%
def outcome_objective(x):
    """wrapper for the outcome objective function"""
    # return mme_torch(X).type_as(X)
    return mme_noise_jump_1d(x).type_as(x)

# %%
# functions for getting and working with data from searches
def get_bounds(graph):
    """Get the bounds for each node in a graph to be able to plot them"""
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    bound_list = []
    node_list = []
    for n in graph_leaves:
        # get current leaf node
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_bounds = current_state.local_bounds
        node_list.append(n)
        bound_list.append(current_bounds)
    return node_list, bound_list


def get_bounds_all(graph):
    """Get the bounds for each node in a graph to be able to plot them"""
    graph_nodes = [n for n in graph]
    bound_list = []
    node_list = []
    for n in graph_nodes:
        # get current node
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_bounds = current_state.local_bounds
        node_list.append(n)
        bound_list.append(current_bounds)
    return node_list, bound_list


def plot_1d_results(mll: ExactMarginalLogLikelihood, model: SingleTaskGP, x_search, y_search, nodes, bnds, rep):
    """Plot 1d results for experiment on multi-modal optimization"""
    fit_gpytorch_mll(mll)
    x_test = torch.linspace(0, 1, 400)
    f, ax = plt.subplots(1, 1, figsize=(8, 6))
    # true objective
    # ax.plot(x_test.numpy(), outcome_objective(x_test).numpy(), 'r-', alpha=0.9, label='true objective')
    sns.lineplot(x=x1, y=y_deter, ax=ax, color='r')
    upper_99 = torch.quantile(y_reps, 0.995, dim=1)
    lower_01 = torch.quantile(y_reps, 0.005, dim=1)
    ax.fill_between(x1, lower_01, upper_99, color='r', alpha=0.3, label=r'99% quantiles')
    # final model
    mean_test = model.posterior(x_test).mean.detach().numpy()
    ax.plot(x_test.numpy(), mean_test, 'b-', alpha=0.9, label='surrogate mean')
    var_test = model.posterior(x_test).variance.detach().numpy()
    sd_test = np.sqrt(var_test)
    upper_test = mean_test + 2.0*sd_test
    lower_test = mean_test - 2.0*sd_test
    ax.fill_between(x_test.numpy(), lower_test.squeeze(), upper_test.squeeze(), color='b', alpha=0.3, label=r'surrogate 2$\sigma$')
    # training points
    ax.plot(x_search.numpy()[0:10], y_search[0:10].numpy(), '.', color='tab:orange', label='initial data')
    ax.plot(x_search.numpy()[10:], y_search[10:].numpy(), '.', color='g', label='bo data')
    # partitions
    for n, b in zip(nodes, bnds):
        ax.plot([b[0].numpy(), b[0].numpy()], [-0.05, 1.45], 'k-')
    ax.legend()
    plt.savefig(datasavedir + '/'+'1d_results_global_model_rep{}'.format(rep)+'.png')


def fit_local_models(graph):
    """Go through leaf nodes and update LocalSearchState to have local {x, y}
    based on global {x, y} that are within bounds"""
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    for n in graph_leaves:
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_state.local_model = SingleTaskGP(current_state.x_local, current_state.y_local,
                                                 input_transform=Normalize(d=current_state.x_local.shape[-1]),
                                                 outcome_transform=Standardize(m=current_state.y_local.shape[-1]))
        current_state.local_mll = ExactMarginalLogLikelihood(current_state.local_model.likelihood,
                                                             current_state.local_model)
        fit_gpytorch_mll(current_state.local_mll)


def plot_local_models_1d(graph, x_search, y_search, rep):
    """Go through leaf nodes and plot the local models only within the bounds of the node"""
    fit_local_models(graph)
    nodes, bnds = get_bounds(graph)
    x_test = torch.linspace(0, 1, 400)
    f, ax = plt.subplots(1, 1, figsize=(8, 6))
    # true objective
    # ax.plot(x_test.numpy(), outcome_objective(x_test).numpy(), 'r-', alpha=0.9, label='true objective')
    sns.lineplot(x=x1, y=y_deter, ax=ax, color='r')
    upper_99 = torch.quantile(y_reps, 0.995, dim=1)
    lower_01 = torch.quantile(y_reps, 0.005, dim=1)
    ax.fill_between(x1, lower_01, upper_99, color='r', alpha=0.3, label=r'99% quantiles')
    # local models
    graph_leaves = [n for n in graph if graph.out_degree[n] == 0]
    for n in graph_leaves:
        current_node = graph.nodes()[n]
        current_state = current_node['data']
        current_model = current_state.local_model
        current_bounds = current_state.local_bounds
        current_x_test_mask = torch.ge(x_test, current_bounds[0]) & torch.lt(x_test, current_bounds[1])
        current_x_test = x_test[current_x_test_mask]
        mean_test = current_model.posterior(current_x_test.unsqueeze(-1)).mean.detach().numpy()
        ax.plot(current_x_test.numpy(), mean_test, 'b-', alpha=0.9, label='surrogate mean')
        var_test = current_model.posterior(current_x_test.unsqueeze(-1)).variance.detach().numpy()
        sd_test = np.sqrt(var_test)
        upper_test = mean_test + 2.0 * sd_test
        lower_test = mean_test - 2.0 * sd_test
        ax.fill_between(current_x_test.numpy(), lower_test.squeeze(), upper_test.squeeze(), color='b', alpha=0.3,
                        label=r'surrogate 2$\sigma$')
    # training points
    ax.plot(x_search.numpy()[0:10], y_search[0:10].numpy(), '.', color='tab:orange', label='initial data')
    ax.plot(x_search.numpy()[10:], y_search[10:].numpy(), '.', color='g', label='bo data')
    # partitions
    for n, b in zip(nodes, bnds):
        ax.plot([b[0].numpy(), b[0].numpy()], [-0.05, 1.45], 'k-')
    # ax.legend()
    ax.set_ylim([-0.1, 1.6])
    # ax.set_xlim([0.915, 0.925])
    plt.savefig(datasavedir + '/'+'1d_results_local_models_rep{}'.format(rep)+'.png')


def plot_current_tree(global_search: MultimodalExtremaSearch, rep):
    """Save a plot of the tree structure after the search"""
    # tree figure
    T = global_search.global_state.partition_graph
    pos = nx.nx_agraph.graphviz_layout(T, prog="dot")
    # bounds to put on nodes on plot
    all_nodes, all_bounds = get_bounds_all(global_search.global_state.partition_graph)
    # positioning of bound text
    pos_attrs = {}
    for node, coords in pos.items():
        pos_attrs[node] = (coords[0]-15, coords[1])
    custom_node_attrs = {}
    for node, attrs in zip(all_nodes, all_bounds):
        custom_node_attrs[node] = str(attrs.numpy().round(decimals=3))
    # plot commands
    f, ax = plt.subplots(1, 1, figsize=(12, 8), constrained_layout=True)
    nx.draw(T, pos, with_labels=True, font_weight='bold', ax=ax)
    nx.draw_networkx_labels(T, pos_attrs, labels=custom_node_attrs, ax=ax)
    plt.savefig(datasavedir + '/'+'partition_tree_rep{}'.format(rep)+'.png')

# %%
# metrics functions
def count_number_peaks_observed(x_obs, y_obs, num_known_peaks=4):
    """Function to count the number of peaks observed for the mme_noise_jump_1d function"""
    peak1, peak2, peak3, peak4 = False, False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.03 <= x <= 0.07:
            if y >= 1.065:
                peak1 = True
        elif 0.345 <= x <= 0.355:
            if y >= 1.12:
                peak2 = True
        elif 0.645 <= x <= 0.655:
            if y >= 1.145:
                peak3 = True
        elif 0.915 <= x <= 0.925:
            if y >= 0.734:
                peak4 = True
    num_peaks_observed = peak1 + peak2 + peak3 + peak4
    return num_peaks_observed


def count_evaluations_for_all_peaks(x_obs, y_obs):
    """Count the number of function evaluations before finding all peaks"""
    i = 0
    num_evals_for_all_peaks = x_obs.shape[0]
    peak1, peak2, peak3, peak4 = False, False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.03 <= x <= 0.07:
            if y >= 1.065:
                peak1 = True
        elif 0.345 <= x <= 0.355:
            if y >= 1.12:
                peak2 = True
        elif 0.645 <= x <= 0.655:
            if y >= 1.145:
                peak3 = True
        elif 0.915 <= x <= 0.925:
            if y >= 0.734:
                peak4 = True
        i += 1
        if peak1 and peak2 and peak3 and peak4:
            num_evals_for_all_peaks = i
            break
    return num_evals_for_all_peaks

# %%
# replicated searches

# search and experiment settings
n_replications = 15
global_bounds = torch.tensor([0.0, 1.0], dtype=dtype)

# data holders
x_observed_all = []
y_observed_all = []
distinct_peaks = []
function_evaluations = []

# experiment loop
for rep in range(1, n_replications + 1):
    print(f"\nTrial {rep:>2} of {n_replications} ", end="")
    # initialize search
    current_global_search = MultimodalExtremaSearch(60,global_bounds,outcome_objective,)
    # run search
    current_global_search.run_global_search()

    # collect data
    x_observed_all.append(current_global_search.global_state.x_global)
    y_observed_all.append(current_global_search.global_state.y_global)

    # run and save plots
    # # results with global model
    # test_nodes, test_bounds = get_bounds(current_global_search.global_state.partition_graph)
    # plot_1d_results(current_global_search.global_state.global_mll, current_global_search.global_state.global_model,
    #             current_global_search.global_state.x_global, current_global_search.global_state.y_global,
    #             test_nodes, test_bounds, rep)
    # results with local model
    plot_local_models_1d(current_global_search.global_state.partition_graph,
                         current_global_search.global_state.x_global,
                         current_global_search.global_state.y_global,
                         rep)
    # partitioning results tree
    plot_current_tree(current_global_search, rep)

    # calculate metrics
    num_peaks_observed = count_number_peaks_observed(current_global_search.global_state.x_global,
                                                     current_global_search.global_state.y_global)
    print("Observed {num:} peaks".format(num=num_peaks_observed),)
    distinct_peaks.append(num_peaks_observed)
    fe = count_evaluations_for_all_peaks(current_global_search.global_state.x_global,
                                         current_global_search.global_state.y_global)
    print("Function evaluations to find all peaks: {}".format(fe))
    function_evaluations.append(fe)
# Out:
# Trial  1 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.2787, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.2787062307167538
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.4614622529669631  best tead:  1.1336495003766593
# SELECT: For node  2  best x:  0.5178761014954749  best tead:  1.1601858686724884
# SELECT: Found  2  as best with score  1.1601858686724884
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  5.152198459618173e-05  and  0.11198220227664107
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.1291, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(0.7988, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.129052010808353
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  3  new edge from  1  to  3
# PARTITION: New node  4  new edge from  1  to  4
# Running subdomain selection
# SELECT: For node  2  best x:  0.5025568625875301  best tead:  1.078998259420803
# SELECT: For node  3  best x:  0.08975300890456588  best tead:  0.1870052252798747
# SELECT: For node  4  best x:  0.49840617012036453  best tead:  0.8168490195028807
# SELECT: Found  2  as best with score  1.078998259420803
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  0.8524399713950315  and  0.9283525113586419
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  2  tead score:  tensor(1.0638, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.2684, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.1184, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  1.1183635495100985
# Running partition
# PARTITION: Splitting node  4  from  0.25  to  0.375  to  0.5
# PARTITION: New node  5  new edge from  4  to  5
# PARTITION: New node  6  new edge from  4  to  6
# Running subdomain selection
# SELECT: For node  2  best x:  0.5030255841859426  best tead:  1.1220043174618235
# SELECT: For node  3  best x:  0.0898469514063634  best tead:  0.2725626074243652
# SELECT: For node  5  best x:  0.28816201117067763  best tead:  1.1347410805658265
# SELECT: For node  6  best x:  0.38022013613532374  best tead:  1.1811136134568947
# SELECT: Found  6  as best with score  1.1811136134568947
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  10  new evaluations between  0.4746567902925819  and  0.49703849273057876
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  2  tead score:  tensor(0.5690, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.2748, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.4855, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(0.5843, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  0.5843450926428276
# Running partition
# PARTITION: Splitting node  6  from  0.375  to  0.4375  to  0.5
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  2  best x:  0.7829607335349298  best tead:  0.600941082277449
# SELECT: For node  3  best x:  0.08991791444401746  best tead:  0.2726447486888976
# SELECT: For node  5  best x:  0.28823729836974255  best tead:  0.5258791011067754
# SELECT: For node  7  best x:  0.38037532852769135  best tead:  0.516223060978932
# SELECT: For node  8  best x:  0.46810298183777665  best tead:  0.22736900445268998
# SELECT: Found  2  as best with score  0.600941082277449
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  0.6185804760943534  and  0.675402028781678
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  2  tead score:  tensor(0.3939, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.3953, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.3448, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.3082, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.0979, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  3  for split with score  0.39528256148917784
# Running partition
# PARTITION: Splitting node  3  from  0.0  to  0.125  to  0.25
# PARTITION: New node  9  new edge from  3  to  9
# PARTITION: New node  10  new edge from  3  to  10
# Running subdomain selection
# SELECT: For node  2  best x:  0.9632329932851542  best tead:  0.38537693207937335
# SELECT: For node  5  best x:  0.3319224819924577  best tead:  0.35795147789959775
# SELECT: For node  7  best x:  0.41031718181127463  best tead:  0.3034781204796875
# SELECT: For node  8  best x:  0.4681025446833379  best tead:  0.09835728455980661
# SELECT: For node  9  best x:  0.01085895951699672  best tead:  0.358309491573906
# SELECT: For node  10  best x:  0.20340490212211546  best tead:  0.3579587690047101
# SELECT: Found  2  as best with score  0.38537693207937335
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  0.6350791579797765  and  0.6517314187412517
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  2  tead score:  tensor(0.8088, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.8112, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.4157, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.2484, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.8667, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.6025, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  9  for split with score  0.8666841616801799
# Running partition
# PARTITION: Splitting node  9  from  0.0  to  0.0625  to  0.125
# PARTITION: New node  11  new edge from  9  to  11
# PARTITION: New node  12  new edge from  9  to  12
# Running subdomain selection
# SELECT: For node  2  best x:  0.772898482563864  best tead:  0.8206205375671504
# SELECT: For node  5  best x:  0.3318262345246429  best tead:  0.8327237500259066
# SELECT: For node  7  best x:  0.4101214813186553  best tead:  0.4203738317579665
# SELECT: For node  8  best x:  0.46828704306884594  best tead:  0.2502112928485402
# SELECT: For node  10  best x:  0.24863322776762742  best tead:  0.6031932999321613
# SELECT: For node  11  best x:  0.04398295415277058  best tead:  0.7220429033511236
# SELECT: For node  12  best x:  0.11858504990997551  best tead:  0.4492863316384807
# SELECT: Found  5  as best with score  0.8327237500259066
# Running local search
# LOCALSEARCH: Running search in node  5
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  0.345005439285248  and  0.36971930744411746
# Observed 4 peaks
# Function evaluations to find all peaks: 120
#
# Trial  2 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.3038, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.3038033455563016
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.47481558672726043  best tead:  0.9999806076243818
# SELECT: For node  2  best x:  0.6497940907942288  best tead:  1.3835725817071387
# SELECT: Found  2  as best with score  1.3835725817071387
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  0.01250154651323887  and  0.0977162358872089
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.0860, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.0424, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.085964269709359
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  3  new edge from  1  to  3
# PARTITION: New node  4  new edge from  1  to  4
# Running subdomain selection
# SELECT: For node  2  best x:  0.9708372523446084  best tead:  1.3471300004953295
# SELECT: For node  3  best x:  0.0004617317756706536  best tead:  0.19301958159664628
# SELECT: For node  4  best x:  0.3496275225829093  best tead:  1.2903596132787174
# SELECT: Found  2  as best with score  1.3471300004953295
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  4.774107829369774e-07  and  0.11603675957289175
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  2  tead score:  tensor(1.1222, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.0748, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.0566, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.122173774928295
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  5  new edge from  2  to  5
# PARTITION: New node  6  new edge from  2  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.08714761650557924  best tead:  0.07391757539816775
# SELECT: For node  4  best x:  0.30380065298638076  best tead:  1.0461574507261968
# SELECT: For node  5  best x:  0.582161751541597  best tead:  0.8198652298966255
# SELECT: For node  6  best x:  0.8775697678111282  best tead:  1.254615400393477
# SELECT: Found  6  as best with score  1.254615400393477
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  0.340611273317611  and  0.3617090227892754
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.6364, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.0912, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(1.0707, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(1.1346, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  1.1345833591934795
# Running partition
# PARTITION: Splitting node  6  from  0.75  to  0.875  to  1.0
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.15689880097308515  best tead:  0.62698454740865
# SELECT: For node  4  best x:  0.4334298355618125  best tead:  1.0889027255596107
# SELECT: For node  5  best x:  0.58214657206481  best tead:  1.0480771032046512
# SELECT: For node  7  best x:  0.7726323408123751  best tead:  0.7847422692367015
# SELECT: For node  8  best x:  0.8883696104019855  best tead:  1.0695923869187518
# SELECT: Found  4  as best with score  1.0889027255596107
# Running local search
# LOCALSEARCH: Running search in node  4
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  0.3455093520572541  and  0.351676635338938
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.6134, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(1.0039, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.9591, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.8834, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.9393, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  1.0038695593966591
# Running partition
# PARTITION: Splitting node  4  from  0.25  to  0.375  to  0.5
# PARTITION: New node  9  new edge from  4  to  9
# PARTITION: New node  10  new edge from  4  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.22737039425724886  best tead:  0.5932614192713795
# SELECT: For node  5  best x:  0.5820914248495324  best tead:  0.9176498127692978
# SELECT: For node  7  best x:  0.7728021361083169  best tead:  0.8587581487176167
# SELECT: For node  8  best x:  0.9232275285987924  best tead:  0.8255635787460741
# SELECT: For node  9  best x:  0.25383858746514737  best tead:  0.8890112926312377
# SELECT: For node  10  best x:  0.43340584476276417  best tead:  0.46762006970256986
# SELECT: Found  5  as best with score  0.9176498127692978
# Running local search
# LOCALSEARCH: Running search in node  5
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  0.6476564369501796  and  0.6753562818618741
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.2909, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.7242, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.4839, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.8992, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.4317, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.1526, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  8  for split with score  0.8991990316276371
# Running partition
# PARTITION: Splitting node  8  from  0.875  to  0.9375  to  1.0
# PARTITION: New node  11  new edge from  8  to  11
# PARTITION: New node  12  new edge from  8  to  12
# Running subdomain selection
# SELECT: For node  3  best x:  0.15681523809117096  best tead:  0.29994746448512893
# SELECT: For node  5  best x:  0.5021183718410328  best tead:  0.7459027770632222
# SELECT: For node  7  best x:  0.8238576914781125  best tead:  0.4813352533912782
# SELECT: For node  9  best x:  0.29982675895399546  best tead:  0.4419240503772406
# SELECT: For node  10  best x:  0.384749180961096  best tead:  0.1559314759431148
# SELECT: For node  11  best x:  0.9190589479064355  best tead:  0.5136453065559863
# SELECT: For node  12  best x:  0.9474134105601382  best tead:  0.7706784664620627
# SELECT: Found  12  as best with score  0.7706784664620627
# Running local search
# LOCALSEARCH: Running search in node  12
# tead
# tead
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  3  new evaluations between  0.4504834493113832  and  0.4607212231917457
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.5946, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.8298, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.8636, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.8687, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.2037, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  11  tead score:  tensor(0.5277, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  12  tead score:  tensor(0.8234, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  9  for split with score  0.8686956036612892
# Running partition
# PARTITION: Splitting node  9  from  0.25  to  0.3125  to  0.375
# PARTITION: New node  13  new edge from  9  to  13
# PARTITION: New node  14  new edge from  9  to  14
# Running subdomain selection
# SELECT: For node  3  best x:  0.1305865765913889  best tead:  0.8064031901514295
# SELECT: For node  5  best x:  0.7431007647682089  best tead:  1.1681983769932407
# SELECT: For node  7  best x:  0.772896230455327  best tead:  1.1857813231728584
# SELECT: For node  10  best x:  0.43323985635033085  best tead:  0.2897702221666866
# SELECT: For node  11  best x:  0.9187360972640132  best tead:  0.7777268695453855
# SELECT: For node  12  best x:  0.9477336375497555  best tead:  1.166914786810136
# SELECT: For node  13  best x:  0.2518576528731081  best tead:  0.4925765376702278
# SELECT: For node  14  best x:  0.32120260865002653  best tead:  0.23167155257643585
# SELECT: Found  7  as best with score  1.1857813231728584
# Running local search
# LOCALSEARCH: Running search in node  7
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  7  new evaluations between  0.19252137734055522  and  0.2083737550905347
# Observed 4 peaks
# Function evaluations to find all peaks: 113
#
# Trial  3 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  0  tead score:  tensor(1.3236, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  0  for split with score  1.323617218809308
# Running partition
# PARTITION: Splitting node  0  from  0.0  to  0.5  to  1.0
# PARTITION: New node  1  new edge from  0  to  1
# PARTITION: New node  2  new edge from  0  to  2
# Running subdomain selection
# SELECT: For node  1  best x:  0.03443157559019935  best tead:  1.1973205314346131
# SELECT: For node  2  best x:  0.9208289182433685  best tead:  1.119180665056781
# SELECT: Found  1  as best with score  1.1973205314346131
# Running local search
# LOCALSEARCH: Running search in node  1
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  0.00595044415856083  and  0.08486289292885255
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  1  tead score:  tensor(1.2905, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  2  tead score:  tensor(1.2512, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  1  for split with score  1.2904759399404262
# Running partition
# PARTITION: Splitting node  1  from  0.0  to  0.25  to  0.5
# PARTITION: New node  3  new edge from  1  to  3
# PARTITION: New node  4  new edge from  1  to  4
# Running subdomain selection
# SELECT: For node  2  best x:  0.9209145021834272  best tead:  1.2551902054085002
# SELECT: For node  3  best x:  0.13596790228868944  best tead:  0.6460471416235382
# SELECT: For node  4  best x:  0.3611696143637265  best tead:  0.8307802156754027
# SELECT: Found  2  as best with score  1.2551902054085002
# Running local search
# LOCALSEARCH: Running search in node  2
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  0.5912661429544636  and  0.6814070023180642
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  2  tead score:  tensor(1.0450, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  3  tead score:  tensor(0.5754, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.6919, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  2  for split with score  1.0449946882730803
# Running partition
# PARTITION: Splitting node  2  from  0.5  to  0.75  to  1.0
# PARTITION: New node  5  new edge from  2  to  5
# PARTITION: New node  6  new edge from  2  to  6
# Running subdomain selection
# SELECT: For node  3  best x:  0.13573234164063028  best tead:  0.5822831329850884
# SELECT: For node  4  best x:  0.28823681817717195  best tead:  0.6926389711354837
# SELECT: For node  5  best x:  0.5002898026827728  best tead:  0.9627740293773347
# SELECT: For node  6  best x:  0.9127896170339104  best tead:  1.2308713927438217
# SELECT: Found  6  as best with score  1.2308713927438217
# Running local search
# LOCALSEARCH: Running search in node  6
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  11  new evaluations between  0.17161117802047787  and  0.2028819027417308
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.3284, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.6616, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.8729, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  6  tead score:  tensor(1.0688, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  6  for split with score  1.0688189494274425
# Running partition
# PARTITION: Splitting node  6  from  0.75  to  0.875  to  1.0
# PARTITION: New node  7  new edge from  6  to  7
# PARTITION: New node  8  new edge from  6  to  8
# Running subdomain selection
# SELECT: For node  3  best x:  0.021198503562463826  best tead:  0.3447734602861044
# SELECT: For node  4  best x:  0.4002786043521634  best tead:  0.6820267626339173
# SELECT: For node  5  best x:  0.5002030973919955  best tead:  0.9005225670352239
# SELECT: For node  7  best x:  0.816453567498273  best tead:  0.5599785695321958
# SELECT: For node  8  best x:  0.918591007899675  best tead:  1.02887541180756
# SELECT: Found  8  as best with score  1.02887541180756
# Running local search
# LOCALSEARCH: Running search in node  8
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  10  new evaluations between  0.9094240059601718  and  0.9251336085543146
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.2596, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.4244, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  5  tead score:  tensor(0.5316, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.2193, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.5243, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  5  for split with score  0.5315780966118558
# Running partition
# PARTITION: Splitting node  5  from  0.5  to  0.625  to  0.75
# PARTITION: New node  9  new edge from  5  to  9
# PARTITION: New node  10  new edge from  5  to  10
# Running subdomain selection
# SELECT: For node  3  best x:  0.1355380516670502  best tead:  0.2595598079616082
# SELECT: For node  4  best x:  0.4239807186065936  best tead:  0.4134089345652618
# SELECT: For node  7  best x:  0.7836451242604968  best tead:  0.22041494230940564
# SELECT: For node  8  best x:  0.9604217313335333  best tead:  0.5272317731329093
# SELECT: For node  9  best x:  0.616471272685621  best tead:  0.37895365164552486
# SELECT: For node  10  best x:  0.642092156303483  best tead:  0.5098919653234271
# SELECT: Found  8  as best with score  0.5272317731329093
# Running local search
# LOCALSEARCH: Running search in node  8
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
#
# TuRBO restart triggered
# LOCALSEARCH: Completed  9  new evaluations between  0.9183393328383674  and  0.9367497733727207
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Completed: TEAD exploration iteration
# Calculating pre-select scores
# Calculating subdomain pre-select scores
# PRESELECT: For node  3  tead score:  tensor(0.4440, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  4  tead score:  tensor(0.5239, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  7  tead score:  tensor(0.1469, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  8  tead score:  tensor(0.2890, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  9  tead score:  tensor(0.4566, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: For node  10  tead score:  tensor(0.5198, dtype=torch.float64, grad_fn=<MaxBackward1>)
# PRESELECT: Selecting node  4  for split with score  0.5239323816443464
# Running partition
# PARTITION: Splitting node  4  from  0.25  to  0.375  to  0.5
# PARTITION: New node  11  new edge from  4  to  11
# PARTITION: New node  12  new edge from  4  to  12
# Running subdomain selection
# SELECT: For node  3  best x:  0.021543382219810128  best tead:  0.43203276375208993
# SELECT: For node  7  best x:  0.7839793513167334  best tead:  0.14246509856258704
# SELECT: For node  8  best x:  0.9601992117198824  best tead:  0.28362079821762204
# SELECT: For node  9  best x:  0.6165904681652818  best tead:  0.45764092018350955
# SELECT: For node  10  best x:  0.6927018326850741  best tead:  0.5176439910115562
# SELECT: For node  11  best x:  0.37464941611628105  best tead:  0.5199499096528886
# SELECT: For node  12  best x:  0.3773905624202262  best tead:  0.5167130652150682
# SELECT: Found  11  as best with score  0.5199499096528886
# Running local search
# LOCALSEARCH: Running search in node  11
# tead
# tead
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# turbo
# LOCALSEARCH: Completed  11  new evaluations between  0.3303243615706967  and  0.3671940080281863
# Observed 4 peaks
# Function evaluations to find all peaks: 117
#
# Trial  4 of 15 Collecting initial samples
# Setting up global state
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# tead
# Fitting global model
# Exploring full space
# Completed: TEAD exploration iteration
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[22], line 19
#      17 current_global_search = MultimodalExtremaSearch(60,global_bounds,outcome_objective,)
#      18 # run search
# ---> 19 current_global_search.run_global_search()
#      21 # collect data
#      22 x_observed_all.append(current_global_search.global_state.x_global)
#
# File ~\PycharmProjects\extrema_search\src\extremasearch\globalmm\globalsearch.py:470, in MultimodalExtremaSearch.run_global_search(self)
#     468 self.fit_global_model_partitioned()
#     469 print('Exploring full space')
# --> 470 self.run_global_tead_exploration_evaluations()
#     471 print('Calculating pre-select scores')
#     472 self.compute_global_preselect_scores()
#
# File ~\PycharmProjects\extrema_search\src\extremasearch\globalmm\globalsearch.py:146, in MultimodalExtremaSearch.run_global_tead_exploration_evaluations(self)
#     144     x_candidates, x_tead_scores = global_tead(self.global_state.global_model, get_all_candidates=True)
#     145 elif self.tead_model_type == 'piecewise':
# --> 146     x_candidates, x_tead_scores = piecewise_tead(self.global_state.x_global, self.global_state.y_global,
#     147                                                  self.global_state.partition_graph, get_all_candidates=True)
#     148 else:
#     149     print('TEAD type selection not recognized')
#
# File ~\PycharmProjects\extrema_search\src\extremasearch\acquisition\tead.py:160, in piecewise_tead(x_all, y_all, graph, get_all_candidates)
#     158 y_train = y_all
#     159 # calculate gradient at each training point using finite difference
# --> 160 grads = finite_diff_piecewise(x_train, graph)
#     161 # (this may be available through torch built in behavior, but no time now
#     162 # generate potential input candidates using LHC samples
#     163 lhs_sampler = LatinHypercube(d=1)
#
# File ~\PycharmProjects\extrema_search\src\extremasearch\acquisition\tead.py:148, in finite_diff_piecewise(x_all, graph)
#     146 model_lo = get_model_from_piecewise_set(graph, x_lo.unsqueeze(-1))
#     147 y_lo = model_lo(x_lo.unsqueeze(-1)).mean
# --> 148 model_hi = get_model_from_piecewise_set(graph, x_hi.unsqueeze(-1))
#     149 y_hi = model_hi(x_hi.unsqueeze(-1)).mean
#     150 delta_s[i] = (y_hi - y_lo)/(2*h)
#
# File ~\PycharmProjects\extrema_search\src\extremasearch\acquisition\tead.py:128, in get_model_from_piecewise_set(graph, x)
#     125     return graph.nodes()[low_node]['data'].local_model
#     126 elif x >= 1.0:
#     127     # if a prediction higher than 1.0 needed
# --> 128     return graph.nodes()[high_node]['data'].local_model
#     129 print("Model lookup failed")
#
# UnboundLocalError: local variable 'high_node' referenced before assignment

# %%
# calculate summary metrics
# peak ratio
num_known_peaks = 4
n_replications = 4
peak_ratio = sum(distinct_peaks) / (num_known_peaks * n_replications)
print("Peak ratio: {}".format(peak_ratio))
# success rate
num_successes = 0
for i in range(n_replications):
    if distinct_peaks[i] == 4:
        num_successes += 1
success_ratio = num_successes / n_replications
print("Success ratio: {}".format(success_ratio))
print("Average function evaluations: {}".format(sum(function_evaluations)/n_replications))

# %%
temp1, temp2 = get_bounds_all(current_global_search.global_state.partition_graph)
