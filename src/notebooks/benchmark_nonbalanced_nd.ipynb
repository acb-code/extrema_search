# %%
# benchmarking the non-balanced strategies for comparison
# -NEI
# -TEAD
# -TuRBO - todo
# - Sobol
# Author: Alex Braafladt
# Created 3/5/2023
# Notes:

# %%
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from extremasearch.globalmm.globalsearch import MultimodalExtremaSearch
from botorch import fit_gpytorch_mll
from botorch.models.gp_regression import SingleTaskGP
from gpytorch.mlls import ExactMarginalLogLikelihood
import numpy as np
import networkx as nx
from botorch.models.transforms import Normalize, Standardize


# setup
dtype = torch.double
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import warnings
from botorch.exceptions import BadInitialCandidatesWarning
warnings.filterwarnings('ignore', category=BadInitialCandidatesWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# %%
# setup file i/o
import os as os
import datetime as dt
# get current working directory
wrkdir = os.getcwd()
print('Current working directory: '+wrkdir)
# set up a data save directory for all future runs
newoutputdir = wrkdir+'\output'
if not os.path.exists(newoutputdir):
    os.makedirs(newoutputdir)
# set up a new directory to store files for the current run - updates at each new full run of notebook
curDatetime = dt.datetime.now()
datasavedir = newoutputdir + r'\\' + 'mme_nonbalanced_benchmark_nd' + str(curDatetime.strftime('%Y%m%d%H%M%S'))
if not os.path.exists(datasavedir):
    os.makedirs(datasavedir)
print('Data save directory: '+datasavedir)
# Out:
# Current working directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks
# Data save directory: C:\Users\alexb\PycharmProjects\extrema_search\src\notebooks\output\\mme_nonbalanced_benchmark_nd20230307105232

# %%
# and with addition of smooth global behavior
def mme_add_2d_plot(x1, x2):
    y = (torch.exp(-(100.*(x1-0.65))**2.)) * (torch.exp(-(50.*(x2-0.65))**2.))
    y += 0.7*(torch.exp(-(100.*(x1-0.25))**2.)) * (torch.exp(-(50.*(x2-0.35))**2.))
    y += 0.8*(torch.exp(-(100.*(x1-0.8))**2.)) * (torch.exp(-(50.*(x2-0.15))**2.))
    y += 0.66*(-1.*x2*x1 + 0.1*torch.sin(30.*x1*x2)) + 0.73
    return y

x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z = mme_add_2d_plot(X1, X2)
from matplotlib import ticker, cm
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(8,6))

from matplotlib.colors import LightSource
ls = LightSource(270, 45)
rgb = ls.shade(Z.numpy(), cmap=cm.gist_earth, vert_exag=0.1, blend_mode='soft')
surf = ax.plot_surface(X1, X2, Z, cmap='Blues', shade=False, cstride=1, rstride=1, linewidth=0)
# surf = ax.plot_surface(X1, X2, Z, facecolors=rgb, shade=False)
plt.savefig(datasavedir + '/'+'2d_mme_attempt'+'.png')
# Out:
# C:\Users\alexb\PycharmProjects\extrema_search\venv\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3191.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
sigma_max = 0.12
sigma_min = 0.02
def noise_1_2d(x1, x2):
    # mean
    y = mme_add_2d_plot(x1, x2)
    # noise
    noise = torch.zeros(y.shape)
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.61) * (x1 < 0.71) * (x2 >= 0.61) * (x2 < 0.71)  # peak 1
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.21) * (x1 < 0.31) * (x2 >= 0.31) * (x2 < 0.41)  # peak 2
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.76) * (x1 < 0.84) * (x2 >= 0.11) * (x2 < 0.21)  # peak 3
    # noise += (torch.randn(y.shape) * (sigma_max - sigma_min) / (1. + torch.exp(-10.*(x1-0.2))) + sigma_min) * (x1 < 0.5) * (x2 < 0.5)
    # noise += (torch.randn(y.shape) * (sigma_max - sigma_min) / (1. + torch.exp(10.*(x1-0.75))) + sigma_min) * (x1 >= 0.5) * (x2 >= 0.5)
    noise += torch.randn(y.shape) * (sigma_max - sigma_min) * (0.4 / (torch.abs(1.25*y - 0.5) + 0.4))
    # jump
    y1 = y + noise
    y_jump = 0.2 * y1 * (x1 <= 0.45) * (x2 <= 0.58)
    y2 = y1 - y_jump
    return y2

x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z = noise_1_2d(X1, X2)
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(10,8))
surf = ax.plot_surface(X1, X2, Z, cmap='Blues', shade=False, cstride=1, rstride=1, linewidth=0)
plt.savefig(datasavedir + '/'+'2d_mme_noise_attempt1'+'.png')

# %%
sigma_max = 0.12
sigma_min = 0.02
def mme_add_2d(X):
    x1, x2 = X[..., 0], X[..., 1]
    y = (torch.exp(-(100.*(x1-0.65))**2.)) * (torch.exp(-(50.*(x2-0.65))**2.))
    y += 0.7*(torch.exp(-(100.*(x1-0.25))**2.)) * (torch.exp(-(50.*(x2-0.35))**2.))
    y += 0.8*(torch.exp(-(100.*(x1-0.8))**2.)) * (torch.exp(-(50.*(x2-0.15))**2.))
    y += 0.66*(-1.*x2*x1 + 0.1*torch.sin(30.*x1*x2)) + 0.73
    return y

def mme_2d(X):
    x1, x2 = X[..., 0], X[..., 1]
    # mean
    y = mme_add_2d(X)
    # noise
    noise = torch.zeros(y.shape)
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.61) * (x1 < 0.71) * (x2 >= 0.61) * (x2 < 0.71)  # peak 1
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.21) * (x1 < 0.31) * (x2 >= 0.31) * (x2 < 0.41)  # peak 2
    noise += (torch.randn(y.shape) * sigma_max) * (x1 >= 0.76) * (x1 < 0.84) * (x2 >= 0.11) * (x2 < 0.21)  # peak 3
    # noise += (torch.randn(y.shape) * (sigma_max - sigma_min) / (1. + torch.exp(-10.*(x1-0.2))) + sigma_min) * (x1 < 0.5) * (x2 < 0.5)
    # noise += (torch.randn(y.shape) * (sigma_max - sigma_min) / (1. + torch.exp(10.*(x1-0.75))) + sigma_min) * (x1 >= 0.5) * (x2 >= 0.5)
    noise += torch.randn(y.shape) * (sigma_max - sigma_min) * (0.4 / (torch.abs(1.25*y - 0.5) + 0.4))
    # jump
    y1 = y + noise
    y_jump = 0.2 * y1 * (x1 <= 0.45) * (x2 <= 0.58)
    y2 = y1 - y_jump
    return y2

def outcome_objective(x):
    """wrapper for the outcome objective function"""
    return mme_2d(x).type_as(x).unsqueeze(-1)

# %%
# set up the GP model for use
def initialize_model(train_x, train_obj, state_dict=None):
    """function to initialize the GP model"""
    model_obj = SingleTaskGP(train_x, train_obj)
    mll = ExactMarginalLogLikelihood(model_obj.likelihood, model_obj)
    # load state_dict if it is not passed
    if state_dict is not None:
        model_obj.load_state_dict(state_dict)
    return mll, model_obj

# set up the initial data set
def generate_initial_data(n=10):
    """generate initial set of data to get started with BO loop"""
    train_x = torch.rand(10, 2, device=device, dtype=dtype)
    exact_obj = outcome_objective(train_x)
    train_obj = exact_obj
    best_observed_value = exact_obj.max().item()
    return train_x, train_obj, best_observed_value

from botorch.optim import optimize_acqf
NUM_RESTARTS = 10
RAW_SAMPLES = 512
bounds = torch.tensor([[0.0, 1.0],[0.0, 1.0]], device=device, dtype=dtype)
def optimize_acqf_and_get_observation(acq_func):
    """Optimizes the acquisition function, and returns a new candidate and a noisy observation"""
    # optimize
    candidates, _ = optimize_acqf(
        acq_function=acq_func,
        bounds=bounds,
        q=BATCH_SIZE,
        num_restarts=NUM_RESTARTS,
        raw_samples=RAW_SAMPLES,# initialization heuristic
        options={"batch_limit": 5, "maxiter": 200},
    )
    # observe new values
    new_x = candidates.detach()
    new_obj = outcome_objective(new_x)
    return new_x, new_obj

def update_random_observation():
    """Simulates a random policy by taking the current list of best values observed
    randomly, drawing a new random point, observing its value, and updating the list
    """
    rand_x = torch.rand(BATCH_SIZE, 2)  # drawing from random uniform
    next_random_best = outcome_objective(rand_x)
    return  rand_x, next_random_best

# %%
# metrics functions
def count_number_peaks_observed_2d(x_obs, y_obs, num_known_peaks=3):
    """Function to count the number of peaks observed for the mme_noise_jump_1d function"""
    peak1, peak2, peak3 = False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.64 <= x[0] <= 0.66 and 0.64 <= x[1] <= 0.66:
            if y >= 1.37:
                peak1 = True
        elif 0.24 <= x[0] <= 0.26 and 0.34 <= x[1] <= 0.36:
            if y >= 1.06:
                peak2 = True
        elif 0.79 <= x[0] <= 0.81 and 0.14 <= x[1] <= 0.16:
            if y >= 1.36:
                peak3 = True
    num_peaks_observed = peak1 + peak2 + peak3
    return num_peaks_observed


def count_evaluations_for_all_peaks_2d(x_obs, y_obs):
    """Count the number of function evaluations before finding all peaks"""
    i = 0
    num_evals_for_all_peaks = x_obs.shape[0]
    peak1, peak2, peak3 = False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.64 <= x[0] <= 0.66 and 0.64 <= x[1] <= 0.66:
            if y >= 1.37:
                peak1 = True
        elif 0.24 <= x[0] <= 0.26 and 0.34 <= x[1] <= 0.36:
            if y >= 1.06:
                peak2 = True
        elif 0.79 <= x[0] <= 0.81 and 0.14 <= x[1] <= 0.16:
            if y >= 1.36:
                peak3 = True
        i += 1
        if peak1 and peak2 and peak3:
            num_evals_for_all_peaks = i
            break
    return num_evals_for_all_peaks

# %%
# testing loop functions
test_train_x = torch.rand(10, 2, dtype=dtype)
test_obj = outcome_objective(test_train_x)
best_observed_value = test_obj.max().item()

# %%
from extremasearch.acquisition.turbo import NewTurboState, new_update_state, generate_batch
from extremasearch.acquisition.tead import global_tead
from extremasearch.acquisition.qtead import nglobal_tead
import time
from botorch.sampling import SobolQMCNormalSampler
from botorch.acquisition.monte_carlo import qNoisyExpectedImprovement
from extremasearch.local.localsearch import initialize_scaled_model

N_TRIALS = 1
N_BATCH = 400 # note +10 for total iteration limit
MC_SAMPLES = 256
dim = 2
N_CANDIDATES = min(5000, max(2000, 200 * dim))
BATCH_SIZE = 1

verbose = True
import warnings
warnings.filterwarnings('ignore', category=BadInitialCandidatesWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# set up arrays to hold arrays of data
# best values
best_observed_all_nei, best_observed_random_all, best_observed_all_tead = [], [], []
# best_observed_all_turbo = []
# {x, y} values
x_observed_all_random, x_observed_all_nei, x_observed_all_tead = [], [], []
y_observed_all_random, y_observed_all_nei, y_observed_all_tead = [], [], []
# x_observed_all_turbo = []
# y_observed_all_turbo = []

# mmo results
distinct_peaks_random, distinct_peaks_nei, distinct_peaks_tead = [], [], []
function_evals_random, function_evals_nei, function_evals_tead = [], [], []
# distinct_peaks_turbo = []
# function_evals_turbo = []

# going to average over N_TRIALS
for trial in range(1, N_TRIALS + 1):
    print(f"\nTrial {trial:>2} of {N_TRIALS} ", end="")
    # set up arrays to hold data for this trial
    best_observed_nei, best_observed_random, best_observed_tead = [], [], []
    # best_observed_turbo = []

    # generate initial training data and initial model for this trial
    # nei
    # use same initial training points
    train_x_nei, train_obj_nei, best_observed_value_nei = generate_initial_data(n=10)
    mll_nei, model_nei = initialize_model(train_x_nei, train_obj_nei)
    # tead
    # use same initial points
    train_x_tead, train_obj_tead = train_x_nei, train_obj_nei
    best_observed_value_tead = best_observed_value_nei
    mll_tead, model_tead = initialize_model(train_x_tead, train_obj_tead)
    # turbo
    # train_x_turbo, train_obj_turbo = train_x_nei, train_obj_nei
    # best_observed_value_turbo = best_observed_value_nei
    # turbo initialization
    # state = NewTurboState(dim=1, batch_size=BATCH_SIZE, center=torch.tensor(0.5), lb=torch.tensor(0.0), ub=torch.tensor(1.0))
    # state = new_update_state(state, train_x_turbo, train_obj_turbo, torch.DoubleTensor([best_observed_value_turbo]))
    # tr_x_turbo, tr_obj_turbo = state.get_training_samples_in_region()
    # mll_turbo, model_turbo = initialize_scaled_model(tr_x_turbo, tr_obj_turbo)
    # random
    train_x_random, train_obj_random = train_x_nei, train_obj_nei

    # start collection of results from random initialization
    best_observed_nei.append(best_observed_value_nei)
    best_observed_random.append(best_observed_value_nei)
    best_observed_tead.append(best_observed_value_tead)
    # best_observed_turbo.append(best_observed_value_turbo)

    # for N_BATCH rounds of BO after the initial random batch
    for iteration in range(1, N_BATCH + 1):
        t0 = time.monotonic()
        # fit models
        fit_gpytorch_mll(mll_nei)
        fit_gpytorch_mll(mll_tead)
        # fit_gpytorch_mll(mll_turbo)

        # set up the sampler to use with the acq funcs
        qmc_sampler = SobolQMCNormalSampler(sample_shape=MC_SAMPLES)

        # set up the acquisition functions
        qNEI = qNoisyExpectedImprovement(
            model=model_nei,
            X_baseline=train_x_nei,
            sampler=qmc_sampler,
        )

        # optimize the acquisition functions
        new_x_nei, new_obj_nei = optimize_acqf_and_get_observation(qNEI)
        new_x_tead = nglobal_tead(model_tead)
        new_obj_tead = outcome_objective(new_x_tead)
        # new_x_turbo = generate_batch(
        #     state=state,
        #     model=model_turbo,
        #     # x=train_x_turbo,
        #     x=state.train_x,
        #     # y=train_obj_turbo,
        #     y=state.train_y,
        #     batch_size=BATCH_SIZE,
        #     n_candidates=N_CANDIDATES,
        #     num_restarts=NUM_RESTARTS,
        #     raw_samples=RAW_SAMPLES,
        #     acqf='ts',
        #     # acqf='ei',
        # )
        # new_obj_turbo = outcome_objective(new_x_turbo)
        # random
        new_x_random, new_obj_random = update_random_observation()

        # update training points
        train_x_nei = torch.cat([train_x_nei, new_x_nei])
        train_obj_nei = torch.cat([train_obj_nei, new_obj_nei])
        train_x_tead = torch.cat([train_x_tead, new_x_tead])
        train_obj_tead = torch.cat([train_obj_tead, new_obj_tead])
        # train_x_turbo = torch.cat([train_x_turbo, new_x_turbo])
        # train_obj_turbo = torch.cat([train_obj_turbo, new_obj_turbo])
        train_x_random = torch.cat([train_x_random, new_x_random])
        train_obj_random = torch.cat([train_obj_random, new_obj_random])

        # update trust region
        # state = new_update_state(state, x_train=train_x_turbo, y_train=train_obj_turbo, y_next=new_obj_turbo)

        # update progress data
        best_value_random = train_obj_random.max()
        best_observed_random.append(best_value_random)
        best_value_nei = train_obj_nei.max()
        best_observed_nei.append(best_value_nei)
        best_value_tead = train_obj_tead.max()
        best_observed_tead.append(best_value_tead)
        # best_value_turbo = train_obj_turbo.max()
        # best_observed_turbo.append(best_value_turbo)

        # reinitialize the models so that they're ready to fit on the next iteration
        # state dict passed to speed up fitting
        mll_nei, model_nei = initialize_model(
            train_x_nei,
            train_obj_nei,
            model_nei.state_dict(),
        )
        mll_tead, model_tead = initialize_model(
            train_x_tead,
            train_obj_tead,
            model_tead.state_dict(),
        )
        # update trust region model
        # tr_x_turbo, tr_obj_turbo = state.get_training_samples_in_region()
        # mll_turbo, model_turbo = initialize_scaled_model(tr_x_turbo, tr_obj_turbo)

        t1 = time.monotonic()

        if verbose:
            print(
                # f"\nBatch {iteration:>2}: best_value (random, qNEI, TEAD, TuRBO) = "
                # f"({best_value_random:>4.2f}, {best_value_nei:>4.2f}, {best_value_tead:>4.2f}, {state.best_value:>4.2f}), "
                f"\nBatch {iteration:>2}: best_value (random, qNEI, TEAD) = "
                f"({best_value_random:>4.2f}, {best_value_nei:>4.2f}, {best_value_tead:>4.2f},), "
                f"time = {t1-t0:>4.2f}.", end=""
            )
        else:
            print(".", end="")

    # collect observations from trial
    best_observed_all_nei.append(best_observed_nei)
    best_observed_random_all.append(best_observed_random)
    best_observed_all_tead.append(best_observed_tead)
    # best_observed_all_turbo.append(best_observed_turbo)
    x_observed_all_random.append(train_x_random)
    x_observed_all_nei.append(train_x_nei)
    x_observed_all_tead.append(train_x_tead)
    # x_observed_all_turbo.append(train_x_turbo)
    y_observed_all_random.append(train_obj_random)
    y_observed_all_nei.append(train_obj_nei)
    y_observed_all_tead.append(train_obj_tead)
    # y_observed_all_turbo.append(train_obj_turbo)
    # todo once metric functions updated to 2d
    # # collect metrics
    distinct_peaks_random.append(count_number_peaks_observed_2d(train_x_random, train_obj_random))
    distinct_peaks_nei.append(count_number_peaks_observed_2d(train_x_nei, train_obj_nei))
    distinct_peaks_tead.append(count_number_peaks_observed_2d(train_x_tead, train_obj_tead))
    # # distinct_peaks_turbo.append(count_number_peaks_observed(train_x_turbo, train_obj_turbo))
    function_evals_random.append(count_evaluations_for_all_peaks_2d(train_x_random, train_obj_random))
    function_evals_nei.append(count_evaluations_for_all_peaks_2d(train_x_nei, train_obj_nei))
    function_evals_tead.append(count_evaluations_for_all_peaks_2d(train_x_tead, train_obj_tead))
    # # function_evals_turbo.append(count_evaluations_for_all_peaks(train_x_turbo, train_obj_turbo))
# Out:
# Trial  1 of 1
# Batch  1: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 10.01.
# Batch  2: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.80.
# Batch  3: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.58.
# Batch  4: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.66.
# Batch  5: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.62.
# Batch  6: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.56.
# Batch  7: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.61.
# Batch  8: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.95.
# Batch  9: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.76.
# Batch 10: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.88.
# Batch 11: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 7.00.
# Batch 12: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.67.
# Batch 13: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.75.
# Batch 14: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 7.06.
# Batch 15: best_value (random, qNEI, TEAD) = (0.78, 0.78, 0.78,), time = 6.64.
# Batch 16: best_value (random, qNEI, TEAD) = (0.81, 0.78, 0.78,), time = 7.05.
# Batch 17: best_value (random, qNEI, TEAD) = (0.81, 0.78, 0.78,), time = 10.02.
# Batch 18: best_value (random, qNEI, TEAD) = (0.81, 0.80, 0.78,), time = 9.33.
# Batch 19: best_value (random, qNEI, TEAD) = (0.81, 0.80, 0.78,), time = 7.31.
# Batch 20: best_value (random, qNEI, TEAD) = (0.81, 0.80, 0.78,), time = 6.95.
# Batch 21: best_value (random, qNEI, TEAD) = (0.81, 0.85, 0.78,), time = 7.05.
# Batch 22: best_value (random, qNEI, TEAD) = (0.81, 0.85, 0.78,), time = 7.47.
# Batch 23: best_value (random, qNEI, TEAD) = (0.81, 0.85, 0.78,), time = 7.20.
# Batch 24: best_value (random, qNEI, TEAD) = (0.81, 0.85, 0.78,), time = 7.12.
# Batch 25: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.28.
# Batch 26: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.19.
# Batch 27: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.17.
# Batch 28: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.28.
# Batch 29: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.44.
# Batch 30: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.55.
# Batch 31: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 9.94.
# Batch 32: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.97.
# Batch 33: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 10.19.
# Batch 34: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.19.
# Batch 35: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 9.41.
# Batch 36: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.31.
# Batch 37: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.47.
# Batch 38: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.22.
# Batch 39: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 9.70.
# Batch 40: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.92.
# Batch 41: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.55.
# Batch 42: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.05.
# Batch 43: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 10.36.
# Batch 44: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.75.
# Batch 45: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.50.
# Batch 46: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.52.
# Batch 47: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.42.
# Batch 48: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.50.
# Batch 49: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.51.
# Batch 50: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.86.
# Batch 51: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.91.
# Batch 52: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.67.
# Batch 53: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.88.
# Batch 54: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.92.
# Batch 55: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.64.
# Batch 56: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.03.
# Batch 57: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.47.
# Batch 58: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.86.
# Batch 59: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.08.
# Batch 60: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.19.
# Batch 61: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.88.
# Batch 62: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.28.
# Batch 63: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 8.08.
# Batch 64: best_value (random, qNEI, TEAD) = (0.81, 0.85, 1.10,), time = 7.86.
# Batch 65: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.10,), time = 8.19.
# Batch 66: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.10,), time = 8.22.
# Batch 67: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.10,), time = 8.52.
# Batch 68: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.30.
# Batch 69: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.53.
# Batch 70: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.47.
# Batch 71: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.34.
# Batch 72: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.53.
# Batch 73: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.56.
# Batch 74: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.36.
# Batch 75: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.67.
# Batch 76: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.66.
# Batch 77: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.38.
# Batch 78: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.69.
# Batch 79: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.44.
# Batch 80: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 9.12.
# Batch 81: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.86.
# Batch 82: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.92.
# Batch 83: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.91.
# Batch 84: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.91.
# Batch 85: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 9.05.
# Batch 86: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 8.94.
# Batch 87: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 9.22.
# Batch 88: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.21,), time = 9.17.
# Batch 89: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.41,), time = 9.24.
# Batch 90: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.41,), time = 9.33.
# Batch 91: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.41,), time = 9.22.
# Batch 92: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.41,), time = 9.39.
# Batch 93: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.41,), time = 9.53.
# Batch 94: best_value (random, qNEI, TEAD) = (0.83, 0.85, 1.41,), time = 9.69.
# Batch 95: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 9.45.
# Batch 96: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 9.45.
# Batch 97: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 9.99.
# Batch 98: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 10.78.
# Batch 99: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 10.27.
# Batch 100: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 9.64.
# Batch 101: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 9.95.
# Batch 102: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 9.86.
# Batch 103: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 10.31.
# Batch 104: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 9.81.
# Batch 105: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 10.53.
# Batch 106: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 10.69.
# Batch 107: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 10.70.
# Batch 108: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 10.74.
# Batch 109: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 10.72.
# Batch 110: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.08.
# Batch 111: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 10.89.
# Batch 112: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 10.97.
# Batch 113: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 10.58.
# Batch 114: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.11.
# Batch 115: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.02.
# Batch 116: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.23.
# Batch 117: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.06.
# Batch 118: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.30.
# Batch 119: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.01.
# Batch 120: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.49.
# Batch 121: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.59.
# Batch 122: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.74.
# Batch 123: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.47.
# Batch 124: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.48.
# Batch 125: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.72.
# Batch 126: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.80.
# Batch 127: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.70.
# Batch 128: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 11.69.
# Batch 129: best_value (random, qNEI, TEAD) = (0.86, 0.85, 1.41,), time = 12.06.
# Batch 130: best_value (random, qNEI, TEAD) = (0.86, 0.88, 1.41,), time = 12.03.
# Batch 131: best_value (random, qNEI, TEAD) = (0.86, 0.88, 1.41,), time = 12.06.
# Batch 132: best_value (random, qNEI, TEAD) = (0.86, 0.88, 1.41,), time = 12.12.
# Batch 133: best_value (random, qNEI, TEAD) = (0.86, 0.88, 1.41,), time = 12.06.
# Batch 134: best_value (random, qNEI, TEAD) = (0.86, 0.88, 1.41,), time = 12.36.
# Batch 135: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 12.05.
# Batch 136: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 12.38.
# Batch 137: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 12.38.
# Batch 138: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 12.92.
# Batch 139: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 12.20.
# Batch 140: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 12.72.
# Batch 141: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 12.81.
# Batch 142: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 12.78.
# Batch 143: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 12.91.
# Batch 144: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.06.
# Batch 145: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.20.
# Batch 146: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.17.
# Batch 147: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 12.88.
# Batch 148: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.34.
# Batch 149: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.30.
# Batch 150: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.45.
# Batch 151: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.53.
# Batch 152: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.77.
# Batch 153: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.58.
# Batch 154: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.64.
# Batch 155: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.69.
# Batch 156: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.95.
# Batch 157: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.94.
# Batch 158: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.98.
# Batch 159: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 13.77.
# Batch 160: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.19.
# Batch 161: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.19.
# Batch 162: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.38.
# Batch 163: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.25.
# Batch 164: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.38.
# Batch 165: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.31.
# Batch 166: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.19.
# Batch 167: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.61.
# Batch 168: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.72.
# Batch 169: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.47.
# Batch 170: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 15.05.
# Batch 171: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.61.
# Batch 172: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 15.01.
# Batch 173: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 15.14.
# Batch 174: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.78.
# Batch 175: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 14.92.
# Batch 176: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 15.50.
# Batch 177: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 15.19.
# Batch 178: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 15.62.
# Batch 179: best_value (random, qNEI, TEAD) = (1.09, 0.88, 1.41,), time = 15.34.
# Batch 180: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 15.83.
# Batch 181: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 16.00.
# Batch 182: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 15.78.
# Batch 183: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 15.76.
# Batch 184: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 16.06.
# Batch 185: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 16.31.
# Batch 186: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 16.02.
# Batch 187: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 16.38.
# Batch 188: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 16.41.
# Batch 189: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 16.58.
# Batch 190: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 16.81.
# Batch 191: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 16.47.
# Batch 192: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 17.34.
# Batch 193: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 17.16.
# Batch 194: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 17.12.
# Batch 195: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 16.89.
# Batch 196: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 17.24.
# Batch 197: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 17.61.
# Batch 198: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 17.95.
# Batch 199: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 17.42.
# Batch 200: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 17.58.
# Batch 201: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 17.45.
# Batch 202: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 17.86.
# Batch 203: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 18.14.
# Batch 204: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 18.09.
# Batch 205: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 18.09.
# Batch 206: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 18.25.
# Batch 207: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 18.27.
# Batch 208: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 18.41.
# Batch 209: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 18.62.
# Batch 210: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 18.58.
# Batch 211: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 18.64.
# Batch 212: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 19.30.
# Batch 213: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 18.75.
# Batch 214: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 18.92.
# Batch 215: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 19.31.
# Batch 216: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 19.36.
# Batch 217: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 19.59.
# Batch 218: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 19.59.
# Batch 219: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 19.61.
# Batch 220: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 19.53.
# Batch 221: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 19.86.
# Batch 222: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 20.31.
# Batch 223: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 20.20.
# Batch 224: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 20.52.
# Batch 225: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 19.98.
# Batch 226: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 20.58.
# Batch 227: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 20.77.
# Batch 228: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 20.83.
# Batch 229: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 20.97.
# Batch 230: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 20.95.
# Batch 231: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 20.92.
# Batch 232: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 21.41.
# Batch 233: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 21.53.
# Batch 234: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 21.81.
# Batch 235: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 21.80.
# Batch 236: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 21.91.
# Batch 237: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 21.98.
# Batch 238: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 22.17.
# Batch 239: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 21.69.
# Batch 240: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 22.33.
# Batch 241: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 22.25.
# Batch 242: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 22.11.
# Batch 243: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 22.69.
# Batch 244: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 22.80.
# Batch 245: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 22.67.
# Batch 246: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 23.01.
# Batch 247: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 24.02.
# Batch 248: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 22.80.
# Batch 249: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 22.83.
# Batch 250: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 23.05.
# Batch 251: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 23.22.
# Batch 252: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 23.59.
# Batch 253: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 23.34.
# Batch 254: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 23.70.
# Batch 255: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 23.97.
# Batch 256: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 24.41.
# Batch 257: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 25.01.
# Batch 258: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 24.44.
# Batch 259: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 26.23.
# Batch 260: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 24.55.
# Batch 261: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 25.89.
# Batch 262: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 25.70.
# Batch 263: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 25.22.
# Batch 264: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 25.23.
# Batch 265: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 25.27.
# Batch 266: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 25.34.
# Batch 267: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 25.64.
# Batch 268: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 25.86.
# Batch 269: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 26.25.
# Batch 270: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 26.30.
# Batch 271: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 25.99.
# Batch 272: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 26.53.
# Batch 273: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 26.73.
# Batch 274: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 27.42.
# Batch 275: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 29.45.
# Batch 276: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 27.56.
# Batch 277: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 28.76.
# Batch 278: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 29.44.
# Batch 279: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 28.53.
# Batch 280: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 28.86.
# Batch 281: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 29.27.
# Batch 282: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 29.30.
# Batch 283: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 29.05.
# Batch 284: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 29.94.
# Batch 285: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 31.89.
# Batch 286: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 29.17.
# Batch 287: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 29.61.
# Batch 288: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 29.61.
# Batch 289: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 30.30.
# Batch 290: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 29.72.
# Batch 291: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 30.52.
# Batch 292: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 29.81.
# Batch 293: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 30.89.
# Batch 294: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 31.41.
# Batch 295: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 32.58.
# Batch 296: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 31.11.
# Batch 297: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 31.80.
# Batch 298: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 31.75.
# Batch 299: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 31.92.
# Batch 300: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 31.88.
# Batch 301: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 32.70.
# Batch 302: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 32.80.
# Batch 303: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 33.06.
# Batch 304: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 32.52.
# Batch 305: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 32.62.
# Batch 306: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 32.30.
# Batch 307: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 33.11.
# Batch 308: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 33.42.
# Batch 309: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 33.66.
# Batch 310: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 33.62.
# Batch 311: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 33.45.
# Batch 312: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 36.88.
# Batch 313: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 35.06.
# Batch 314: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 33.76.
# Batch 315: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 39.84.
# Batch 316: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 34.84.
# Batch 317: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 37.23.
# Batch 318: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 38.48.
# Batch 319: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 43.33.
# Batch 320: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 44.28.
# Batch 321: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 39.69.
# Batch 322: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 38.61.
# Batch 323: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 38.31.
# Batch 324: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 36.30.
# Batch 325: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 35.70.
# Batch 326: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 43.44.
# Batch 327: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 38.39.
# Batch 328: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 36.74.
# Batch 329: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 38.12.
# Batch 330: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 37.51.
# Batch 331: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 36.99.
# Batch 332: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 38.44.
# Batch 333: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 37.94.
# Batch 334: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 37.95.
# Batch 335: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 42.88.
# Batch 336: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 45.91.
# Batch 337: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 45.05.
# Batch 338: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 44.89.
# Batch 339: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 42.92.
# Batch 340: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 41.17.
# Batch 341: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 40.97.
# Batch 342: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 39.75.
# Batch 343: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 40.25.
# Batch 344: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 43.61.
# Batch 345: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 43.23.
# Batch 346: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 43.03.
# Batch 347: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 45.83.
# Batch 348: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 41.55.
# Batch 349: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 47.84.
# Batch 350: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 46.47.
# Batch 351: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 44.84.
# Batch 352: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 51.83.
# Batch 353: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 55.36.
# Batch 354: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 54.48.
# Batch 355: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 54.77.
# Batch 356: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 54.69.
# Batch 357: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 55.97.
# Batch 358: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 55.19.
# Batch 359: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 56.98.
# Batch 360: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 58.08.
# Batch 361: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 57.97.
# Batch 362: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 56.91.
# Batch 363: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 57.45.
# Batch 364: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 57.08.
# Batch 365: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 57.19.
# Batch 366: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 58.31.
# Batch 367: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 58.34.
# Batch 368: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 59.03.
# Batch 369: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 58.76.
# Batch 370: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 60.19.
# Batch 371: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 60.45.
# Batch 372: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 59.75.
# Batch 373: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 59.73.
# Batch 374: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 59.81.
# Batch 375: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 61.16.
# Batch 376: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 61.70.
# Batch 377: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.41,), time = 62.48.
# Batch 378: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 62.52.
# Batch 379: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 64.05.
# Batch 380: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 60.92.
# Batch 381: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 68.12.
# Batch 382: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 64.78.
# Batch 383: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 64.02.
# Batch 384: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 64.36.
# Batch 385: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 64.84.
# Batch 386: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 65.06.
# Batch 387: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 63.78.
# Batch 388: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 67.55.
# Batch 389: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 65.03.
# Batch 390: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 66.55.
# Batch 391: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 65.69.
# Batch 392: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 67.59.
# Batch 393: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 67.86.
# Batch 394: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 67.36.
# Batch 395: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 67.34.
# Batch 396: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 67.50.
# Batch 397: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 67.28.
# Batch 398: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 67.83.
# Batch 399: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 67.95.
# Batch 400: best_value (random, qNEI, TEAD) = (1.09, 0.89, 1.67,), time = 68.59.

# %%
# abbreviated QMC loop with Sobol sequences
from torch.quasirandom import SobolEngine

best_observed_all_sobol = []
x_observed_all_sobol, y_observed_all_sobol = [], []
distinct_peaks_sobol = []
function_evals_sobol = []
for trial in range(1, N_TRIALS + 1):
    print(f"\nSobol Trial {trial:>2} of {N_TRIALS} ", end="")
    best_observed_sobol = []
    # get sobol random samples for the trial
    X_Sobol = SobolEngine(dimension=2, scramble=True).draw(N_BATCH+10).to(dtype=dtype, device=device)
    Y_Sobol = torch.tensor([outcome_objective(x) for x in X_Sobol], dtype=dtype, device=device)
    curMax = torch.max(Y_Sobol[:10])
    for y_val in Y_Sobol[10:]:
        curMax = torch.max(curMax,y_val)
        best_observed_sobol.append(curMax.squeeze())
    best_observed_all_sobol.append(best_observed_sobol)
    x_observed_all_sobol.append(X_Sobol)
    y_observed_all_sobol.append(Y_Sobol)
    # distinct_peaks_sobol.append(count_number_peaks_observed(X_Sobol, Y_Sobol))
    # function_evals_sobol.append(count_evaluations_for_all_peaks(X_Sobol, Y_Sobol))
# Out:
# Sobol Trial  1 of 1

# %%
# collect output data
# calculate summary metrics
# peak ratio
num_known_peaks = 3
peak_ratio_random = sum(distinct_peaks_random) / (num_known_peaks * N_TRIALS)
peak_ratio_nei = sum(distinct_peaks_nei) / (num_known_peaks * N_TRIALS)
peak_ratio_tead = sum(distinct_peaks_tead) / (num_known_peaks * N_TRIALS)
# peak_ratio_turbo = sum(distinct_peaks_turbo) / (num_known_peaks * N_TRIALS)
peak_ratio_sobol = sum(distinct_peaks_sobol) / (num_known_peaks * N_TRIALS)
# print(f"Peak ratio: Random {peak_ratio_random:>4.2f}, NEI {peak_ratio_nei:>4.2f}, TEAD {peak_ratio_tead:>4.2f}, TuRBO {peak_ratio_turbo:>4.2f}, QMC {peak_ratio_sobol:>4.2f} ")
print(f"Peak ratio: Random {peak_ratio_random:>4.2f}, NEI {peak_ratio_nei:>4.2f}, TEAD {peak_ratio_tead:>4.2f}, QMC {peak_ratio_sobol:>4.2f} ")
# success rate
num_successes_random = 0
num_successes_nei = 0
num_successes_tead = 0
# num_successes_turbo = 0
num_successes_sobol = 0
for i in range(N_TRIALS):
    if distinct_peaks_random[i] == 4:
        num_successes_random += 1
    if distinct_peaks_nei[i] == 4:
        num_successes_nei += 1
    if distinct_peaks_tead[i] == 4:
        num_successes_tead += 1
    # if distinct_peaks_turbo[i] == 4:
    #     num_successes_turbo += 1
    if distinct_peaks_sobol[i] == 4:
        num_successes_sobol += 1
success_ratio_random = num_successes_random / N_TRIALS
success_ratio_nei = num_successes_nei / N_TRIALS
success_ratio_tead = num_successes_tead / N_TRIALS
# success_ratio_turbo = num_successes_turbo / N_TRIALS
success_ratio_sobol = num_successes_sobol / N_TRIALS
# print(f"Success ratio: Random {success_ratio_random:>4.2f}, NEI {success_ratio_nei:>4.2f}, TEAD {success_ratio_tead:>4.2f}, TuRBO {success_ratio_turbo:>4.2f}, Sobol {success_ratio_sobol:>4.2f}")
print(f"Success ratio: Random {success_ratio_random:>4.2f}, NEI {success_ratio_nei:>4.2f}, TEAD {success_ratio_tead:>4.2f}, Sobol {success_ratio_sobol:>4.2f}")
# function evaluations
fe_random = sum(function_evals_random)/N_TRIALS
fe_nei = sum(function_evals_nei)/N_TRIALS
fe_tead = sum(function_evals_tead)/N_TRIALS
# fe_turbo = sum(function_evals_turbo)/N_TRIALS
fe_sobol = sum(function_evals_sobol)/N_TRIALS
# print(f"Average function evaluations: Random {fe_random}, NEI {fe_nei}, TEAD {fe_tead}, TuRBO {fe_turbo}, Sobol {fe_sobol}")
print(f"Average function evaluations: Random {fe_random}, NEI {fe_nei}, TEAD {fe_tead}, Sobol {fe_sobol}")
# Out:
# Peak ratio: Random 0.00, NEI 0.00, TEAD 0.33, QMC 0.00
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 27
#      24         num_successes_tead += 1
#      25     # if distinct_peaks_turbo[i] == 4:
#      26     #     num_successes_turbo += 1
# ---> 27     if distinct_peaks_sobol[i] == 4:
#      28         num_successes_sobol += 1
#      29 success_ratio_random = num_successes_random / N_TRIALS
#
# IndexError: list index out of range

# %%
y_tead = np.asarray(best_observed_all_tead)
y_sobol = np.asarray(best_observed_all_sobol)

# %%
fit_gpytorch_mll(mll_nei)
fit_gpytorch_mll(mll_tead)
# fit_gpytorch_mll(mll_turbo)
None

# %%
# plot evaluations for tead - surface
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z = noise_1_2d(X1, X2)
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(10,8))
surf = ax.plot_surface(X1, X2, Z, cmap='Blues', shade=False, cstride=1, rstride=1, linewidth=0, alpha=0.2)
ax.scatter(train_x_tead[:,0].numpy()[0:10], train_x_tead[:,1].numpy()[0:10], train_obj_tead.numpy()[0:10], marker='.', color='tab:orange', s=40)
ax.scatter(train_x_tead[:,0].numpy()[10:], train_x_tead[:,1].numpy()[10:], train_obj_tead.numpy()[10:], marker='.', color='g', s=40)
plt.savefig(datasavedir + '/'+'2d_mme_noise_tead_evals'+'.png')

# %%
# plot evaluations for tead contour
fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, Z, levels=15, cmap='Blues')
cbar = fig1.colorbar(CS)
# ax1.autoscale(False)
ax1.scatter(train_x_tead[:,0].numpy()[0:10], train_x_tead[:,1].numpy()[0:10], s=15, marker='o', color='tab:orange', zorder=2)
ax1.scatter(train_x_tead[:,0].numpy()[10:], train_x_tead[:,1].numpy()[10:], s=15, marker='o', color='g', zorder=2)
ax1.set_xlim([0,1])
ax1.set_ylim([0,1])
plt.savefig(datasavedir + '/'+'2d_mme_noise_tead_evals_contour'+'.png')

# %%
# plot model contours tead
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z_tead_model = model_tead.posterior(torch.stack([X1.flatten(), X2.flatten()], dim=1)).mean
Z_tead_shaped = Z_tead_model.unflatten(dim=0, sizes=(100,100)).squeeze()

fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, Z_tead_shaped.detach().numpy(), levels=15, cmap='viridis')
cbar = fig1.colorbar(CS)

# %%
# plot model contours tead
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z_tead_model = model_tead.posterior(torch.stack([X1.flatten(), X2.flatten()], dim=1)).variance
Z_tead_shaped = Z_tead_model.unflatten(dim=0, sizes=(100,100)).squeeze()

fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, np.sqrt(Z_tead_shaped.detach().numpy()), levels=15, cmap='viridis')
cbar = fig1.colorbar(CS)

# %%
test_z = model_tead.posterior(torch.stack([X1.flatten(), X2.flatten()], dim=1)).mean

# %%
testz2 = test_z.unflatten(dim=0, sizes=(100,100))

# %%
# plot evaluations for nei
x1 = torch.arange(0.0, 1.0, 0.01)
x2 = torch.arange(0.0, 1.0, 0.01)
X1, X2 = torch.meshgrid([x1, x2])
Z = noise_1_2d(X1, X2)
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(10,8))
surf = ax.plot_surface(X1, X2, Z, cmap='Blues', shade=False, cstride=1, rstride=1, linewidth=0, alpha=0.2)
ax.scatter(train_x_nei[:,0].numpy(), train_x_nei[:,1].numpy(), train_obj_nei.numpy(), marker='.', color='g')
plt.savefig(datasavedir + '/'+'2d_mme_noise_nei_evals'+'.png')

# %%
# plot evaluations for tead contour
fig1, ax1 = plt.subplots()
CS = ax1.contour(X1, X2, Z, levels=15, cmap='Blues')
cbar = fig1.colorbar(CS)
# ax1.autoscale(False)
ax1.scatter(train_x_nei[:,0].numpy()[0:10], train_x_nei[:,1].numpy()[0:10], s=15, marker='o', color='tab:orange', zorder=2)
ax1.scatter(train_x_nei[:,0].numpy()[10:], train_x_nei[:,1].numpy()[10:], s=15, marker='o', color='g', zorder=2)
# ax1.set_xlim([0,1])
# ax1.set_ylim([0,1])
plt.savefig(datasavedir + '/'+'2d_mme_noise_nei_evals_contour'+'.png')

# %%
# plot the results for tead
x_test = torch.linspace(0,1,200)
f, ax = plt.subplots(1,1, figsize=(8, 6))
# true objective
# true objective
# ax.plot(x_test.numpy(), outcome_objective(x_test).numpy(), 'r-', alpha=0.9, label='true objective')
sns.lineplot(x=x1, y=y_deter, ax=ax, color='r')
upper_99 = torch.quantile(y_reps, 0.995, dim=1)
lower_01 = torch.quantile(y_reps, 0.005, dim=1)
ax.fill_between(x1, lower_01, upper_99, color='r', alpha=0.3, label=r'99% quantiles')
# final model
mean_test = model_tead.posterior(x_test.unsqueeze(-1)).mean.detach().numpy()
ax.plot(x_test.numpy(), mean_test, 'b-', alpha=0.9, label='surrogate mean')
var_test = model_tead.posterior(x_test.unsqueeze(-1)).variance.detach().numpy()
sd_test = np.sqrt(var_test)
upper_test = mean_test + 2.0*sd_test
lower_test = mean_test - 2.0*sd_test
ax.fill_between(x_test.numpy(), lower_test.squeeze(), upper_test.squeeze(), color='b', alpha=0.3, label=r'surrogate 2$\sigma$')
# training points
ax.plot(train_x_tead.numpy()[0:10], train_obj_tead[0:10].numpy(), '.', color='tab:orange', label='initial data')
ax.plot(train_x_tead.numpy()[10:], train_obj_tead[10:].numpy(), '.', color='g', label='bo data')
ax.legend()
None

# %%
# plot the results for nei
x_test = torch.linspace(0,1,200)
f, ax = plt.subplots(1,1, figsize=(8, 6))
# true objective
# true objective
# ax.plot(x_test.numpy(), outcome_objective(x_test).numpy(), 'r-', alpha=0.9, label='true objective')
sns.lineplot(x=x1, y=y_deter, ax=ax, color='r')
upper_99 = torch.quantile(y_reps, 0.995, dim=1)
lower_01 = torch.quantile(y_reps, 0.005, dim=1)
ax.fill_between(x1, lower_01, upper_99, color='r', alpha=0.3, label=r'99% quantiles')
# final model
mean_test = model_nei.posterior(x_test.unsqueeze(-1)).mean.detach().numpy()
ax.plot(x_test.numpy(), mean_test, 'b-', alpha=0.9, label='surrogate mean')
var_test = model_nei.posterior(x_test.unsqueeze(-1)).variance.detach().numpy()
sd_test = np.sqrt(var_test)
upper_test = mean_test + 2.0*sd_test
lower_test = mean_test - 2.0*sd_test
ax.fill_between(x_test.numpy(), lower_test.squeeze(), upper_test.squeeze(), color='b', alpha=0.3, label=r'surrogate 2$\sigma$')
# training points
ax.plot(train_x_nei.numpy()[0:10], train_obj_nei[0:10].numpy(), '.', color='tab:orange', label='initial data')
ax.plot(train_x_nei.numpy()[10:], train_obj_nei[10:].numpy(), '.', color='g', label='bo data')
ax.legend()
None

# %%
# plot the results for turbo
x_test = torch.linspace(0,1,200)
f, ax = plt.subplots(1,1, figsize=(8, 6))
# true objective
sns.lineplot(x=x1, y=y_deter, ax=ax, color='r')
upper_99 = torch.quantile(y_reps, 0.995, dim=1)
lower_01 = torch.quantile(y_reps, 0.005, dim=1)
ax.fill_between(x1, lower_01, upper_99, color='r', alpha=0.3, label=r'99% quantiles')
# final model
mean_test = model_turbo.posterior(x_test.unsqueeze(-1)).mean.detach().numpy()
ax.plot(x_test.numpy(), mean_test, 'b-', alpha=0.9, label='surrogate mean')
var_test = model_turbo.posterior(x_test.unsqueeze(-1)).variance.detach().numpy()
sd_test = np.sqrt(var_test)
upper_test = mean_test + 2.0*sd_test
lower_test = mean_test - 2.0*sd_test
ax.fill_between(x_test.numpy(), lower_test.squeeze(), upper_test.squeeze(), color='b', alpha=0.3, label=r'surrogate 2$\sigma$')
# training points
ax.plot(train_x_turbo.numpy()[0:10], train_obj_turbo[0:10].numpy(), '.', color='tab:orange', label='initial data')
ax.plot(train_x_turbo.numpy()[10:], train_obj_turbo[10:].numpy(), '.', color='g', label='bo data')
ax.legend()
None

# %%
# plot the results for random
x_test = torch.linspace(0,1,200)
f, ax = plt.subplots(1,1, figsize=(8, 6))
# true objective
sns.lineplot(x=x1, y=y_deter, ax=ax, color='r')
upper_99 = torch.quantile(y_reps, 0.995, dim=1)
lower_01 = torch.quantile(y_reps, 0.005, dim=1)
ax.fill_between(x1, lower_01, upper_99, color='r', alpha=0.3, label=r'99% quantiles')
# training points
ax.plot(train_x_random.numpy()[0:10], train_obj_random[0:10].numpy(), '.', color='tab:orange', label='initial data')
ax.plot(train_x_random.numpy()[10:], train_obj_random[10:].numpy(), '.', color='g', label='mc data')
ax.legend()
None

# %%
# plot the results for qmc
x_test = torch.linspace(0,1,200)
f, ax = plt.subplots(1,1, figsize=(8, 6))
# true objective
sns.lineplot(x=x1, y=y_deter, ax=ax, color='r')
upper_99 = torch.quantile(y_reps, 0.995, dim=1)
lower_01 = torch.quantile(y_reps, 0.005, dim=1)
ax.fill_between(x1, lower_01, upper_99, color='r', alpha=0.3, label=r'99% quantiles')
# training points
ax.plot(X_Sobol.numpy(), Y_Sobol.numpy(), '.', color='g', label='qmc data')
ax.legend()
None

# %%
# algorithms for multi-modal optimization metrics
def count_number_peaks_observed(x_obs, y_obs, num_known_peaks=4):
    """Function to count the number of peaks observed for the mme_noise_jump_1d function"""
    peak1, peak2, peak3, peak4 = False, False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.03 <= x <= 0.07:
            if y >= 1.065:
                peak1 = True
        elif 0.345 <= x <= 0.355:
            if y >= 1.12:
                peak2 = True
        elif 0.645 <= x <= 0.655:
            if y >= 1.145:
                peak3 = True
        elif 0.915 <= x <= 0.925:
            if y >= 0.734:
                peak4 = True
    num_peaks_observed = peak1 + peak2 + peak3 + peak4
    return num_peaks_observed

def count_evaluations_for_all_peaks(x_obs, y_obs):
    """Count the number of function evaluations before finding all peaks"""
    i = 0
    num_evals_for_all_peaks = x_obs.shape[0]
    peak1, peak2, peak3, peak4 = False, False, False, False
    for x, y in zip(x_obs, y_obs):
        if 0.03 <= x <= 0.07:
            if y >= 1.065:
                peak1 = True
        elif 0.345 <= x <= 0.355:
            if y >= 1.12:
                peak2 = True
        elif 0.645 <= x <= 0.655:
            if y >= 1.145:
                peak3 = True
        elif 0.915 <= x <= 0.925:
            if y >= 0.734:
                peak4 = True
        i += 1
        if peak1 and peak2 and peak3 and peak4:
            num_evals_for_all_peaks = i
            break
    return num_evals_for_all_peaks

# %%
# # calculate and print metrics
# x_sob, y_sob = X_Sobol, Y_Sobol
# x_nei, y_nei = train_x_nei, train_obj_nei
# x_ran, y_ran = train_x_random, train_obj_random
# x_tea, y_tea = train_x_tead, train_obj_tead
# x_tur, y_tur = train_x_turbo, train_obj_turbo
#
# print('Random: peaks {num}, evaluations for all {evals}'.format(num=count_number_peaks_observed(x_ran, y_ran),
#                                                                 evals=count_evaluations_for_all_peaks(x_ran, y_ran)))
# print('Sobol: peaks {num}, evaluations for all {evals}'.format(num=count_number_peaks_observed(x_sob, y_sob),
#                                                                evals=count_evaluations_for_all_peaks(x_sob, y_sob)))
# print('NEI: peaks {num}, evaluations for all {evals}'.format(num=count_number_peaks_observed(x_nei, y_nei),
#                                                                 evals=count_evaluations_for_all_peaks(x_nei, y_nei)))
# print('TuRBO: peaks {num}, evaluations for all {evals}'.format(num=count_number_peaks_observed(x_tur, y_tur),
#                                                                 evals=count_evaluations_for_all_peaks(x_tur, y_tur)))
# print('TEAD: peaks {num}, evaluations for all {evals}'.format(num=count_number_peaks_observed(x_tea, y_tea),
#                                                                 evals=count_evaluations_for_all_peaks(x_tea, y_tea)))
